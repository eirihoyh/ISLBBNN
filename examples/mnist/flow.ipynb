# %% [markdown]
# ## Imports

# %%
import copy
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from sklearn.model_selection import train_test_split
import torchvision
from torchvision import transforms
from config import config
import os
import sys
current_dir = os.getcwd()
path = "C:\\Users\\eirik\\Documents\\Master\\ISLBBNN\\islbbnn"
# path = "C:\\you\\path\\to\\islbbnn\\folder\\here"
os.chdir(path)
import plot_functions as pf
import pipeline_functions as pip_func
sys.path.append('networks')
from flow_net import BayesianNetwork
import torch.nn.functional as F

os.chdir(current_dir) # set the working directory back to this one
# Out:
# CPUs are used!

# %% [markdown]
# # Problem description
#
# The MNIST dataset from Lecun et al.
#
# # Batch size and parameters

# %%
# define parameters
HIDDEN_LAYERS = config['n_layers'] - 2 
epochs = config['num_epochs']
post_train_epochs = config['post_train_epochs']
dim = config['hidden_dim']
num_transforms = config['num_transforms']
n_nets = config['n_nets']
lr = config['lr']
class_problem = config["class_problem"]
verbose = config['verbose']
save_res = config['save_res']
patience = config['patience']
a_prior = config['a_prior']
SAMPLES = 1



#---------DATA------------
trainset = torchvision.datasets.MNIST(root='./mnist', train=True, download=True, transform=transforms.ToTensor())
testset = torchvision.datasets.MNIST(root='./mnist', train=False, download=True, transform=transforms.ToTensor())

train_data = trainset.data/255.
train_target = trainset.targets

test_data = (testset.data/255.)
test_target = testset.targets

p = train_data.shape[-1]

X_original = torch.cat((train_data, test_data), 0).detach().numpy().reshape(-1,p*p)
y_original = torch.cat((train_target, test_target), 0).detach().numpy()

n,p = X_original.shape
print(n,p,dim)

n_classes = len(np.unique(y_original))
multiclass = n_classes > 1

BATCH_SIZE = int((n*0.8)/5)
TEST_BATCH_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_BATCH_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

TRAIN_SIZE = int((n*0.80)/5)
TEST_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

NUM_BATCHES = TRAIN_SIZE/BATCH_SIZE

assert (TRAIN_SIZE % BATCH_SIZE) == 0
assert (TEST_SIZE % TEST_BATCH_SIZE) == 0
# Out:
# 70000 784 50

# %% [markdown]
# # Sigmoid based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 47540
# 0
# loss 687945.25
# nll 12666.9921875
# density 0.9801229467613134
#
# val_loss: 679664.9375, val_nll: 7645.8179, val_ensemble: 0.6643, used_weights_median: 47540
#
# 1
# loss 663841.875
# nll 7066.7802734375
# density 0.9750181866559754
#
# val_loss: 657713.6250, val_nll: 4381.0200, val_ensemble: 0.8076, used_weights_median: 47540
#
# 2
# loss 644486.25
# nll 5103.00390625
# density 0.968556185792011
#
# val_loss: 639250.3750, val_nll: 3436.5881, val_ensemble: 0.8557, used_weights_median: 47540
#
# 3
# loss 625842.9375
# nll 4445.7998046875
# density 0.9603420470058792
#
# val_loss: 620638.5625, val_nll: 2969.2178, val_ensemble: 0.8804, used_weights_median: 47540
#
# 4
# loss 606378.75
# nll 4042.747802734375
# density 0.9499123351948573
#
# val_loss: 601104.0000, val_nll: 2797.3328, val_ensemble: 0.8887, used_weights_median: 47540
#
# 5
# loss 585537.9375
# nll 3766.090087890625
# density 0.9367379764536122
#
# val_loss: 580039.4375, val_nll: 2559.2029, val_ensemble: 0.8973, used_weights_median: 47540
#
# 6
# loss 563160.9375
# nll 3539.29541015625
# density 0.9202744757371838
#
# val_loss: 557357.5625, val_nll: 2450.5251, val_ensemble: 0.9011, used_weights_median: 47540
#
# 7
# loss 538871.1875
# nll 3394.014404296875
# density 0.9000033276136
#
# val_loss: 532753.6875, val_nll: 2320.9436, val_ensemble: 0.9046, used_weights_median: 46663
#
# 8
# loss 512836.65625
# nll 3320.792724609375
# density 0.8755042097525382
#
# val_loss: 506332.6875, val_nll: 2272.8318, val_ensemble: 0.9101, used_weights_median: 44774
#
# 9
# loss 484745.15625
# nll 3213.62646484375
# density 0.8464892799055872
#
# val_loss: 477914.0312, val_nll: 2204.2029, val_ensemble: 0.9107, used_weights_median: 42633
#
# 10
# loss 454783.3125
# nll 3143.15576171875
# density 0.8128319216917982
#
# val_loss: 447604.0000, val_nll: 2158.8125, val_ensemble: 0.9123, used_weights_median: 40370
#
# 11
# loss 423243.21875
# nll 3098.59619140625
# density 0.7745535680838478
#
# val_loss: 415741.3125, val_nll: 2081.9377, val_ensemble: 0.9141, used_weights_median: 37872
#
# 12
# loss 390242.0625
# nll 3078.267822265625
# density 0.7318110040571191
#
# val_loss: 382572.6875, val_nll: 2116.9941, val_ensemble: 0.9137, used_weights_median: 35187
#
# 13
# loss 356226.5
# nll 3068.12841796875
# density 0.6848712105111234
#
# val_loss: 348302.6875, val_nll: 2083.2734, val_ensemble: 0.9161, used_weights_median: 32407
#
# 14
# loss 321502.75
# nll 3117.736328125
# density 0.6341038942243002
#
# val_loss: 313423.0938, val_nll: 2064.7136, val_ensemble: 0.9169, used_weights_median: 29497
#
# 15
# loss 286328.65625
# nll 3178.12255859375
# density 0.5799663282404264
#
# val_loss: 278199.5938, val_nll: 2078.5449, val_ensemble: 0.9176, used_weights_median: 26466
#
# 16
# loss 251177.703125
# nll 3220.444580078125
# density 0.5230101010163868
#
# val_loss: 243080.6094, val_nll: 2129.5759, val_ensemble: 0.9127, used_weights_median: 23318
#
# 17
# loss 216616.25
# nll 3382.71533203125
# density 0.4639216871655534
#
# val_loss: 208628.8594, val_nll: 2246.8611, val_ensemble: 0.9057, used_weights_median: 20145
#
# 18
# loss 183025.125
# nll 3475.251220703125
# density 0.40364567656814426
#
# val_loss: 175215.3906, val_nll: 2262.0818, val_ensemble: 0.9067, used_weights_median: 16390
#
# 19
# loss 151070.09375
# nll 3557.39697265625
# density 0.3433562612036446
#
# val_loss: 143606.0312, val_nll: 2257.0789, val_ensemble: 0.9050, used_weights_median: 13146
#
# 20
# loss 121634.171875
# nll 3784.2109375
# density 0.28485584185060253
#
# val_loss: 114804.5312, val_nll: 2438.3831, val_ensemble: 0.8967, used_weights_median: 9511
#
# 21
# loss 95761.4375
# nll 4050.857666015625
# density 0.23050163442587898
#
# val_loss: 89878.6016, val_nll: 2904.2249, val_ensemble: 0.8770, used_weights_median: 6062
#
# 22
# loss 74023.203125
# nll 4194.19873046875
# density 0.183014732560548
#
# val_loss: 69480.4219, val_nll: 3338.8909, val_ensemble: 0.8529, used_weights_median: 2378
#
# 23
# loss 57450.671875
# nll 4440.45458984375
# density 0.14462434068074562
#
# val_loss: 53984.2695, val_nll: 3692.0896, val_ensemble: 0.8369, used_weights_median: 463
#
# 24
# loss 45566.1875
# nll 4508.92822265625
# density 0.11575748132840331
#
# val_loss: 42766.8984, val_nll: 3670.9641, val_ensemble: 0.8361, used_weights_median: 358
#
# 25
# loss 37403.51953125
# nll 4602.0361328125
# density 0.09526999818523942
#
# val_loss: 35094.6641, val_nll: 3649.7661, val_ensemble: 0.8347, used_weights_median: 308
#
# 26
# loss 31958.19921875
# nll 4701.69287109375
# density 0.08099939665103979
#
# val_loss: 29976.9238, val_nll: 3603.6707, val_ensemble: 0.8391, used_weights_median: 292
#
# 27
# loss 27992.79296875
# nll 4693.4384765625
# density 0.07094289046971987
#
# val_loss: 26299.3652, val_nll: 3536.0876, val_ensemble: 0.8460, used_weights_median: 276
#
# 28
# loss 25146.7734375
# nll 4645.96875
# density 0.06364448280298991
#
# val_loss: 23486.4375, val_nll: 3440.0657, val_ensemble: 0.8461, used_weights_median: 274
#
# 29
# loss 23085.40625
# nll 4660.9189453125
# density 0.05814381650138488
#
# val_loss: 21288.6562, val_nll: 3296.1133, val_ensemble: 0.8577, used_weights_median: 267
#
# 30
# loss 21277.62890625
# nll 4557.17578125
# density 0.053843856809584784
#
# val_loss: 19644.3730, val_nll: 3228.6577, val_ensemble: 0.8626, used_weights_median: 261
#
# 31
# loss 19883.90234375
# nll 4545.35400390625
# density 0.05036715646954171
#
# val_loss: 18315.2305, val_nll: 3238.2188, val_ensemble: 0.8599, used_weights_median: 259
#
# 32
# loss 18762.68359375
# nll 4620.47802734375
# density 0.047454120427077
#
# val_loss: 17312.4863, val_nll: 3305.3157, val_ensemble: 0.8564, used_weights_median: 256
#
# 33
# loss 17774.193359375
# nll 4660.02099609375
# density 0.04496370739862636
#
# val_loss: 17609.2812, val_nll: 3332.2861, val_ensemble: 0.8533, used_weights_median: 250
#
# 34
# loss 16847.693359375
# nll 4586.11474609375
# density 0.042788709616927184
#
# val_loss: 15313.1807, val_nll: 3103.7141, val_ensemble: 0.8664, used_weights_median: 249
#
# 35
# loss 16110.6630859375
# nll 4506.11328125
# density 0.040871285881767215
#
# val_loss: 14596.1465, val_nll: 3139.1909, val_ensemble: 0.8646, used_weights_median: 247
#
# 36
# loss 15453.078125
# nll 4610.89453125
# density 0.039163109886377334
#
# val_loss: 13856.2363, val_nll: 3143.4631, val_ensemble: 0.8626, used_weights_median: 243
#
# 37
# loss 14712.07421875
# nll 4533.7216796875
# density 0.0376233608644498
#
# val_loss: 13086.9492, val_nll: 3055.4189, val_ensemble: 0.8729, used_weights_median: 244
#
# 38
# loss 14020.845703125
# nll 4492.20654296875
# density 0.03621623860734805
#
# val_loss: 12467.8369, val_nll: 3063.2390, val_ensemble: 0.8706, used_weights_median: 244
#
# 39
# loss 13444.8291015625
# nll 4499.5751953125
# density 0.034928955891564153
#
# val_loss: 11900.8105, val_nll: 3015.4556, val_ensemble: 0.8731, used_weights_median: 244
#
# 40
# loss 4851.0751953125
# nll 4626.1298828125
# density 0.034928955891564153
#
# val_loss: 3128.2358, val_nll: 3071.1931, val_ensemble: 0.8731, used_weights_median: 244
#
# 41
# loss 4630.18115234375
# nll 4650.50537109375
# density 0.034928955891564153
#
# val_loss: 2913.2476, val_nll: 3089.8091, val_ensemble: 0.8716, used_weights_median: 244
#
# 42
# loss 4307.0205078125
# nll 4708.3173828125
# density 0.034928955891564153
#
# val_loss: 2667.8804, val_nll: 3133.6138, val_ensemble: 0.8707, used_weights_median: 244
#
# 43
# loss 4057.74951171875
# nll 4687.83935546875
# density 0.034928955891564153
#
# val_loss: 2371.2524, val_nll: 3049.7559, val_ensemble: 0.8699, used_weights_median: 244
#
# 44
# loss 3768.201171875
# nll 4579.0068359375
# density 0.034928955891564153
#
# val_loss: 2148.3193, val_nll: 3030.8789, val_ensemble: 0.8774, used_weights_median: 244
#
# 45
# loss 3575.41845703125
# nll 4630.86572265625
# density 0.034928955891564153
#
# val_loss: 2007.9523, val_nll: 3073.9880, val_ensemble: 0.8709, used_weights_median: 244
#
# 46
# loss 3299.4052734375
# nll 4553.7138671875
# density 0.034928955891564153
#
# val_loss: 1879.5308, val_nll: 3061.9414, val_ensemble: 0.8676, used_weights_median: 244
#
# 47
# loss 3021.2373046875
# nll 4500.69140625
# density 0.034928955891564153
#
# val_loss: 1549.2732, val_nll: 2976.5627, val_ensemble: 0.8756, used_weights_median: 244
#
# 48
# loss 2900.228759765625
# nll 4569.6943359375
# density 0.034928955891564153
#
# val_loss: 1320.0192, val_nll: 3001.1855, val_ensemble: 0.8740, used_weights_median: 244
#
# 49
# loss 2683.068603515625
# nll 4581.97412109375
# density 0.034928955891564153
#
# val_loss: 1162.7732, val_nll: 3011.8750, val_ensemble: 0.8730, used_weights_median: 244
#
# 50
# loss 2506.24658203125
# nll 4511.701171875
# density 0.034928955891564153
#
# val_loss: 976.2185, val_nll: 3041.3247, val_ensemble: 0.8707, used_weights_median: 244
#
# 51
# loss 2243.54150390625
# nll 4527.21142578125
# density 0.034928955891564153
#
# val_loss: 697.2163, val_nll: 2986.4346, val_ensemble: 0.8750, used_weights_median: 244
#
# 52
# loss 2009.683349609375
# nll 4486.7353515625
# density 0.034928955891564153
#
# val_loss: 471.9985, val_nll: 2994.3237, val_ensemble: 0.8769, used_weights_median: 244
#
# 53
# loss 1825.22265625
# nll 4506.70703125
# density 0.034928955891564153
#
# val_loss: 708.1758, val_nll: 3056.1055, val_ensemble: 0.8751, used_weights_median: 244
#
# 54
# loss 1646.900634765625
# nll 4474.06298828125
# density 0.034928955891564153
#
# val_loss: 109.4631, val_nll: 3028.8015, val_ensemble: 0.8729, used_weights_median: 244
#
# 55
# loss 1422.220703125
# nll 4446.15673828125
# density 0.034928955891564153
#
# val_loss: -26.9563, val_nll: 3012.6482, val_ensemble: 0.8756, used_weights_median: 244
#
# 56
# loss 1284.97265625
# nll 4513.2626953125
# density 0.034928955891564153
#
# val_loss: -110.6218, val_nll: 3045.9084, val_ensemble: 0.8739, used_weights_median: 244
#
# 57
# loss 1323.712890625
# nll 4598.021484375
# density 0.034928955891564153
#
# val_loss: -420.1179, val_nll: 2965.7556, val_ensemble: 0.8771, used_weights_median: 244
#
# 58
# loss 901.3955078125
# nll 4540.4697265625
# density 0.034928955891564153
#
# val_loss: -639.9717, val_nll: 2969.9348, val_ensemble: 0.8777, used_weights_median: 244
#
# 59
# loss 741.11572265625
# nll 4465.2607421875
# density 0.034928955891564153
#
# val_loss: -840.2466, val_nll: 3022.5925, val_ensemble: 0.8780, used_weights_median: 244
#
# 60
# loss 490.851806640625
# nll 4455.62548828125
# density 0.034928955891564153
#
# val_loss: -1143.1555, val_nll: 2954.3225, val_ensemble: 0.8794, used_weights_median: 244
#
# 61
# loss 229.30126953125
# nll 4444.59814453125
# density 0.034928955891564153
#
# val_loss: -1187.8826, val_nll: 2998.3860, val_ensemble: 0.8761, used_weights_median: 244
#
# 62
# loss 25.67138671875
# nll 4477.38623046875
# density 0.034928955891564153
#
# val_loss: -1415.9963, val_nll: 2982.4041, val_ensemble: 0.8777, used_weights_median: 244
#
# 63
# loss -17.26953125
# nll 4538.34326171875
# density 0.034928955891564153
#
# val_loss: -1646.3777, val_nll: 2988.0754, val_ensemble: 0.8744, used_weights_median: 244
#
# 64
# loss -36.3818359375
# nll 4605.14990234375
# density 0.034928955891564153
#
# val_loss: -1596.0110, val_nll: 3181.6755, val_ensemble: 0.8649, used_weights_median: 244
#
# 65
# loss 1378.9716796875
# nll 4765.04638671875
# density 0.034928955891564153
#
# val_loss: -1634.7129, val_nll: 3198.6338, val_ensemble: 0.8701, used_weights_median: 244
#
# 66
# loss -152.07763671875
# nll 4851.94677734375
# density 0.034928955891564153
#
# val_loss: -1297.7693, val_nll: 3168.5491, val_ensemble: 0.8707, used_weights_median: 244
#
# 67
# loss -170.7470703125
# nll 4632.955078125
# density 0.034928955891564153
#
# val_loss: -1799.9280, val_nll: 3072.7136, val_ensemble: 0.8726, used_weights_median: 244
#
# 68
# loss -381.1318359375
# nll 4692.21875
# density 0.034928955891564153
#
# val_loss: -2101.1235, val_nll: 3048.0605, val_ensemble: 0.8756, used_weights_median: 244
#
# 69
# loss -743.46923828125
# nll 4577.96533203125
# density 0.034928955891564153
#
# val_loss: -2217.0823, val_nll: 3096.4519, val_ensemble: 0.8693, used_weights_median: 244
#
# 70
# loss -858.40869140625
# nll 4624.8056640625
# density 0.034928955891564153
#
# val_loss: -2427.4729, val_nll: 3002.7615, val_ensemble: 0.8760, used_weights_median: 244
#
# 71
# loss -967.85791015625
# nll 4626.97607421875
# density 0.034928955891564153
#
# val_loss: -2543.8752, val_nll: 3033.7571, val_ensemble: 0.8759, used_weights_median: 244
#
# 72
# loss -1206.96044921875
# nll 4527.30224609375
# density 0.034928955891564153
#
# val_loss: -2757.6980, val_nll: 2957.6541, val_ensemble: 0.8764, used_weights_median: 244
#
# 73
# loss -1322.34716796875
# nll 4533.13720703125
# density 0.034928955891564153
#
# val_loss: -2917.9827, val_nll: 3016.9050, val_ensemble: 0.8749, used_weights_median: 244
#
# 74
# loss -1575.10400390625
# nll 4530.39501953125
# density 0.034928955891564153
#
# val_loss: -3050.0168, val_nll: 3056.4729, val_ensemble: 0.8676, used_weights_median: 244
#
# 75
# loss -1684.81298828125
# nll 4538.01416015625
# density 0.034928955891564153
#
# val_loss: -3167.9810, val_nll: 3052.2837, val_ensemble: 0.8730, used_weights_median: 244
#
# 76
# loss -1770.1181640625
# nll 4581.765625
# density 0.034928955891564153
#
# val_loss: -3384.1963, val_nll: 2912.9502, val_ensemble: 0.8804, used_weights_median: 244
#
# 77
# loss -1936.53857421875
# nll 4501.41845703125
# density 0.034928955891564153
#
# val_loss: -3510.0322, val_nll: 3002.2505, val_ensemble: 0.8759, used_weights_median: 244
#
# 78
# loss -2045.1337890625
# nll 4506.05859375
# density 0.034928955891564153
#
# val_loss: -3633.9087, val_nll: 2947.1860, val_ensemble: 0.8756, used_weights_median: 244
#
# 79
# loss -2328.7265625
# nll 4444.9794921875
# density 0.034928955891564153
#
# val_loss: -3856.6931, val_nll: 2960.7483, val_ensemble: 0.8770, used_weights_median: 244
#
# 0.0051325196 density median
# 244.0 used weights median
# 0.14777142857142858 ensemble full
# 0.8799857142857144 ensemble median
# [0.14777142857142858, 0.0051325196]

# %% [markdown]
# ## Weights used each class

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")

# %% [markdown]
# # ReLU based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    #---------------------------
    # DIFFERENCE IS IN act_func=F.relu part
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, act_func=F.relu, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    #---------------------------
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 47540
# 0
# loss 697123.875
# nll 20691.67578125
# density 0.9801520749657004
#
# val_loss: 679578.7500, val_nll: 8222.4707, val_ensemble: 0.6424, used_weights_median: 47540
#
# 1
# loss 663353.625
# nll 6735.84375
# density 0.9751338176181651
#
# val_loss: 657500.9375, val_nll: 4101.2568, val_ensemble: 0.8263, used_weights_median: 47540
#
# 2
# loss 644677.0625
# nll 4668.18212890625
# density 0.9687656215486479
#
# val_loss: 639572.9375, val_nll: 3115.2363, val_ensemble: 0.8669, used_weights_median: 47540
#
# 3
# loss 626298.9375
# nll 4236.05322265625
# density 0.9606638548363644
#
# val_loss: 621194.6875, val_nll: 2838.7205, val_ensemble: 0.8876, used_weights_median: 47540
#
# 4
# loss 606934.1875
# nll 3864.149169921875
# density 0.9503677045153027
#
# val_loss: 601794.3125, val_nll: 2715.6772, val_ensemble: 0.8941, used_weights_median: 47540
#
# 5
# loss 586212.4375
# nll 3581.123046875
# density 0.9373540363394015
#
# val_loss: 580845.7500, val_nll: 2491.5425, val_ensemble: 0.9021, used_weights_median: 47540
#
# 6
# loss 563961.5625
# nll 3395.746337890625
# density 0.9210775447897315
#
# val_loss: 558173.7500, val_nll: 2302.7688, val_ensemble: 0.9119, used_weights_median: 47540
#
# 7
# loss 539727.75
# nll 3209.529052734375
# density 0.9010220599828972
#
# val_loss: 533657.3125, val_nll: 2156.6504, val_ensemble: 0.9147, used_weights_median: 46702
#
# 8
# loss 513722.59375
# nll 3066.624267578125
# density 0.8767618914668832
#
# val_loss: 507320.2500, val_nll: 2092.1509, val_ensemble: 0.9169, used_weights_median: 44853
#
# 9
# loss 485693.25
# nll 2927.193115234375
# density 0.8480021267878592
#
# val_loss: 478913.5000, val_nll: 1951.7574, val_ensemble: 0.9224, used_weights_median: 42738
#
# 10
# loss 455746.65625
# nll 2789.611572265625
# density 0.8146069356710107
#
# val_loss: 448688.0312, val_nll: 1911.8992, val_ensemble: 0.9234, used_weights_median: 40493
#
# 11
# loss 424258.40625
# nll 2736.94873046875
# density 0.7765898227936138
#
# val_loss: 416910.0625, val_nll: 1854.7428, val_ensemble: 0.9270, used_weights_median: 37991
#
# 12
# loss 391255.0
# nll 2620.5712890625
# density 0.734090771660566
#
# val_loss: 383724.5625, val_nll: 1783.3164, val_ensemble: 0.9271, used_weights_median: 35332
#
# 13
# loss 357298.40625
# nll 2600.967041015625
# density 0.6873702461971146
#
# val_loss: 349501.1875, val_nll: 1726.9661, val_ensemble: 0.9289, used_weights_median: 32566
#
# 14
# loss 322568.4375
# nll 2594.24951171875
# density 0.6367848349090228
#
# val_loss: 314636.9688, val_nll: 1681.5408, val_ensemble: 0.9307, used_weights_median: 29690
#
# 15
# loss 287382.5
# nll 2623.7783203125
# density 0.5827834146709303
#
# val_loss: 279479.5625, val_nll: 1735.5613, val_ensemble: 0.9273, used_weights_median: 26644
#
# 16
# loss 252260.734375
# nll 2690.940185546875
# density 0.5259391487503583
#
# val_loss: 244289.1875, val_nll: 1724.4662, val_ensemble: 0.9263, used_weights_median: 23469
#
# 17
# loss 217700.40625
# nll 2819.72412109375
# density 0.466979004363547
#
# val_loss: 209738.8438, val_nll: 1727.3414, val_ensemble: 0.9276, used_weights_median: 20305
#
# 18
# loss 184067.078125
# nll 2878.498779296875
# density 0.4068341112211754
#
# val_loss: 176414.3594, val_nll: 1815.0055, val_ensemble: 0.9233, used_weights_median: 16811
#
# 19
# loss 152108.25
# nll 2931.006591796875
# density 0.3466958066997881
#
# val_loss: 144832.7500, val_nll: 1823.3132, val_ensemble: 0.9213, used_weights_median: 13544
#
# 20
# loss 122667.703125
# nll 3156.55859375
# density 0.288317404708092
#
# val_loss: 116001.2109, val_nll: 1974.9844, val_ensemble: 0.9151, used_weights_median: 10206
#
# 21
# loss 96840.6875
# nll 3465.526611328125
# density 0.23404590909596146
#
# val_loss: 91078.9062, val_nll: 2387.3247, val_ensemble: 0.8987, used_weights_median: 6555
#
# 22
# loss 75053.6640625
# nll 3600.76123046875
# density 0.18648689209045133
#
# val_loss: 70331.9297, val_nll: 2641.5852, val_ensemble: 0.8853, used_weights_median: 2999
#
# 23
# loss 58374.86328125
# nll 3904.659423828125
# density 0.14780487060017153
#
# val_loss: 55621.3789, val_nll: 3917.3555, val_ensemble: 0.8196, used_weights_median: 633
#
# 24
# loss 46260.94921875
# nll 3986.8212890625
# density 0.11876503744961511
#
# val_loss: 44727.0391, val_nll: 4404.0947, val_ensemble: 0.7879, used_weights_median: 491
#
# 25
# loss 37957.15625
# nll 4047.288818359375
# density 0.09804877130080408
#
# val_loss: 37025.3984, val_nll: 4514.0425, val_ensemble: 0.7827, used_weights_median: 410
#
# 26
# loss 32577.72265625
# nll 4125.18798828125
# density 0.0835681614366101
#
# val_loss: 31482.9707, val_nll: 4108.2285, val_ensemble: 0.8054, used_weights_median: 376
#
# 27
# loss 28500.27734375
# nll 4039.96630859375
# density 0.07331147791577215
#
# val_loss: 27862.9922, val_nll: 4081.7268, val_ensemble: 0.8087, used_weights_median: 351
#
# 28
# loss 25486.25
# nll 4021.21142578125
# density 0.06584264275695867
#
# val_loss: 24828.3945, val_nll: 3708.1743, val_ensemble: 0.8333, used_weights_median: 329
#
# 29
# loss 23242.19921875
# nll 3912.664794921875
# density 0.06017717673832321
#
# val_loss: 22752.1348, val_nll: 3822.8765, val_ensemble: 0.8230, used_weights_median: 323
#
# 30
# loss 21462.8984375
# nll 3891.866455078125
# density 0.05574943483570104
#
# val_loss: 20581.7559, val_nll: 3243.1106, val_ensemble: 0.8556, used_weights_median: 315
#
# 31
# loss 20156.9921875
# nll 3885.38427734375
# density 0.05215819464893804
#
# val_loss: 19388.3594, val_nll: 3479.7163, val_ensemble: 0.8441, used_weights_median: 313
#
# 32
# loss 18903.8984375
# nll 3866.7294921875
# density 0.049153207020844275
#
# val_loss: 17907.5215, val_nll: 3053.4563, val_ensemble: 0.8657, used_weights_median: 312
#
# 33
# loss 17944.673828125
# nll 3974.70166015625
# density 0.046574340158423856
#
# val_loss: 16716.7891, val_nll: 2945.4116, val_ensemble: 0.8731, used_weights_median: 306
#
# 34
# loss 16872.046875
# nll 3849.687744140625
# density 0.04432613154537082
#
# val_loss: 15839.0977, val_nll: 2944.5959, val_ensemble: 0.8733, used_weights_median: 300
#
# 35
# loss 16104.8046875
# nll 3858.820068359375
# density 0.042335120593477785
#
# val_loss: 14703.7578, val_nll: 2680.5022, val_ensemble: 0.8871, used_weights_median: 298
#
# 36
# loss 15315.0126953125
# nll 3899.531982421875
# density 0.040545805755510554
#
# val_loss: 14021.3574, val_nll: 2770.3247, val_ensemble: 0.8787, used_weights_median: 295
#
# 37
# loss 14581.8857421875
# nll 3845.175048828125
# density 0.03893088015312776
#
# val_loss: 13391.5469, val_nll: 2755.7285, val_ensemble: 0.8793, used_weights_median: 292
#
# 38
# loss 14008.38671875
# nll 3875.14990234375
# density 0.03746208199752408
#
# val_loss: 12553.4502, val_nll: 2667.1443, val_ensemble: 0.8866, used_weights_median: 287
#
# 39
# loss 13360.896484375
# nll 3690.191650390625
# density 0.03612179163844177
#
# val_loss: 11991.9717, val_nll: 2701.9114, val_ensemble: 0.8861, used_weights_median: 285
#
# 40
# loss 4368.64404296875
# nll 3979.3330078125
# density 0.03612179163844177
#
# val_loss: 3053.6631, val_nll: 2734.6064, val_ensemble: 0.8863, used_weights_median: 285
#
# 41
# loss 4212.57763671875
# nll 3864.186767578125
# density 0.03612179163844177
#
# val_loss: 3047.3494, val_nll: 2711.3140, val_ensemble: 0.8843, used_weights_median: 285
#
# 42
# loss 3787.364501953125
# nll 3841.41650390625
# density 0.03612179163844177
#
# val_loss: 2488.3599, val_nll: 2616.7017, val_ensemble: 0.8883, used_weights_median: 285
#
# 43
# loss 3609.74658203125
# nll 3854.93798828125
# density 0.03612179163844177
#
# val_loss: 2290.8904, val_nll: 2608.7734, val_ensemble: 0.8864, used_weights_median: 285
#
# 44
# loss 3375.727783203125
# nll 3809.617431640625
# density 0.03612179163844177
#
# val_loss: 2130.3032, val_nll: 2701.4114, val_ensemble: 0.8900, used_weights_median: 285
#
# 45
# loss 3279.09521484375
# nll 3889.735595703125
# density 0.03612179163844177
#
# val_loss: 2027.2046, val_nll: 2752.7539, val_ensemble: 0.8860, used_weights_median: 285
#
# 46
# loss 3069.05126953125
# nll 3964.29443359375
# density 0.03612179163844177
#
# val_loss: 1619.9097, val_nll: 2601.7051, val_ensemble: 0.8876, used_weights_median: 285
#
# 47
# loss 2651.798828125
# nll 3792.60009765625
# density 0.03612179163844177
#
# val_loss: 1382.3804, val_nll: 2633.2471, val_ensemble: 0.8880, used_weights_median: 285
#
# 48
# loss 2383.2080078125
# nll 3761.39794921875
# density 0.03612179163844177
#
# val_loss: 1170.9542, val_nll: 2601.7236, val_ensemble: 0.8880, used_weights_median: 285
#
# 49
# loss 2203.217529296875
# nll 3813.5224609375
# density 0.03612179163844177
#
# val_loss: 954.4200, val_nll: 2593.0557, val_ensemble: 0.8924, used_weights_median: 285
#
# 50
# loss 1946.2890625
# nll 3776.927734375
# density 0.03612179163844177
#
# val_loss: 1058.4308, val_nll: 2668.0823, val_ensemble: 0.8890, used_weights_median: 285
#
# 51
# loss 1983.88427734375
# nll 3849.746826171875
# density 0.03612179163844177
#
# val_loss: 543.8455, val_nll: 2633.7703, val_ensemble: 0.8914, used_weights_median: 285
#
# 52
# loss 1555.683349609375
# nll 3799.030029296875
# density 0.03612179163844177
#
# val_loss: 446.3203, val_nll: 2709.7524, val_ensemble: 0.8846, used_weights_median: 285
#
# 53
# loss 2369.60546875
# nll 3729.00341796875
# density 0.03612179163844177
#
# val_loss: 1028.7134, val_nll: 2569.8044, val_ensemble: 0.8929, used_weights_median: 285
#
# 54
# loss 1130.384765625
# nll 3719.94873046875
# density 0.03612179163844177
#
# val_loss: 464.0352, val_nll: 2576.6714, val_ensemble: 0.8881, used_weights_median: 285
#
# 55
# loss 1339.973388671875
# nll 3769.560302734375
# density 0.03612179163844177
#
# val_loss: -19.0107, val_nll: 2634.0571, val_ensemble: 0.8887, used_weights_median: 285
#
# 56
# loss 1036.87158203125
# nll 3759.494140625
# density 0.03612179163844177
#
# val_loss: -406.8342, val_nll: 2560.9873, val_ensemble: 0.8920, used_weights_median: 285
#
# 57
# loss 637.926025390625
# nll 3769.343505859375
# density 0.03612179163844177
#
# val_loss: -556.1289, val_nll: 2598.4395, val_ensemble: 0.8901, used_weights_median: 285
#
# 58
# loss 475.321044921875
# nll 3757.667724609375
# density 0.03612179163844177
#
# val_loss: -795.0559, val_nll: 2502.5378, val_ensemble: 0.8933, used_weights_median: 285
#
# 59
# loss 260.46923828125
# nll 3758.1357421875
# density 0.03612179163844177
#
# val_loss: -944.0525, val_nll: 2540.5022, val_ensemble: 0.8907, used_weights_median: 285
#
# 60
# loss 47.7919921875
# nll 3661.841552734375
# density 0.03612179163844177
#
# val_loss: -1210.0427, val_nll: 2531.3357, val_ensemble: 0.8921, used_weights_median: 285
#
# 61
# loss -281.069580078125
# nll 3631.816162109375
# density 0.03612179163844177
#
# val_loss: -1345.9585, val_nll: 2514.1514, val_ensemble: 0.8943, used_weights_median: 285
#
# 62
# loss -433.668212890625
# nll 3683.562744140625
# density 0.03612179163844177
#
# val_loss: -1540.8181, val_nll: 2554.1406, val_ensemble: 0.8931, used_weights_median: 285
#
# 63
# loss -553.252685546875
# nll 3736.592041015625
# density 0.03612179163844177
#
# val_loss: -1849.1348, val_nll: 2487.2012, val_ensemble: 0.8924, used_weights_median: 285
#
# 64
# loss -738.201904296875
# nll 3768.354736328125
# density 0.03612179163844177
#
# val_loss: 733.1699, val_nll: 5257.0342, val_ensemble: 0.7920, used_weights_median: 285
#
# 65
# loss 11800.291015625
# nll 3806.8232421875
# density 0.03612179163844177
#
# val_loss: 6315.1133, val_nll: 2613.7246, val_ensemble: 0.8900, used_weights_median: 285
#
# 66
# loss -78.195556640625
# nll 3818.002685546875
# density 0.03612179163844177
#
# val_loss: -1453.5520, val_nll: 2521.7639, val_ensemble: 0.8901, used_weights_median: 285
#
# 67
# loss -305.335693359375
# nll 3804.673583984375
# density 0.03612179163844177
#
# val_loss: -1514.6768, val_nll: 2594.2690, val_ensemble: 0.8910, used_weights_median: 285
#
# 68
# loss -317.548095703125
# nll 3801.348388671875
# density 0.03612179163844177
#
# val_loss: -1574.0205, val_nll: 2538.8418, val_ensemble: 0.8957, used_weights_median: 285
#
# 69
# loss -506.114501953125
# nll 3759.804443359375
# density 0.03612179163844177
#
# val_loss: -1699.9272, val_nll: 2519.9380, val_ensemble: 0.8896, used_weights_median: 285
#
# 70
# loss -670.76611328125
# nll 3740.36376953125
# density 0.03612179163844177
#
# val_loss: -1789.8242, val_nll: 2569.4336, val_ensemble: 0.8909, used_weights_median: 285
#
# 71
# loss -805.0341796875
# nll 3685.53466796875
# density 0.03612179163844177
#
# val_loss: -1986.5366, val_nll: 2508.8867, val_ensemble: 0.8904, used_weights_median: 285
#
# 72
# loss -1049.319580078125
# nll 3626.571533203125
# density 0.03612179163844177
#
# val_loss: -2204.8196, val_nll: 2456.0530, val_ensemble: 0.8941, used_weights_median: 285
#
# 73
# loss -1030.6494140625
# nll 3705.1513671875
# density 0.03612179163844177
#
# val_loss: -2233.7288, val_nll: 2571.8704, val_ensemble: 0.8913, used_weights_median: 285
#
# 74
# loss -1274.01708984375
# nll 3674.64697265625
# density 0.03612179163844177
#
# val_loss: -2458.1362, val_nll: 2483.9927, val_ensemble: 0.8950, used_weights_median: 285
#
# 75
# loss -1372.529296875
# nll 3654.09130859375
# density 0.03612179163844177
#
# val_loss: -2559.3870, val_nll: 2492.4871, val_ensemble: 0.8959, used_weights_median: 285
#
# 76
# loss -1399.76708984375
# nll 3720.87841796875
# density 0.03612179163844177
#
# val_loss: -2604.3811, val_nll: 2573.7244, val_ensemble: 0.8931, used_weights_median: 285
#
# 77
# loss -1589.139892578125
# nll 3631.564208984375
# density 0.03612179163844177
#
# val_loss: -2740.8831, val_nll: 2534.9749, val_ensemble: 0.8917, used_weights_median: 285
#
# 78
# loss -1692.64111328125
# nll 3634.29931640625
# density 0.03612179163844177
#
# val_loss: -2861.7698, val_nll: 2533.3054, val_ensemble: 0.8936, used_weights_median: 285
#
# 79
# loss -1939.2080078125
# nll 3570.90673828125
# density 0.03612179163844177
#
# val_loss: -2989.1318, val_nll: 2511.5137, val_ensemble: 0.8919, used_weights_median: 285
#
# 0.0059949523 density median
# 285.0 used weights median
# 0.10914285714285714 ensemble full
# 0.8999142857142857 ensemble median
# [0.10914285714285714, 0.0059949523]

# %% [markdown]
# ## Weights used each class

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")
