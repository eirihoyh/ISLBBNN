# %% [markdown]
# ## Imports

# %%
import copy
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from sklearn.model_selection import train_test_split
import torchvision
from torchvision import transforms
from config import config
import os
import sys
current_dir = os.getcwd()
path = "C:\\Users\\eirik\\Documents\\Master\\ISLBBNN\\islbbnn"
# path = "C:\\you\\path\\to\\islbbnn\\folder\\here"
os.chdir(path)
import plot_functions as pf
import pipeline_functions as pip_func
sys.path.append('networks')
from lrt_net import BayesianNetwork
import torch.nn.functional as F

os.chdir(current_dir) # set the working directory back to this one

# %% [markdown]
# # Problem description
#
# The MNIST dataset from Lecun et al.
#
# # Batch size and parameters

# %%
# define parameters
HIDDEN_LAYERS = config['n_layers'] - 2 
epochs = config['num_epochs']
post_train_epochs = config['post_train_epochs']
dim = config['hidden_dim']
num_transforms = config['num_transforms']
n_nets = config['n_nets']
lr = config['lr']
class_problem = config["class_problem"]
verbose = config['verbose']
save_res = config['save_res']
patience = config['patience']
a_prior = config['a_prior']
SAMPLES = 1



#---------DATA------------
trainset = torchvision.datasets.MNIST(root='./mnist', train=True, download=True, transform=transforms.ToTensor())
testset = torchvision.datasets.MNIST(root='./mnist', train=False, download=True, transform=transforms.ToTensor())

train_data = trainset.data/255.
train_target = trainset.targets

test_data = (testset.data/255.)
test_target = testset.targets

p = train_data.shape[-1]

X_original = torch.cat((train_data, test_data), 0).detach().numpy().reshape(-1,p*p)
y_original = torch.cat((train_target, test_target), 0).detach().numpy()

n,p = X_original.shape
print(n,p,dim)

n_classes = len(np.unique(y_original))
multiclass = n_classes > 1

BATCH_SIZE = int((n*0.8)/5)
TEST_BATCH_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_BATCH_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

TRAIN_SIZE = int((n*0.80)/5)
TEST_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

NUM_BATCHES = TRAIN_SIZE/BATCH_SIZE

assert (TRAIN_SIZE % BATCH_SIZE) == 0
assert (TEST_SIZE % TEST_BATCH_SIZE) == 0
# Out:
# 70000 784 50

# %% [markdown]
# # Sigmoid based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni], test_dat, DEVICE, SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 47540
# 0
# loss 717997.125
# nll 28065.130859375
# density 0.9991780189892099
#
# val_loss: 701802.2500, val_nll: 13452.3037, val_ensemble: 0.6423, used_weights_median: 47540
#
# 1
# loss 692151.0625
# nll 14292.0234375
# density 0.9989725158790805
#
# val_loss: 684479.3125, val_nll: 8027.9385, val_ensemble: 0.7833, used_weights_median: 47540
#
# 2
# loss 676577.0
# nll 10843.7509765625
# density 0.9986968975045574
#
# val_loss: 670606.8125, val_nll: 6052.8901, val_ensemble: 0.8401, used_weights_median: 47540
#
# 3
# loss 662271.5
# nll 8736.39453125
# density 0.9983223745639354
#
# val_loss: 657786.0625, val_nll: 5128.2017, val_ensemble: 0.8644, used_weights_median: 47540
#
# 4
# loss 648730.25
# nll 7494.85107421875
# density 0.9978047134121978
#
# val_loss: 645306.6875, val_nll: 4542.9609, val_ensemble: 0.8804, used_weights_median: 47540
#
# 5
# loss 635494.375
# nll 6703.13623046875
# density 0.9970770761301702
#
# val_loss: 632948.3125, val_nll: 4075.7625, val_ensemble: 0.8937, used_weights_median: 47540
#
# 6
# loss 622275.125
# nll 6135.94873046875
# density 0.9960371409638067
#
# val_loss: 620760.4375, val_nll: 3774.8633, val_ensemble: 0.8983, used_weights_median: 47540
#
# 7
# loss 608628.375
# nll 5442.1328125
# density 0.9945291005216028
#
# val_loss: 608596.1250, val_nll: 3491.0071, val_ensemble: 0.9064, used_weights_median: 47540
#
# 8
# loss 594814.3125
# nll 5016.66162109375
# density 0.992317095183253
#
# val_loss: 596528.7500, val_nll: 3294.4268, val_ensemble: 0.9073, used_weights_median: 47540
#
# 9
# loss 580479.125
# nll 4698.49755859375
# density 0.9890487537370994
#
# val_loss: 584482.5625, val_nll: 3104.5906, val_ensemble: 0.9109, used_weights_median: 47540
#
# 10
# loss 565209.125
# nll 4338.65625
# density 0.9842140602310716
#
# val_loss: 572466.7500, val_nll: 2923.2969, val_ensemble: 0.9139, used_weights_median: 47540
#
# 11
# loss 548767.0
# nll 4044.09033203125
# density 0.9771096678105131
#
# val_loss: 560535.4375, val_nll: 2793.6895, val_ensemble: 0.9159, used_weights_median: 47540
#
# 12
# loss 530776.375
# nll 3846.066650390625
# density 0.9668425721509345
#
# val_loss: 548656.1875, val_nll: 2666.7480, val_ensemble: 0.9180, used_weights_median: 47540
#
# 13
# loss 510743.90625
# nll 3659.416748046875
# density 0.9524195946549286
#
# val_loss: 536860.4375, val_nll: 2549.7485, val_ensemble: 0.9210, used_weights_median: 47540
#
# 14
# loss 488405.09375
# nll 3522.756103515625
# density 0.9329403309829355
#
# val_loss: 522341.0312, val_nll: 2462.9927, val_ensemble: 0.9230, used_weights_median: 47282
#
# 15
# loss 463599.125
# nll 3354.311767578125
# density 0.9078445654207284
#
# val_loss: 490866.8438, val_nll: 2387.2737, val_ensemble: 0.9253, used_weights_median: 45440
#
# 16
# loss 436678.0
# nll 3307.416259765625
# density 0.8770684394024729
#
# val_loss: 456541.7812, val_nll: 2322.7886, val_ensemble: 0.9246, used_weights_median: 43238
#
# 17
# loss 407884.3125
# nll 3200.997314453125
# density 0.8410032828132746
#
# val_loss: 422748.1250, val_nll: 2284.5996, val_ensemble: 0.9244, used_weights_median: 40975
#
# 18
# loss 377941.0
# nll 3233.730712890625
# density 0.8003036483341799
#
# val_loss: 387937.8750, val_nll: 2228.4736, val_ensemble: 0.9236, used_weights_median: 38499
#
# 19
# loss 347139.71875
# nll 3185.64404296875
# density 0.7556820732439121
#
# val_loss: 353545.6875, val_nll: 2193.3806, val_ensemble: 0.9229, used_weights_median: 35935
#
# 20
# loss 316072.6875
# nll 3210.881103515625
# density 0.7077835259050895
#
# val_loss: 319939.7188, val_nll: 2165.5115, val_ensemble: 0.9209, used_weights_median: 33316
#
# 21
# loss 285019.5625
# nll 3241.24267578125
# density 0.6571259323208207
#
# val_loss: 287278.8750, val_nll: 2180.4304, val_ensemble: 0.9201, used_weights_median: 30650
#
# 22
# loss 254335.375
# nll 3358.36376953125
# density 0.6041162117535219
#
# val_loss: 255547.4375, val_nll: 2187.8147, val_ensemble: 0.9199, used_weights_median: 27939
#
# 23
# loss 224068.90625
# nll 3375.0908203125
# density 0.5491092060825431
#
# val_loss: 223513.3750, val_nll: 2161.0352, val_ensemble: 0.9199, used_weights_median: 25040
#
# 24
# loss 194718.109375
# nll 3560.8564453125
# density 0.49246946845531187
#
# val_loss: 193155.0469, val_nll: 2186.7031, val_ensemble: 0.9176, used_weights_median: 22161
#
# 25
# loss 166498.234375
# nll 3868.8212890625
# density 0.4346721593517031
#
# val_loss: 163909.6406, val_nll: 2255.2322, val_ensemble: 0.9156, used_weights_median: 19235
#
# 26
# loss 139532.140625
# nll 4085.70458984375
# density 0.37642116031233736
#
# val_loss: 135078.5781, val_nll: 2315.2795, val_ensemble: 0.9134, used_weights_median: 16181
#
# 27
# loss 114623.578125
# nll 4548.59423828125
# density 0.3188275482733591
#
# val_loss: 107708.6172, val_nll: 2407.7761, val_ensemble: 0.9069, used_weights_median: 13118
#
# 28
# loss 91876.5859375
# nll 4738.64404296875
# density 0.26357056363903025
#
# val_loss: 81602.6953, val_nll: 2547.5698, val_ensemble: 0.9007, used_weights_median: 10020
#
# 29
# loss 72842.0625
# nll 5438.2265625
# density 0.21307494877071617
#
# val_loss: 56671.0117, val_nll: 2879.8174, val_ensemble: 0.8899, used_weights_median: 6862
#
# 30
# loss 57284.5
# nll 5599.67138671875
# density 0.17029472006932309
#
# val_loss: 33251.0703, val_nll: 3390.2927, val_ensemble: 0.8686, used_weights_median: 3675
#
# 31
# loss 46068.9921875
# nll 5781.78955078125
# density 0.1372200521147196
#
# val_loss: 21995.3105, val_nll: 3285.9851, val_ensemble: 0.8664, used_weights_median: 2146
#
# 32
# loss 38572.15625
# nll 5885.7060546875
# density 0.11363214063718696
#
# val_loss: 19977.5508, val_nll: 3321.0115, val_ensemble: 0.8690, used_weights_median: 1859
#
# 33
# loss 33766.109375
# nll 5942.3525390625
# density 0.09752695114262869
#
# val_loss: 18768.5859, val_nll: 3378.4402, val_ensemble: 0.8689, used_weights_median: 1669
#
# 34
# loss 30518.08984375
# nll 5843.2607421875
# density 0.08646397241448053
#
# val_loss: 17764.4297, val_nll: 3140.5752, val_ensemble: 0.8749, used_weights_median: 1551
#
# 35
# loss 28081.26171875
# nll 5572.140625
# density 0.07854744328607499
#
# val_loss: 16953.2988, val_nll: 3002.4524, val_ensemble: 0.8854, used_weights_median: 1457
#
# 36
# loss 26191.12109375
# nll 5273.07373046875
# density 0.07259713620853289
#
# val_loss: 16510.3711, val_nll: 2995.9287, val_ensemble: 0.8850, used_weights_median: 1401
#
# 37
# loss 24775.21875
# nll 5113.60546875
# density 0.06787978476579476
#
# val_loss: 15862.2441, val_nll: 2907.3499, val_ensemble: 0.8891, used_weights_median: 1329
#
# 38
# loss 23688.443359375
# nll 5064.69775390625
# density 0.06400157711215922
#
# val_loss: 15336.9570, val_nll: 2794.2593, val_ensemble: 0.8920, used_weights_median: 1274
#
# 39
# loss 22746.083984375
# nll 5003.79736328125
# density 0.06072044957720674
#
# val_loss: 14766.8330, val_nll: 2641.0637, val_ensemble: 0.8997, used_weights_median: 1215
#
# 40
# loss 14481.1611328125
# nll 4737.92578125
# density 0.06072044957720674
#
# val_loss: 12285.6309, val_nll: 2544.2461, val_ensemble: 0.9016, used_weights_median: 1215
#
# 41
# loss 14302.84375
# nll 4567.34912109375
# density 0.06072044957720674
#
# val_loss: 12206.1250, val_nll: 2471.3938, val_ensemble: 0.9041, used_weights_median: 1215
#
# 42
# loss 14186.1181640625
# nll 4456.8466796875
# density 0.06072044957720674
#
# val_loss: 12152.6250, val_nll: 2424.7866, val_ensemble: 0.9054, used_weights_median: 1215
#
# 43
# loss 14066.880859375
# nll 4344.71337890625
# density 0.06072044957720674
#
# val_loss: 12098.9785, val_nll: 2378.3086, val_ensemble: 0.9080, used_weights_median: 1215
#
# 44
# loss 13978.009765625
# nll 4262.65185546875
# density 0.06072044957720674
#
# val_loss: 12053.8525, val_nll: 2339.7566, val_ensemble: 0.9104, used_weights_median: 1215
#
# 45
# loss 13999.19140625
# nll 4292.39599609375
# density 0.06072044957720674
#
# val_loss: 12006.4385, val_nll: 2300.9607, val_ensemble: 0.9119, used_weights_median: 1215
#
# 46
# loss 13946.744140625
# nll 4248.013671875
# density 0.06072044957720674
#
# val_loss: 11975.2939, val_nll: 2277.6035, val_ensemble: 0.9133, used_weights_median: 1215
#
# 47
# loss 13807.111328125
# nll 4116.013671875
# density 0.06072044957720674
#
# val_loss: 11942.7500, val_nll: 2253.5857, val_ensemble: 0.9143, used_weights_median: 1215
#
# 48
# loss 13806.595703125
# nll 4125.39990234375
# density 0.06072044957720674
#
# val_loss: 11918.7607, val_nll: 2239.3167, val_ensemble: 0.9139, used_weights_median: 1215
#
# 49
# loss 13771.4306640625
# nll 4097.7880859375
# density 0.06072044957720674
#
# val_loss: 11888.8096, val_nll: 2216.3015, val_ensemble: 0.9154, used_weights_median: 1215
#
# 50
# loss 13730.546875
# nll 4063.419677734375
# density 0.06072044957720674
#
# val_loss: 11866.0283, val_nll: 2200.4739, val_ensemble: 0.9170, used_weights_median: 1215
#
# 51
# loss 13635.625
# nll 3973.788330078125
# density 0.06072044957720674
#
# val_loss: 11841.4805, val_nll: 2180.9543, val_ensemble: 0.9171, used_weights_median: 1215
#
# 52
# loss 13639.220703125
# nll 3984.69580078125
# density 0.06072044957720674
#
# val_loss: 11822.2285, val_nll: 2168.9983, val_ensemble: 0.9177, used_weights_median: 1215
#
# 53
# loss 13587.8974609375
# nll 3939.2685546875
# density 0.06072044957720674
#
# val_loss: 11806.0684, val_nll: 2159.0730, val_ensemble: 0.9183, used_weights_median: 1215
#
# 54
# loss 13571.92578125
# nll 3928.828125
# density 0.06072044957720674
#
# val_loss: 11789.2656, val_nll: 2146.8416, val_ensemble: 0.9199, used_weights_median: 1215
#
# 55
# loss 13513.375
# nll 3876.2578125
# density 0.06072044957720674
#
# val_loss: 11770.1143, val_nll: 2134.6536, val_ensemble: 0.9187, used_weights_median: 1215
#
# 56
# loss 13527.1376953125
# nll 3899.322265625
# density 0.06072044957720674
#
# val_loss: 11752.8242, val_nll: 2126.5784, val_ensemble: 0.9189, used_weights_median: 1215
#
# 57
# loss 13501.2451171875
# nll 3879.6494140625
# density 0.06072044957720674
#
# val_loss: 11735.5586, val_nll: 2114.6128, val_ensemble: 0.9197, used_weights_median: 1215
#
# 58
# loss 13458.7470703125
# nll 3843.082275390625
# density 0.06072044957720674
#
# val_loss: 11721.3730, val_nll: 2107.3040, val_ensemble: 0.9199, used_weights_median: 1215
#
# 59
# loss 13487.6318359375
# nll 3877.920654296875
# density 0.06072044957720674
#
# val_loss: 11715.8818, val_nll: 2106.7219, val_ensemble: 0.9199, used_weights_median: 1215
#
# 60
# loss 13406.646484375
# nll 3799.60986328125
# density 0.06072044957720674
#
# val_loss: 11697.7383, val_nll: 2091.3984, val_ensemble: 0.9207, used_weights_median: 1215
#
# 61
# loss 13394.59375
# nll 3794.16455078125
# density 0.06072044957720674
#
# val_loss: 11689.4209, val_nll: 2090.8191, val_ensemble: 0.9206, used_weights_median: 1215
#
# 62
# loss 13367.150390625
# nll 3776.07373046875
# density 0.06072044957720674
#
# val_loss: 11666.4688, val_nll: 2077.5259, val_ensemble: 0.9207, used_weights_median: 1215
#
# 63
# loss 13387.3623046875
# nll 3806.1240234375
# density 0.06072044957720674
#
# val_loss: 11657.0635, val_nll: 2077.4924, val_ensemble: 0.9214, used_weights_median: 1215
#
# 64
# loss 13315.140625
# nll 3742.633544921875
# density 0.06072044957720674
#
# val_loss: 11637.9111, val_nll: 2067.3059, val_ensemble: 0.9214, used_weights_median: 1215
#
# 65
# loss 13325.783203125
# nll 3761.32177734375
# density 0.06072044957720674
#
# val_loss: 11625.8838, val_nll: 2062.8889, val_ensemble: 0.9219, used_weights_median: 1215
#
# 66
# loss 13330.791015625
# nll 3773.468017578125
# density 0.06072044957720674
#
# val_loss: 11613.5605, val_nll: 2057.5508, val_ensemble: 0.9221, used_weights_median: 1215
#
# 67
# loss 13273.783203125
# nll 3724.56640625
# density 0.06072044957720674
#
# val_loss: 11600.4756, val_nll: 2052.8787, val_ensemble: 0.9227, used_weights_median: 1215
#
# 68
# loss 13308.84375
# nll 3766.801513671875
# density 0.06072044957720674
#
# val_loss: 11590.8584, val_nll: 2048.9941, val_ensemble: 0.9220, used_weights_median: 1215
#
# 69
# loss 13196.205078125
# nll 3654.08984375
# density 0.06072044957720674
#
# val_loss: 11586.5293, val_nll: 2044.7056, val_ensemble: 0.9220, used_weights_median: 1215
#
# 70
# loss 13252.689453125
# nll 3712.99365234375
# density 0.06072044957720674
#
# val_loss: 11582.9229, val_nll: 2044.3099, val_ensemble: 0.9224, used_weights_median: 1215
#
# 71
# loss 13160.6640625
# nll 3625.27001953125
# density 0.06072044957720674
#
# val_loss: 11572.2109, val_nll: 2038.3466, val_ensemble: 0.9221, used_weights_median: 1215
#
# 72
# loss 13247.8701171875
# nll 3719.629638671875
# density 0.06072044957720674
#
# val_loss: 11561.9434, val_nll: 2035.0023, val_ensemble: 0.9236, used_weights_median: 1215
#
# 73
# loss 13150.384765625
# nll 3631.630615234375
# density 0.06072044957720674
#
# val_loss: 11546.2627, val_nll: 2030.1156, val_ensemble: 0.9227, used_weights_median: 1215
#
# 74
# loss 13149.3359375
# nll 3642.249755859375
# density 0.06072044957720674
#
# val_loss: 11533.4395, val_nll: 2028.2915, val_ensemble: 0.9233, used_weights_median: 1215
#
# 75
# loss 13196.607421875
# nll 3699.747802734375
# density 0.06072044957720674
#
# val_loss: 11519.9570, val_nll: 2024.6847, val_ensemble: 0.9227, used_weights_median: 1215
#
# 76
# loss 13144.48828125
# nll 3655.75048828125
# density 0.06072044957720674
#
# val_loss: 11505.0830, val_nll: 2018.0551, val_ensemble: 0.9224, used_weights_median: 1215
#
# 77
# loss 13128.7861328125
# nll 3651.381591796875
# density 0.06072044957720674
#
# val_loss: 11487.8799, val_nll: 2012.6428, val_ensemble: 0.9223, used_weights_median: 1215
#
# 78
# loss 13073.1689453125
# nll 3602.9130859375
# density 0.06072044957720674
#
# val_loss: 11480.6650, val_nll: 2011.5089, val_ensemble: 0.9210, used_weights_median: 1215
#
# 79
# loss 13056.4501953125
# nll 3589.84765625
# density 0.06072044957720674
#
# val_loss: 11471.4814, val_nll: 2005.7556, val_ensemble: 0.9236, used_weights_median: 1215
#
# 0.025557425 density median
# 1215.0 used weights median
# 0.8764428571428571 ensemble full
# 0.9063714285714285 ensemble median
# [0.8764428571428571, 0.025557425]

# %% [markdown]
# ## Weights used each class

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")

# %% [markdown]
# # ReLU based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    #---------------------------
    # DIFFERENCE IS IN act_func=F.relu part
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, a_prior=a_prior, n_classes=n_classes, act_func=F.relu).to(DEVICE)
    #---------------------------
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni], test_dat, DEVICE, SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 47540
# 0
# loss 808299.375
# nll 118336.5078125
# density 0.9992186480013322
#
# val_loss: 756200.4375, val_nll: 67850.7734, val_ensemble: 0.5321, used_weights_median: 47540
#
# 1
# loss 722184.625
# nll 44248.8515625
# density 0.9990652337914813
#
# val_loss: 698150.3125, val_nll: 21699.4492, val_ensemble: 0.6887, used_weights_median: 47540
#
# 2
# loss 689886.0
# nll 24016.748046875
# density 0.998859554796245
#
# val_loss: 679314.5625, val_nll: 14761.4785, val_ensemble: 0.7173, used_weights_median: 47540
#
# 3
# loss 669493.125
# nll 15743.48046875
# density 0.9985811739896695
#
# val_loss: 662778.5000, val_nll: 10122.0879, val_ensemble: 0.7899, used_weights_median: 47540
#
# 4
# loss 653730.5
# nll 12174.3974609375
# density 0.9981986624218107
#
# val_loss: 648802.6250, val_nll: 8041.1167, val_ensemble: 0.8214, used_weights_median: 47540
#
# 5
# loss 639451.125
# nll 10193.173828125
# density 0.9976638822255638
#
# val_loss: 635530.0625, val_nll: 6661.1953, val_ensemble: 0.8426, used_weights_median: 47540
#
# 6
# loss 625183.0625
# nll 8373.9794921875
# density 0.9969025694865061
#
# val_loss: 622665.0000, val_nll: 5685.3462, val_ensemble: 0.8580, used_weights_median: 47540
#
# 7
# loss 611909.25
# nll 7766.71826171875
# density 0.9958025919724073
#
# val_loss: 610354.0625, val_nll: 5258.3457, val_ensemble: 0.8660, used_weights_median: 47540
#
# 8
# loss 598070.75
# nll 6910.26416015625
# density 0.994193139594545
#
# val_loss: 597986.0625, val_nll: 4766.9448, val_ensemble: 0.8779, used_weights_median: 47540
#
# 9
# loss 584033.125
# nll 6309.625
# density 0.9918195900116641
#
# val_loss: 585767.7500, val_nll: 4413.9253, val_ensemble: 0.8834, used_weights_median: 47540
#
# 10
# loss 569446.1875
# nll 5808.05224609375
# density 0.9883108988573535
#
# val_loss: 573637.3125, val_nll: 4132.1196, val_ensemble: 0.8886, used_weights_median: 47540
#
# 11
# loss 554058.3125
# nll 5406.20361328125
# density 0.983154414505782
#
# val_loss: 561565.4375, val_nll: 3883.9612, val_ensemble: 0.8943, used_weights_median: 47540
#
# 12
# loss 537596.9375
# nll 5133.46484375
# density 0.9756927550578749
#
# val_loss: 549574.2500, val_nll: 3678.9717, val_ensemble: 0.8976, used_weights_median: 47540
#
# 13
# loss 519636.6875
# nll 4875.5146484375
# density 0.9651806690710956
#
# val_loss: 537649.5625, val_nll: 3485.4783, val_ensemble: 0.8997, used_weights_median: 47540
#
# 14
# loss 499960.96875
# nll 4662.57763671875
# density 0.950915092343937
#
# val_loss: 523804.0625, val_nll: 3330.2915, val_ensemble: 0.9019, used_weights_median: 47356
#
# 15
# loss 478446.90625
# nll 4472.9140625
# density 0.9324021805414744
#
# val_loss: 498201.7500, val_nll: 3202.5342, val_ensemble: 0.9053, used_weights_median: 46071
#
# 16
# loss 455198.375
# nll 4324.35498046875
# density 0.9094691792097872
#
# val_loss: 470749.8750, val_nll: 3094.0525, val_ensemble: 0.9071, used_weights_median: 44546
#
# 17
# loss 430408.15625
# nll 4168.08056640625
# density 0.8822432673803061
#
# val_loss: 442640.4688, val_nll: 3004.1062, val_ensemble: 0.9080, used_weights_median: 42878
#
# 18
# loss 404492.78125
# nll 4098.61181640625
# density 0.8510384817696641
#
# val_loss: 413882.5625, val_nll: 2921.5688, val_ensemble: 0.9087, used_weights_median: 41060
#
# 19
# loss 377663.96875
# nll 3992.55029296875
# density 0.8162407583689107
#
# val_loss: 385078.3125, val_nll: 2889.7576, val_ensemble: 0.9090, used_weights_median: 39135
#
# 20
# loss 350335.90625
# nll 3951.021484375
# density 0.778239184286215
#
# val_loss: 355108.7812, val_nll: 2778.7693, val_ensemble: 0.9104, used_weights_median: 36994
#
# 21
# loss 322650.4375
# nll 3838.09765625
# density 0.7373878436431847
#
# val_loss: 325867.6562, val_nll: 2757.4373, val_ensemble: 0.9091, used_weights_median: 34802
#
# 22
# loss 295159.84375
# nll 3976.683349609375
# density 0.6939712414131678
#
# val_loss: 297808.9062, val_nll: 2695.7209, val_ensemble: 0.9094, used_weights_median: 32620
#
# 23
# loss 267703.90625
# nll 4000.054443359375
# density 0.6482463580759561
#
# val_loss: 269155.9062, val_nll: 2689.4941, val_ensemble: 0.9113, used_weights_median: 30236
#
# 24
# loss 240531.5
# nll 3952.903076171875
# density 0.6004851334492826
#
# val_loss: 241008.8750, val_nll: 2685.2520, val_ensemble: 0.9109, used_weights_median: 27768
#
# 25
# loss 214165.328125
# nll 4126.12060546875
# density 0.5510499211906648
#
# val_loss: 213805.5625, val_nll: 2719.6875, val_ensemble: 0.9090, used_weights_median: 25255
#
# 26
# loss 188751.421875
# nll 4380.37158203125
# density 0.500463051192359
#
# val_loss: 186847.3906, val_nll: 2726.6167, val_ensemble: 0.9097, used_weights_median: 22616
#
# 27
# loss 164545.6875
# nll 4615.37890625
# density 0.44948384069309083
#
# val_loss: 160704.7812, val_nll: 2713.6003, val_ensemble: 0.9074, used_weights_median: 19914
#
# 28
# loss 142100.9375
# nll 4897.3212890625
# density 0.3993336898649678
#
# val_loss: 135716.3438, val_nll: 2878.2747, val_ensemble: 0.9001, used_weights_median: 17160
#
# 29
# loss 121896.703125
# nll 5074.48388671875
# density 0.35182516924350465
#
# val_loss: 111584.6250, val_nll: 2888.8162, val_ensemble: 0.8989, used_weights_median: 14362
#
# 30
# loss 104798.453125
# nll 5356.15869140625
# density 0.3092046740031137
#
# val_loss: 88117.4766, val_nll: 2974.9172, val_ensemble: 0.8947, used_weights_median: 11433
#
# 31
# loss 91042.859375
# nll 5580.60498046875
# density 0.27332826846372843
#
# val_loss: 72950.8984, val_nll: 3040.0806, val_ensemble: 0.8927, used_weights_median: 9570
#
# 32
# loss 80497.625
# nll 5799.77685546875
# density 0.24459860280264273
#
# val_loss: 65431.7695, val_nll: 3055.0664, val_ensemble: 0.8916, used_weights_median: 8688
#
# 33
# loss 72533.796875
# nll 6024.9228515625
# density 0.22197326879257231
#
# val_loss: 59760.6797, val_nll: 3036.6511, val_ensemble: 0.8924, used_weights_median: 8016
#
# 34
# loss 66013.9296875
# nll 5846.85107421875
# density 0.20388106850446444
#
# val_loss: 55102.1875, val_nll: 2968.2920, val_ensemble: 0.8957, used_weights_median: 7454
#
# 35
# loss 60960.44140625
# nll 5843.83837890625
# density 0.18902454891237777
#
# val_loss: 51258.3125, val_nll: 2995.9558, val_ensemble: 0.8950, used_weights_median: 6958
#
# 36
# loss 56948.1953125
# nll 5968.46728515625
# density 0.17645733822082266
#
# val_loss: 47686.8945, val_nll: 2846.2102, val_ensemble: 0.8954, used_weights_median: 6503
#
# 37
# loss 53112.94140625
# nll 5594.390625
# density 0.16559820777157122
#
# val_loss: 44888.6016, val_nll: 2810.4229, val_ensemble: 0.8956, used_weights_median: 6119
#
# 38
# loss 50302.42578125
# nll 5721.08056640625
# density 0.15607960710382707
#
# val_loss: 42299.3359, val_nll: 2708.4902, val_ensemble: 0.8993, used_weights_median: 5764
#
# 39
# loss 47616.8671875
# nll 5554.06689453125
# density 0.1476548673541175
#
# val_loss: 40085.3594, val_nll: 2623.7454, val_ensemble: 0.9017, used_weights_median: 5450
#
# 40
# loss 40234.92578125
# nll 5043.40283203125
# density 0.1476548673541175
#
# val_loss: 37747.1602, val_nll: 2580.9038, val_ensemble: 0.9019, used_weights_median: 5450
#
# 41
# loss 40056.28515625
# nll 4988.7197265625
# density 0.1476548673541175
#
# val_loss: 37593.9648, val_nll: 2551.6445, val_ensemble: 0.9041, used_weights_median: 5450
#
# 42
# loss 39798.09375
# nll 4860.90234375
# density 0.1476548673541175
#
# val_loss: 37401.3438, val_nll: 2491.7727, val_ensemble: 0.9059, used_weights_median: 5450
#
# 43
# loss 39478.6875
# nll 4679.064453125
# density 0.1476548673541175
#
# val_loss: 37232.6211, val_nll: 2459.1672, val_ensemble: 0.9077, used_weights_median: 5450
#
# 44
# loss 39477.34765625
# nll 4807.7001953125
# density 0.1476548673541175
#
# val_loss: 37068.1250, val_nll: 2421.9917, val_ensemble: 0.9093, used_weights_median: 5450
#
# 45
# loss 39285.57421875
# nll 4729.56201171875
# density 0.1476548673541175
#
# val_loss: 36935.7422, val_nll: 2401.3560, val_ensemble: 0.9099, used_weights_median: 5450
#
# 46
# loss 39179.46484375
# nll 4730.71435546875
# density 0.1476548673541175
#
# val_loss: 36805.0195, val_nll: 2376.3040, val_ensemble: 0.9114, used_weights_median: 5450
#
# 47
# loss 38921.1484375
# nll 4566.43896484375
# density 0.1476548673541175
#
# val_loss: 36690.9492, val_nll: 2354.3394, val_ensemble: 0.9110, used_weights_median: 5450
#
# 48
# loss 38927.34765625
# nll 4660.1064453125
# density 0.1476548673541175
#
# val_loss: 36585.0117, val_nll: 2334.2039, val_ensemble: 0.9124, used_weights_median: 5450
#
# 49
# loss 38789.41015625
# nll 4610.90966796875
# density 0.1476548673541175
#
# val_loss: 36482.4453, val_nll: 2321.0017, val_ensemble: 0.9131, used_weights_median: 5450
#
# 50
# loss 38587.78515625
# nll 4493.04296875
# density 0.1476548673541175
#
# val_loss: 36383.0234, val_nll: 2303.9841, val_ensemble: 0.9134, used_weights_median: 5450
#
# 51
# loss 38507.69921875
# nll 4481.47314453125
# density 0.1476548673541175
#
# val_loss: 36305.3477, val_nll: 2290.3833, val_ensemble: 0.9137, used_weights_median: 5450
#
# 52
# loss 38287.7265625
# nll 4321.75048828125
# density 0.1476548673541175
#
# val_loss: 36231.4844, val_nll: 2278.0623, val_ensemble: 0.9141, used_weights_median: 5450
#
# 53
# loss 38084.93359375
# nll 4186.99755859375
# density 0.1476548673541175
#
# val_loss: 36137.6953, val_nll: 2255.3015, val_ensemble: 0.9150, used_weights_median: 5450
#
# 54
# loss 38227.00390625
# nll 4399.33203125
# density 0.1476548673541175
#
# val_loss: 36056.1992, val_nll: 2242.3767, val_ensemble: 0.9161, used_weights_median: 5450
#
# 55
# loss 38240.765625
# nll 4475.1982421875
# density 0.1476548673541175
#
# val_loss: 35992.1172, val_nll: 2236.2324, val_ensemble: 0.9156, used_weights_median: 5450
#
# 56
# loss 38015.91015625
# nll 4308.84912109375
# density 0.1476548673541175
#
# val_loss: 35919.8242, val_nll: 2223.6335, val_ensemble: 0.9163, used_weights_median: 5450
#
# 57
# loss 37798.5859375
# nll 4143.626953125
# density 0.1476548673541175
#
# val_loss: 35860.3750, val_nll: 2216.4146, val_ensemble: 0.9169, used_weights_median: 5450
#
# 58
# loss 37776.078125
# nll 4172.6240234375
# density 0.1476548673541175
#
# val_loss: 35789.9727, val_nll: 2196.5039, val_ensemble: 0.9167, used_weights_median: 5450
#
# 59
# loss 37704.2421875
# nll 4156.279296875
# density 0.1476548673541175
#
# val_loss: 35734.0039, val_nll: 2199.6570, val_ensemble: 0.9164, used_weights_median: 5450
#
# 60
# loss 37804.59375
# nll 4328.02685546875
# density 0.1476548673541175
#
# val_loss: 35645.3438, val_nll: 2180.7573, val_ensemble: 0.9163, used_weights_median: 5450
#
# 61
# loss 37638.0390625
# nll 4228.80126953125
# density 0.1476548673541175
#
# val_loss: 35571.4570, val_nll: 2175.4985, val_ensemble: 0.9163, used_weights_median: 5450
#
# 62
# loss 37546.734375
# nll 4199.814453125
# density 0.1476548673541175
#
# val_loss: 35497.4844, val_nll: 2159.7529, val_ensemble: 0.9161, used_weights_median: 5450
#
# 63
# loss 37578.9140625
# nll 4272.8037109375
# density 0.1476548673541175
#
# val_loss: 35449.4883, val_nll: 2148.5356, val_ensemble: 0.9163, used_weights_median: 5450
#
# 64
# loss 37356.375
# nll 4082.64599609375
# density 0.1476548673541175
#
# val_loss: 35406.8086, val_nll: 2141.6099, val_ensemble: 0.9161, used_weights_median: 5450
#
# 65
# loss 37420.23046875
# nll 4184.12890625
# density 0.1476548673541175
#
# val_loss: 35352.9453, val_nll: 2124.4705, val_ensemble: 0.9173, used_weights_median: 5450
#
# 66
# loss 37209.8203125
# nll 4012.9130859375
# density 0.1476548673541175
#
# val_loss: 35305.3203, val_nll: 2117.9143, val_ensemble: 0.9171, used_weights_median: 5450
#
# 67
# loss 37064.59765625
# nll 3918.62255859375
# density 0.1476548673541175
#
# val_loss: 35253.9570, val_nll: 2121.1362, val_ensemble: 0.9171, used_weights_median: 5450
#
# 68
# loss 37216.875
# nll 4133.0390625
# density 0.1476548673541175
#
# val_loss: 35185.9062, val_nll: 2113.8225, val_ensemble: 0.9183, used_weights_median: 5450
#
# 69
# loss 37040.09765625
# nll 4012.5078125
# density 0.1476548673541175
#
# val_loss: 35122.3164, val_nll: 2105.4666, val_ensemble: 0.9190, used_weights_median: 5450
#
# 70
# loss 36993.69921875
# nll 4015.803466796875
# density 0.1476548673541175
#
# val_loss: 35070.1094, val_nll: 2100.8296, val_ensemble: 0.9187, used_weights_median: 5450
#
# 71
# loss 36970.03515625
# nll 4037.631103515625
# density 0.1476548673541175
#
# val_loss: 35006.5312, val_nll: 2083.9045, val_ensemble: 0.9194, used_weights_median: 5450
#
# 72
# loss 37006.57421875
# nll 4122.50048828125
# density 0.1476548673541175
#
# val_loss: 34961.8242, val_nll: 2086.3311, val_ensemble: 0.9186, used_weights_median: 5450
#
# 73
# loss 36954.9375
# nll 4115.69189453125
# density 0.1476548673541175
#
# val_loss: 34922.0820, val_nll: 2090.6721, val_ensemble: 0.9177, used_weights_median: 5450
#
# 74
# loss 36721.2578125
# nll 3931.701416015625
# density 0.1476548673541175
#
# val_loss: 34851.2383, val_nll: 2072.0740, val_ensemble: 0.9201, used_weights_median: 5450
#
# 75
# loss 36627.19140625
# nll 3877.50830078125
# density 0.1476548673541175
#
# val_loss: 34813.5859, val_nll: 2072.3711, val_ensemble: 0.9191, used_weights_median: 5450
#
# 76
# loss 36661.75
# nll 3954.89892578125
# density 0.1476548673541175
#
# val_loss: 34764.6914, val_nll: 2065.8772, val_ensemble: 0.9209, used_weights_median: 5450
#
# 77
# loss 36628.8203125
# nll 3961.9248046875
# density 0.1476548673541175
#
# val_loss: 34715.5430, val_nll: 2056.0154, val_ensemble: 0.9200, used_weights_median: 5450
#
# 78
# loss 36551.06640625
# nll 3912.94189453125
# density 0.1476548673541175
#
# val_loss: 34680.9844, val_nll: 2050.5410, val_ensemble: 0.9203, used_weights_median: 5450
#
# 79
# loss 36558.51171875
# nll 3959.358154296875
# density 0.1476548673541175
#
# val_loss: 34640.2266, val_nll: 2048.2786, val_ensemble: 0.9206, used_weights_median: 5450
#
# 0.11464031 density median
# 5450.0 used weights median
# 0.8777142857142858 ensemble full
# 0.9001428571428571 ensemble median
# [0.8777142857142858, 0.11464031]

# %% [markdown]
# ## Weights used each class

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")

# %% [markdown]
# ## Local explaination

# %%
p = p**0.5  # Just for ease of use

# %%
import matplotlib.pyplot as plt
explain_this = train_data[96].reshape(-1,p*p)
plt.imshow(explain_this.reshape((p,p)))
plt.show()

# %%
pf.plot_local_contribution_images_contribution_empirical(net, explain_this, n_classes=n_classes)

# %%
pf.plot_local_contribution_images_contribution_dist(net, explain_this, n_classes=n_classes)
# Out:
# c:\Users\eirik\miniconda3\envs\master\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# c:\Users\eirik\miniconda3\envs\master\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
