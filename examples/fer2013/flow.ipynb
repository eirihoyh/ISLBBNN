# %% [markdown]
# ## Imports

# %%
import copy
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from config import config
import os
import sys
current_dir = os.getcwd()
path = "C:\\Users\\eirik\\Documents\\Master\\ISLBBNN\\islbbnn"
# path = "C:\\you\\path\\to\\islbbnn\\folder\\here"
os.chdir(path)
import plot_functions as pf
import pipeline_functions as pip_func
sys.path.append('networks')
from flow_net import BayesianNetwork
import torch.nn.functional as F

os.chdir(current_dir) # set the working directory back to this one
# Out:
# CPUs are used!

# %% [markdown]
# # Problem description
#
# The FER 2013 dataset. We will only train on the expressions Happy, Surprised, and Neutral.
#
# Attained from the following kaggle competition: https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/overview
#
# # Batch size and parameters

# %%
# define parameters
HIDDEN_LAYERS = config['n_layers'] - 2 
epochs = config['num_epochs']
post_train_epochs = config['post_train_epochs']
dim = config['hidden_dim']
num_transforms = config['num_transforms']
n_nets = config['n_nets']
lr = config['lr']
class_problem = config["class_problem"]
verbose = config['verbose']
save_res = config['save_res']
patience = config['patience']
a_prior = config['a_prior']
SAMPLES = 1



#---------DATA------------
df = pd.read_csv("../../../fer2013/icml_face_data.csv")

data = np.zeros((len(df), 48*48))
for i in range(len(data)):
    data[i] = np.array(df[" pixels"][i].split(" ")).astype(np.float32)/255.
targets = df.emotion.values

X_original,y_original  = data, targets
used_inds = [yi in [3,5,6] for yi in y_original]  # Happy, sad and neutral
y_original = y_original[used_inds]
y_original = np.where(y_original == 3, 0, y_original)
y_original = np.where(y_original == 5, 1, y_original)
y_original = np.where(y_original == 6, 2, y_original)
X_original = X_original[used_inds]
n,p = X_original.shape
print(n,p,dim)

n_classes = len(np.unique(y_original))
multiclass = n_classes > 1

BATCH_SIZE = int(n*0.8)
TEST_BATCH_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_BATCH_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

TRAIN_SIZE = int(n*0.80)
TEST_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

NUM_BATCHES = TRAIN_SIZE/BATCH_SIZE

assert (TRAIN_SIZE % BATCH_SIZE) == 0
assert (TEST_SIZE % TEST_BATCH_SIZE) == 0
# Out:
# 19189 2304 50

# %% [markdown]
# # Sigmoid based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 122262
# 0
# loss 1785025.625
# nll 16901.2421875
# density 0.9832801789099448
#
# val_loss: 1861750.1250, val_nll: 5303.1196, val_ensemble: 0.4565, used_weights_median: 122262
#
# 1
# loss 1897963.25
# nll 41469.21875
# density 0.9825118095503182
#
# val_loss: 2162772.5000, val_nll: 397695.4688, val_ensemble: 0.2199, used_weights_median: 122262
#
# 2
# loss 4919154.5
# nll 3154058.0
# density 0.9817156564782579
#
# val_loss: 1946911.2500, val_nll: 202804.1250, val_ensemble: 0.3184, used_weights_median: 122262
#
# 3
# loss 3332992.25
# nll 1588847.375
# density 0.9808753772660113
#
# val_loss: 1853551.6250, val_nll: 114732.0469, val_ensemble: 0.3184, used_weights_median: 122262
#
# 4
# loss 2629943.75
# nll 891059.75
# density 0.9799960525511556
#
# val_loss: 1772028.5000, val_nll: 42443.9688, val_ensemble: 0.3184, used_weights_median: 122262
#
# 5
# loss 2053847.0
# nll 324375.34375
# density 0.9790781173195763
#
# val_loss: 1748179.8750, val_nll: 30433.4980, val_ensemble: 0.4617, used_weights_median: 122262
#
# 6
# loss 1949172.75
# nll 231620.109375
# density 0.9781160424163248
#
# val_loss: 1726294.3750, val_nll: 19442.7402, val_ensemble: 0.4617, used_weights_median: 122262
#
# 7
# loss 1856490.25
# nll 149815.9375
# density 0.9771099770904335
#
# val_loss: 1724595.8750, val_nll: 27722.4512, val_ensemble: 0.2199, used_weights_median: 122262
#
# 8
# loss 1916200.75
# nll 219144.484375
# density 0.9760578132484411
#
# val_loss: 1714740.8750, val_nll: 25945.9199, val_ensemble: 0.2199, used_weights_median: 122262
#
# 9
# loss 1893512.25
# nll 205034.234375
# density 0.9749569853462781
#
# val_loss: 1702638.7500, val_nll: 21184.4238, val_ensemble: 0.3184, used_weights_median: 122262
#
# 10
# loss 1846804.0
# nll 165685.21875
# density 0.9738055283202777
#
# val_loss: 1680679.2500, val_nll: 9505.9951, val_ensemble: 0.3189, used_weights_median: 122262
#
# 11
# loss 1743628.125
# nll 72470.2109375
# density 0.9725998553219253
#
# val_loss: 1687404.5000, val_nll: 24841.0645, val_ensemble: 0.4617, used_weights_median: 122262
#
# 12
# loss 1854268.125
# nll 191708.59375
# density 0.9713356164533674
#
# val_loss: 1683882.2500, val_nll: 29913.9844, val_ensemble: 0.4617, used_weights_median: 122262
#
# 13
# loss 1884281.75
# nll 230306.65625
# density 0.9700101382813592
#
# val_loss: 1670186.2500, val_nll: 24945.7871, val_ensemble: 0.4617, used_weights_median: 122262
#
# 14
# loss 1838313.125
# nll 192980.046875
# density 0.9686207114110602
#
# val_loss: 1648749.1250, val_nll: 12375.5137, val_ensemble: 0.4617, used_weights_median: 122262
#
# 15
# loss 1733361.875
# nll 96866.140625
# density 0.967168804120324
#
# val_loss: 1640677.2500, val_nll: 13132.3760, val_ensemble: 0.2194, used_weights_median: 122262
#
# 16
# loss 1729521.125
# nll 101904.640625
# density 0.9656466581086424
#
# val_loss: 1632695.6250, val_nll: 14060.6172, val_ensemble: 0.2538, used_weights_median: 122262
#
# 17
# loss 1728272.625
# nll 109620.34375
# density 0.9640507054864991
#
# val_loss: 1629559.2500, val_nll: 20126.6504, val_ensemble: 0.3184, used_weights_median: 122262
#
# 18
# loss 1764815.25
# nll 155265.3125
# density 0.9623772562548573
#
# val_loss: 1617324.2500, val_nll: 17123.7656, val_ensemble: 0.3184, used_weights_median: 122262
#
# 19
# loss 1731241.875
# nll 131007.5234375
# density 0.9606233379198149
#
# val_loss: 1595333.8750, val_nll: 4467.1177, val_ensemble: 0.3231, used_weights_median: 122262
#
# 20
# loss 1624254.75
# nll 33383.08984375
# density 0.9587847800136726
#
# val_loss: 1592962.2500, val_nll: 11454.4395, val_ensemble: 0.4617, used_weights_median: 122262
#
# 21
# loss 1670409.625
# nll 89088.125
# density 0.9568574522907264
#
# val_loss: 1588124.1250, val_nll: 16376.8457, val_ensemble: 0.4617, used_weights_median: 122262
#
# 22
# loss 1700596.5
# nll 128871.953125
# density 0.954837340355091
#
# val_loss: 1577854.0000, val_nll: 15936.5293, val_ensemble: 0.4612, used_weights_median: 122262
#
# 23
# loss 1687782.5
# nll 125720.015625
# density 0.9527205049360762
#
# val_loss: 1566420.7500, val_nll: 14320.1396, val_ensemble: 0.3622, used_weights_median: 122262
#
# 24
# loss 1664993.5
# nll 112877.109375
# density 0.9505018129608659
#
# val_loss: 1558404.7500, val_nll: 16313.2100, val_ensemble: 0.2308, used_weights_median: 122262
#
# 25
# loss 1670548.75
# nll 128526.2109375
# density 0.9481770884425954
#
# val_loss: 1543870.7500, val_nll: 12077.8193, val_ensemble: 0.2840, used_weights_median: 122262
#
# 26
# loss 1626383.75
# nll 94481.25
# density 0.9457425707967794
#
# val_loss: 1530144.0000, val_nll: 8612.4834, val_ensemble: 0.4627, used_weights_median: 122262
#
# 27
# loss 1590217.25
# nll 68682.09375
# density 0.9431948054257256
#
# val_loss: 1517398.1250, val_nll: 6330.4155, val_ensemble: 0.4607, used_weights_median: 122262
#
# 28
# loss 1560231.375
# nll 49149.92578125
# density 0.9405296765405207
#
# val_loss: 1504586.6250, val_nll: 4215.9712, val_ensemble: 0.3382, used_weights_median: 122262
#
# 29
# loss 1532460.0
# nll 32036.11328125
# density 0.9377421179618406
#
# val_loss: 1498795.6250, val_nll: 9176.6348, val_ensemble: 0.3184, used_weights_median: 122262
#
# 30
# loss 1559108.25
# nll 69460.453125
# density 0.9348275846149204
#
# val_loss: 1486242.2500, val_nll: 7669.4067, val_ensemble: 0.3184, used_weights_median: 122262
#
# 31
# loss 1536240.5
# nll 57661.85546875
# density 0.9317821128332965
#
# val_loss: 1470284.3750, val_nll: 2960.5479, val_ensemble: 0.4784, used_weights_median: 122262
#
# 32
# loss 1490109.25
# nll 22654.255859375
# density 0.9286024667139452
#
# val_loss: 1460073.3750, val_nll: 4040.4788, val_ensemble: 0.4648, used_weights_median: 122262
#
# 33
# loss 1488148.25
# nll 32075.560546875
# density 0.9252853123865876
#
# val_loss: 1448993.5000, val_nll: 4437.1597, val_ensemble: 0.4497, used_weights_median: 122262
#
# 34
# loss 1479709.25
# nll 35227.87109375
# density 0.9218261246783124
#
# val_loss: 1438696.5000, val_nll: 5911.5117, val_ensemble: 0.2824, used_weights_median: 122262
#
# 35
# loss 1477863.75
# nll 45056.265625
# density 0.9182209120138443
#
# val_loss: 1425072.0000, val_nll: 4132.4688, val_ensemble: 0.3997, used_weights_median: 122262
#
# 36
# loss 1453337.375
# nll 32431.978515625
# density 0.9144663179392271
#
# val_loss: 1411758.2500, val_nll: 2880.8167, val_ensemble: 0.4784, used_weights_median: 122262
#
# 37
# loss 1431424.125
# nll 22618.125
# density 0.9105593913856551
#
# val_loss: 1399341.3750, val_nll: 2666.9417, val_ensemble: 0.4633, used_weights_median: 121862
#
# 38
# loss 1417177.25
# nll 20581.53515625
# density 0.9064960990911167
#
# val_loss: 1388720.8750, val_nll: 4679.7075, val_ensemble: 0.3220, used_weights_median: 120960
#
# 39
# loss 1418502.25
# nll 34368.0625
# density 0.9022729314256847
#
# val_loss: 1375403.8750, val_nll: 3921.6238, val_ensemble: 0.3335, used_weights_median: 120027
#
# 40
# loss 1549016.625
# nll 29385.46875
# density 0.9022729314256847
#
# val_loss: 1516665.3750, val_nll: 3050.3115, val_ensemble: 0.4789, used_weights_median: 120027
#
# 41
# loss 1536922.0
# nll 23170.896484375
# density 0.9022729314256847
#
# val_loss: 1510533.6250, val_nll: 2767.4143, val_ensemble: 0.4794, used_weights_median: 120027
#
# 42
# loss 1529686.0
# nll 21970.625
# density 0.9022729314256847
#
# val_loss: 1504599.2500, val_nll: 2977.2385, val_ensemble: 0.3747, used_weights_median: 120027
#
# 43
# loss 1525564.0
# nll 23922.095703125
# density 0.9022729314256847
#
# val_loss: 1498828.3750, val_nll: 3246.6880, val_ensemble: 0.3002, used_weights_median: 120027
#
# 44
# loss 1521468.875
# nll 25990.421875
# density 0.9022729314256847
#
# val_loss: 1491299.0000, val_nll: 1913.8196, val_ensemble: 0.5274, used_weights_median: 120027
#
# 45
# loss 1504370.125
# nll 14881.373046875
# density 0.9022729314256847
#
# val_loss: 1485773.3750, val_nll: 2396.4326, val_ensemble: 0.4893, used_weights_median: 120027
#
# 46
# loss 1501842.875
# nll 18432.404296875
# density 0.9022729314256847
#
# val_loss: 1480143.0000, val_nll: 2973.5847, val_ensemble: 0.4883, used_weights_median: 120027
#
# 47
# loss 1499446.25
# nll 22304.55859375
# density 0.9022729314256847
#
# val_loss: 1474001.5000, val_nll: 2926.8347, val_ensemble: 0.4867, used_weights_median: 120027
#
# 48
# loss 1493851.875
# nll 22738.59765625
# density 0.9022729314256847
#
# val_loss: 1467423.0000, val_nll: 2437.8091, val_ensemble: 0.4909, used_weights_median: 120027
#
# 49
# loss 1483507.625
# nll 18624.25390625
# density 0.9022729314256847
#
# val_loss: 1460674.2500, val_nll: 1859.4612, val_ensemble: 0.5409, used_weights_median: 120027
#
# 50
# loss 1473149.875
# nll 14382.837890625
# density 0.9022729314256847
#
# val_loss: 1454819.7500, val_nll: 2277.8032, val_ensemble: 0.4310, used_weights_median: 120027
#
# 51
# loss 1470628.875
# nll 18008.208984375
# density 0.9022729314256847
#
# val_loss: 1448807.1250, val_nll: 2400.6750, val_ensemble: 0.4200, used_weights_median: 120027
#
# 52
# loss 1465441.5
# nll 18993.76953125
# density 0.9022729314256847
#
# val_loss: 1442272.5000, val_nll: 2011.5955, val_ensemble: 0.5352, used_weights_median: 120027
#
# 53
# loss 1455929.5
# nll 15666.6435546875
# density 0.9022729314256847
#
# val_loss: 1436047.7500, val_nll: 2023.1641, val_ensemble: 0.5237, used_weights_median: 120027
#
# 54
# loss 1449726.875
# nll 15633.8056640625
# density 0.9022729314256847
#
# val_loss: 1430121.2500, val_nll: 2250.5325, val_ensemble: 0.4466, used_weights_median: 120027
#
# 55
# loss 1444789.625
# nll 16923.994140625
# density 0.9022729314256847
#
# val_loss: 1423958.6250, val_nll: 2209.9717, val_ensemble: 0.4231, used_weights_median: 120027
#
# 56
# loss 1438329.75
# nll 16621.03125
# density 0.9022729314256847
#
# val_loss: 1417284.2500, val_nll: 1816.8988, val_ensemble: 0.5597, used_weights_median: 120027
#
# 57
# loss 1429495.75
# nll 14026.3642578125
# density 0.9022729314256847
#
# val_loss: 1411180.1250, val_nll: 1980.4366, val_ensemble: 0.5352, used_weights_median: 120027
#
# 58
# loss 1424694.625
# nll 15469.5634765625
# density 0.9022729314256847
#
# val_loss: 1405156.2500, val_nll: 2078.9749, val_ensemble: 0.5102, used_weights_median: 120027
#
# 59
# loss 1419607.375
# nll 16614.322265625
# density 0.9022729314256847
#
# val_loss: 1398721.2500, val_nll: 1862.2538, val_ensemble: 0.5550, used_weights_median: 120027
#
# 60
# loss 1411415.375
# nll 14553.6337890625
# density 0.9022729314256847
#
# val_loss: 1392373.7500, val_nll: 1806.6722, val_ensemble: 0.5591, used_weights_median: 120027
#
# 61
# loss 1404651.375
# nll 13952.603515625
# density 0.9022729314256847
#
# val_loss: 1386387.3750, val_nll: 2005.9854, val_ensemble: 0.4586, used_weights_median: 120027
#
# 62
# loss 1399915.25
# nll 15470.7548828125
# density 0.9022729314256847
#
# val_loss: 1380102.5000, val_nll: 1868.7885, val_ensemble: 0.5446, used_weights_median: 120027
#
# 63
# loss 1392672.25
# nll 14526.7939453125
# density 0.9022729314256847
#
# val_loss: 1373815.2500, val_nll: 1835.2723, val_ensemble: 0.5602, used_weights_median: 120027
#
# 64
# loss 1386562.25
# nll 14643.80859375
# density 0.9022729314256847
#
# val_loss: 1367640.6250, val_nll: 1848.1361, val_ensemble: 0.5607, used_weights_median: 120027
#
# 65
# loss 1379970.125
# nll 14145.072265625
# density 0.9022729314256847
#
# val_loss: 1361516.5000, val_nll: 1895.1101, val_ensemble: 0.5206, used_weights_median: 120027
#
# 66
# loss 1374883.25
# nll 15303.80859375
# density 0.9022729314256847
#
# val_loss: 1355182.2500, val_nll: 1812.7667, val_ensemble: 0.5623, used_weights_median: 120027
#
# 67
# loss 1367485.5
# nll 14068.5400390625
# density 0.9022729314256847
#
# val_loss: 1348909.0000, val_nll: 1794.5225, val_ensemble: 0.5795, used_weights_median: 120027
#
# 68
# loss 1361188.5
# nll 13990.8251953125
# density 0.9022729314256847
#
# val_loss: 1342834.5000, val_nll: 1912.2058, val_ensemble: 0.5451, used_weights_median: 120027
#
# 69
# loss 1355588.625
# nll 14637.8291015625
# density 0.9022729314256847
#
# val_loss: 1336671.2500, val_nll: 1813.5928, val_ensemble: 0.5555, used_weights_median: 120027
#
# 70
# loss 1349005.625
# nll 14228.65625
# density 0.9022729314256847
#
# val_loss: 1330309.5000, val_nll: 1773.4792, val_ensemble: 0.5701, used_weights_median: 120027
#
# 71
# loss 1342319.125
# nll 13695.95703125
# density 0.9022729314256847
#
# val_loss: 1324311.0000, val_nll: 1855.3188, val_ensemble: 0.5446, used_weights_median: 120027
#
# 72
# loss 1336189.75
# nll 13934.5244140625
# density 0.9022729314256847
#
# val_loss: 1318062.1250, val_nll: 1835.4731, val_ensemble: 0.5586, used_weights_median: 120027
#
# 73
# loss 1330298.875
# nll 14122.1279296875
# density 0.9022729314256847
#
# val_loss: 1311801.7500, val_nll: 1786.6803, val_ensemble: 0.5727, used_weights_median: 120027
#
# 74
# loss 1323701.625
# nll 13731.732421875
# density 0.9022729314256847
#
# val_loss: 1305557.5000, val_nll: 1772.9005, val_ensemble: 0.5763, used_weights_median: 120027
#
# 75
# loss 1317515.5
# nll 13735.984375
# density 0.9022729314256847
#
# val_loss: 1299593.7500, val_nll: 1886.2830, val_ensemble: 0.5138, used_weights_median: 120027
#
# 76
# loss 1311945.875
# nll 14240.0986328125
# density 0.9022729314256847
#
# val_loss: 1293207.3750, val_nll: 1748.5549, val_ensemble: 0.5904, used_weights_median: 120027
#
# 77
# loss 1305017.625
# nll 13645.4072265625
# density 0.9022729314256847
#
# val_loss: 1287073.7500, val_nll: 1760.4214, val_ensemble: 0.5883, used_weights_median: 120027
#
# 78
# loss 1298903.125
# nll 13708.572265625
# density 0.9022729314256847
#
# val_loss: 1280889.5000, val_nll: 1774.2656, val_ensemble: 0.5779, used_weights_median: 120027
#
# 79
# loss 1292831.5
# nll 13675.2001953125
# density 0.9022729314256847
#
# val_loss: 1274868.3750, val_nll: 1840.8833, val_ensemble: 0.5539, used_weights_median: 120027
#
# 0.9817197 density median
# 120027.0 used weights median
# 0.5708181344450234 ensemble full
# 0.5776967170401252 ensemble median
# [0.5708181344450234, 0.9817197]

# %% [markdown]
# ## Weights used each class
#
# Classes:
# * 0 = Happy
# * 1 = Surprised
# * 2 = Neutral

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")

# %% [markdown]
# # ReLU based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    #---------------------------
    # DIFFERENCE IS IN act_func=F.relu part
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, act_func=F.relu, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    #---------------------------
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 122262
# 0
# loss 1785040.625
# nll 16916.279296875
# density 0.9832801789128699
#
# val_loss: 1869516.8750, val_nll: 16016.4785, val_ensemble: 0.4617, used_weights_median: 122262
#
# 1
# loss 1971747.0
# nll 118242.546875
# density 0.982524126314235
#
# val_loss: 2169386.2500, val_nll: 402964.7188, val_ensemble: 0.2199, used_weights_median: 122262
#
# 2
# loss 4965744.0
# nll 3199318.25
# density 0.9817664587413468
#
# val_loss: 2063084.7500, val_nll: 321455.3438, val_ensemble: 0.3184, used_weights_median: 122262
#
# 3
# loss 4220846.0
# nll 2479162.75
# density 0.9809590200113175
#
# val_loss: 1855741.0000, val_nll: 115639.6250, val_ensemble: 0.3184, used_weights_median: 122262
#
# 4
# loss 2648998.25
# nll 908809.625
# density 0.9801272576198973
#
# val_loss: 1781760.5000, val_nll: 50069.3164, val_ensemble: 0.2199, used_weights_median: 122262
#
# 5
# loss 2097091.75
# nll 365519.8125
# density 0.9792814950440774
#
# val_loss: 1845662.0000, val_nll: 98848.8359, val_ensemble: 0.4617, used_weights_median: 122262
#
# 6
# loss 2483946.5
# nll 726972.375
# density 0.9784046821407735
#
# val_loss: 1769189.7500, val_nll: 45044.5469, val_ensemble: 0.4617, used_weights_median: 122262
#
# 7
# loss 2051704.75
# nll 327895.8125
# density 0.9774946468344762
#
# val_loss: 1787464.5000, val_nll: 81056.8125, val_ensemble: 0.3184, used_weights_median: 122262
#
# 8
# loss 2339419.5
# nll 632870.75
# density 0.976541317648961
#
# val_loss: 1784710.0000, val_nll: 90015.1875, val_ensemble: 0.3184, used_weights_median: 122262
#
# 9
# loss 2402650.75
# nll 707940.6875
# density 0.975586368147483
#
# val_loss: 1728596.3750, val_nll: 43758.1094, val_ensemble: 0.2199, used_weights_median: 122262
#
# 10
# loss 2033128.625
# nll 348213.40625
# density 0.9746010569432255
#
# val_loss: 1691148.0000, val_nll: 14884.4609, val_ensemble: 0.2204, used_weights_median: 122262
#
# 11
# loss 1787659.125
# nll 111362.546875
# density 0.9735940058630219
#
# val_loss: 1754867.3750, val_nll: 86927.5938, val_ensemble: 0.4617, used_weights_median: 122262
#
# 12
# loss 2329795.25
# nll 661871.75
# density 0.9725480281497005
#
# val_loss: 1739578.5000, val_nll: 80003.6016, val_ensemble: 0.4617, used_weights_median: 122262
#
# 13
# loss 2277750.5
# nll 618160.8125
# density 0.9714863623366016
#
# val_loss: 1717951.7500, val_nll: 66788.2812, val_ensemble: 0.3184, used_weights_median: 122262
#
# 14
# loss 2138467.0
# nll 487216.4375
# density 0.9704112225011499
#
# val_loss: 1705596.1250, val_nll: 62843.4688, val_ensemble: 0.4617, used_weights_median: 122262
#
# 15
# loss 2119740.5
# nll 476866.375
# density 0.9692819116057302
#
# val_loss: 1690159.7500, val_nll: 55820.0898, val_ensemble: 0.4617, used_weights_median: 122262
#
# 16
# loss 2059109.625
# nll 424692.625
# density 0.9680972335685938
#
# val_loss: 1656974.3750, val_nll: 30937.3965, val_ensemble: 0.4617, used_weights_median: 122262
#
# 17
# loss 1862043.5
# nll 235986.796875
# density 0.9668555632858858
#
# val_loss: 1629522.6250, val_nll: 11947.5215, val_ensemble: 0.3184, used_weights_median: 122262
#
# 18
# loss 1708855.0
# nll 91159.546875
# density 0.9655579049980265
#
# val_loss: 1627209.1250, val_nll: 18132.4141, val_ensemble: 0.2548, used_weights_median: 122262
#
# 19
# loss 1754599.0
# nll 145537.015625
# density 0.9642000563815778
#
# val_loss: 1617214.0000, val_nll: 16711.9043, val_ensemble: 0.2387, used_weights_median: 122262
#
# 20
# loss 1731243.75
# nll 130748.3671875
# density 0.9627789187872244
#
# val_loss: 1596446.1250, val_nll: 4592.2100, val_ensemble: 0.3267, used_weights_median: 122262
#
# 21
# loss 1627242.5
# nll 35580.33203125
# density 0.9612916022306593
#
# val_loss: 1599786.6250, val_nll: 16824.1934, val_ensemble: 0.4617, used_weights_median: 122262
#
# 22
# loss 1712433.875
# nll 129510.65625
# density 0.9597335066960481
#
# val_loss: 1594115.2500, val_nll: 20078.2617, val_ensemble: 0.4617, used_weights_median: 122262
#
# 23
# loss 1727873.375
# nll 153694.546875
# density 0.9581006594086708
#
# val_loss: 1579513.2500, val_nll: 14375.5547, val_ensemble: 0.4617, used_weights_median: 122262
#
# 24
# loss 1674429.875
# nll 109257.96875
# density 0.9563895905203694
#
# val_loss: 1568413.1250, val_nll: 12344.7832, val_ensemble: 0.3184, used_weights_median: 122262
#
# 25
# loss 1652527.125
# nll 96522.9453125
# density 0.9546386710918547
#
# val_loss: 1549594.8750, val_nll: 2796.4805, val_ensemble: 0.4231, used_weights_median: 122262
#
# 26
# loss 1568030.375
# nll 21129.841796875
# density 0.9528037525469808
#
# val_loss: 1544129.0000, val_nll: 6475.7056, val_ensemble: 0.2850, used_weights_median: 122262
#
# 27
# loss 1584567.375
# nll 46908.3046875
# density 0.9508812771277824
#
# val_loss: 1532231.5000, val_nll: 3939.9851, val_ensemble: 0.4122, used_weights_median: 122262
#
# 28
# loss 1558182.5
# nll 29873.97265625
# density 0.9488680880759977
#
# val_loss: 1522685.0000, val_nll: 3903.4482, val_ensemble: 0.4758, used_weights_median: 122262
#
# 29
# loss 1549381.875
# nll 30530.96875
# density 0.9467610634561239
#
# val_loss: 1514375.2500, val_nll: 5134.4043, val_ensemble: 0.3679, used_weights_median: 122262
#
# 30
# loss 1548611.375
# nll 39344.04296875
# density 0.9445562212867074
#
# val_loss: 1503909.1250, val_nll: 4472.4116, val_ensemble: 0.4356, used_weights_median: 122262
#
# 31
# loss 1533330.125
# nll 33901.125
# density 0.9422501090985493
#
# val_loss: 1493238.5000, val_nll: 3759.7092, val_ensemble: 0.4737, used_weights_median: 122262
#
# 32
# loss 1518988.625
# nll 29391.640625
# density 0.9398394892886589
#
# val_loss: 1482498.5000, val_nll: 3070.3103, val_ensemble: 0.4299, used_weights_median: 122262
#
# 33
# loss 1502754.375
# nll 23285.75390625
# density 0.9373203503711324
#
# val_loss: 1473622.2500, val_nll: 4296.3545, val_ensemble: 0.3210, used_weights_median: 122262
#
# 34
# loss 1501599.25
# nll 32360.572265625
# density 0.9346888885090913
#
# val_loss: 1461477.1250, val_nll: 2583.1616, val_ensemble: 0.4054, used_weights_median: 122262
#
# 35
# loss 1478896.375
# nll 19985.046875
# density 0.9319419214710908
#
# val_loss: 1451803.3750, val_nll: 3388.1067, val_ensemble: 0.4966, used_weights_median: 122262
#
# 36
# loss 1474742.125
# nll 26352.9765625
# density 0.9290762297234221
#
# val_loss: 1441165.2500, val_nll: 3363.5828, val_ensemble: 0.5086, used_weights_median: 122262
#
# 37
# loss 1463408.0
# nll 25671.9453125
# density 0.9260883393323013
#
# val_loss: 1429660.2500, val_nll: 2601.9490, val_ensemble: 0.4065, used_weights_median: 122113
#
# 38
# loss 1447500.875
# nll 20532.412109375
# density 0.9229746579139607
#
# val_loss: 1418826.6250, val_nll: 2921.6851, val_ensemble: 0.3721, used_weights_median: 121675
#
# 39
# loss 1437601.5
# nll 21608.884765625
# density 0.919731622648316
#
# val_loss: 1407487.8750, val_nll: 2623.3232, val_ensemble: 0.4664, used_weights_median: 121171
#
# 40
# loss 1557796.375
# nll 20398.41796875
# density 0.919731622648316
#
# val_loss: 1534002.7500, val_nll: 2688.1082, val_ensemble: 0.4904, used_weights_median: 121171
#
# 41
# loss 1552128.75
# nll 20676.6015625
# density 0.919731622648316
#
# val_loss: 1528087.6250, val_nll: 2693.4917, val_ensemble: 0.3893, used_weights_median: 121171
#
# 42
# loss 1545918.25
# nll 20582.0703125
# density 0.919731622648316
#
# val_loss: 1521405.8750, val_nll: 2195.9668, val_ensemble: 0.4596, used_weights_median: 121171
#
# 43
# loss 1535937.625
# nll 16708.513671875
# density 0.919731622648316
#
# val_loss: 1515488.1250, val_nll: 2345.1323, val_ensemble: 0.5112, used_weights_median: 121171
#
# 44
# loss 1531451.625
# nll 18412.36328125
# density 0.919731622648316
#
# val_loss: 1509512.7500, val_nll: 2600.5513, val_ensemble: 0.4997, used_weights_median: 121171
#
# 45
# loss 1527401.875
# nll 20383.875
# density 0.919731622648316
#
# val_loss: 1502774.6250, val_nll: 1920.7328, val_ensemble: 0.5518, used_weights_median: 121171
#
# 46
# loss 1515722.25
# nll 14833.736328125
# density 0.919731622648316
#
# val_loss: 1497312.2500, val_nll: 2707.7280, val_ensemble: 0.3721, used_weights_median: 121171
#
# 47
# loss 1514897.625
# nll 20315.224609375
# density 0.919731622648316
#
# val_loss: 1490536.1250, val_nll: 2065.3193, val_ensemble: 0.5571, used_weights_median: 121171
#
# 48
# loss 1504653.125
# nll 16148.1953125
# density 0.919731622648316
#
# val_loss: 1484522.7500, val_nll: 2184.3025, val_ensemble: 0.5326, used_weights_median: 121171
#
# 49
# loss 1498952.25
# nll 16712.783203125
# density 0.919731622648316
#
# val_loss: 1478503.0000, val_nll: 2383.8674, val_ensemble: 0.4330, used_weights_median: 121171
#
# 50
# loss 1494874.125
# nll 18792.228515625
# density 0.919731622648316
#
# val_loss: 1471767.6250, val_nll: 1962.0804, val_ensemble: 0.5367, used_weights_median: 121171
#
# 51
# loss 1484940.75
# nll 15050.6376953125
# density 0.919731622648316
#
# val_loss: 1465865.0000, val_nll: 2222.7991, val_ensemble: 0.5487, used_weights_median: 121171
#
# 52
# loss 1480712.875
# nll 17028.9296875
# density 0.919731622648316
#
# val_loss: 1459493.7500, val_nll: 2024.9373, val_ensemble: 0.5498, used_weights_median: 121171
#
# 53
# loss 1472960.25
# nll 15486.75390625
# density 0.919731622648316
#
# val_loss: 1453240.8750, val_nll: 2042.8599, val_ensemble: 0.4987, used_weights_median: 121171
#
# 54
# loss 1466925.25
# nll 15655.015625
# density 0.919731622648316
#
# val_loss: 1446922.5000, val_nll: 1932.9779, val_ensemble: 0.5341, used_weights_median: 121171
#
# 55
# loss 1459762.0
# nll 14775.626953125
# density 0.919731622648316
#
# val_loss: 1440785.5000, val_nll: 1953.2004, val_ensemble: 0.5644, used_weights_median: 121171
#
# 56
# loss 1453414.75
# nll 14622.1591796875
# density 0.919731622648316
#
# val_loss: 1434541.1250, val_nll: 2018.3395, val_ensemble: 0.5529, used_weights_median: 121171
#
# 57
# loss 1447965.875
# nll 15439.115234375
# density 0.919731622648316
#
# val_loss: 1428083.3750, val_nll: 1860.7773, val_ensemble: 0.5680, used_weights_median: 121171
#
# 58
# loss 1440375.875
# nll 14127.8310546875
# density 0.919731622648316
#
# val_loss: 1422063.1250, val_nll: 2010.4762, val_ensemble: 0.5154, used_weights_median: 121171
#
# 59
# loss 1435493.375
# nll 15524.642578125
# density 0.919731622648316
#
# val_loss: 1415681.3750, val_nll: 1888.4912, val_ensemble: 0.5664, used_weights_median: 121171
#
# 60
# loss 1428307.5
# nll 14512.5576171875
# density 0.919731622648316
#
# val_loss: 1409360.3750, val_nll: 1888.8002, val_ensemble: 0.5612, used_weights_median: 121171
#
# 61
# loss 1422117.25
# nll 14514.3642578125
# density 0.919731622648316
#
# val_loss: 1403120.8750, val_nll: 1867.1128, val_ensemble: 0.5664, used_weights_median: 121171
#
# 62
# loss 1415435.25
# nll 14121.244140625
# density 0.919731622648316
#
# val_loss: 1396961.6250, val_nll: 1903.8937, val_ensemble: 0.5586, used_weights_median: 121171
#
# 63
# loss 1409152.0
# nll 14182.892578125
# density 0.919731622648316
#
# val_loss: 1390675.5000, val_nll: 1917.9161, val_ensemble: 0.5555, used_weights_median: 121171
#
# 64
# loss 1403211.25
# nll 14515.2080078125
# density 0.919731622648316
#
# val_loss: 1384389.1250, val_nll: 1857.8158, val_ensemble: 0.5659, used_weights_median: 121171
#
# 65
# loss 1396809.125
# nll 14245.748046875
# density 0.919731622648316
#
# val_loss: 1378181.8750, val_nll: 1859.3411, val_ensemble: 0.5784, used_weights_median: 121171
#
# 66
# loss 1390261.375
# nll 13981.1474609375
# density 0.919731622648316
#
# val_loss: 1371939.2500, val_nll: 1912.8085, val_ensemble: 0.5597, used_weights_median: 121171
#
# 67
# loss 1384550.5
# nll 14475.90234375
# density 0.919731622648316
#
# val_loss: 1365547.7500, val_nll: 1823.3314, val_ensemble: 0.5810, used_weights_median: 121171
#
# 68
# loss 1377635.375
# nll 13828.310546875
# density 0.919731622648316
#
# val_loss: 1359385.6250, val_nll: 1900.2891, val_ensemble: 0.5373, used_weights_median: 121171
#
# 69
# loss 1371967.25
# nll 14453.4560546875
# density 0.919731622648316
#
# val_loss: 1353161.3750, val_nll: 1785.0302, val_ensemble: 0.5967, used_weights_median: 121171
#
# 70
# loss 1365002.25
# nll 13705.6123046875
# density 0.919731622648316
#
# val_loss: 1346870.3750, val_nll: 1859.2683, val_ensemble: 0.5774, used_weights_median: 121171
#
# 71
# loss 1359452.875
# nll 14353.4912109375
# density 0.919731622648316
#
# val_loss: 1340756.8750, val_nll: 1871.4084, val_ensemble: 0.5628, used_weights_median: 121171
#
# 72
# loss 1352422.125
# nll 13738.4208984375
# density 0.919731622648316
#
# val_loss: 1334474.7500, val_nll: 1870.8784, val_ensemble: 0.5607, used_weights_median: 121171
#
# 73
# loss 1346890.875
# nll 14337.1630859375
# density 0.919731622648316
#
# val_loss: 1328201.0000, val_nll: 1860.8517, val_ensemble: 0.5743, used_weights_median: 121171
#
# 74
# loss 1340586.0
# nll 14290.572265625
# density 0.919731622648316
#
# val_loss: 1321838.3750, val_nll: 1779.1956, val_ensemble: 0.5977, used_weights_median: 121171
#
# 75
# loss 1333719.5
# nll 13666.294921875
# density 0.919731622648316
#
# val_loss: 1315881.5000, val_nll: 1944.2211, val_ensemble: 0.5149, used_weights_median: 121171
#
# 76
# loss 1328802.375
# nll 14868.0244140625
# density 0.919731622648316
#
# val_loss: 1309460.8750, val_nll: 1820.4945, val_ensemble: 0.5758, used_weights_median: 121171
#
# 77
# loss 1321294.25
# nll 13740.0595703125
# density 0.919731622648316
#
# val_loss: 1303267.2500, val_nll: 1817.9364, val_ensemble: 0.5857, used_weights_median: 121171
#
# 78
# loss 1315188.25
# nll 13858.279296875
# density 0.919731622648316
#
# val_loss: 1296985.1250, val_nll: 1782.6570, val_ensemble: 0.5920, used_weights_median: 121171
#
# 79
# loss 1308896.875
# nll 13654.3515625
# density 0.919731622648316
#
# val_loss: 1290865.1250, val_nll: 1795.9014, val_ensemble: 0.5862, used_weights_median: 121171
#
# 0.9910766 density median
# 121171.0 used weights median
# 0.573892652423137 ensemble full
# 0.5808754559666494 ensemble median
# [0.573892652423137, 0.9910766]

# %% [markdown]
# ## Weights used each class
#
# Classes:
#
# * 0 = Happy
# * 1 = Surprised
# * 2 = Neutral

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")
