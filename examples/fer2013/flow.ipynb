# %% [markdown]
# ## Imports

# %%
import copy
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from config import config
import os
import sys
current_dir = os.getcwd()
path = "/Users/eirikhoyheim/local_files/master/ISLBBNN/islbbnn"
# path = "C:\\Users\\eirik\\Documents\\Master\\ISLBBNN\\islbbnn"
# path = "C:\\you\\path\\to\\islbbnn\\folder\\here"
os.chdir(path)
import plot_functions as pf
import pipeline_functions as pip_func
sys.path.append('networks')
from flow_net import BayesianNetwork
import torch.nn.functional as F

os.chdir(current_dir) # set the working directory back to this one
# Out:
# CPUs are used!

# %% [markdown]
# # Problem description
#
# The FER 2013 dataset. We will only train on the expressions Happy, Surprised, and Neutral.
#
# Attained from the following kaggle competition: https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/overview
#
# # Batch size and parameters

# %%
# define parameters
HIDDEN_LAYERS = config['n_layers'] - 2 
epochs = config['num_epochs']
post_train_epochs = config['post_train_epochs']
dim = config['hidden_dim']
num_transforms = config['num_transforms']
n_nets = config['n_nets']
lr = config['lr']
class_problem = config["class_problem"]
verbose = config['verbose']
save_res = config['save_res']
patience = config['patience']
a_prior = config['a_prior']
SAMPLES = 1



#---------DATA------------
df = pd.read_csv("../../../icml_face_data.csv")

data = np.zeros((len(df), 48*48))
for i in range(len(data)):
    data[i] = np.array(df[" pixels"][i].split(" ")).astype(np.float32)/255.
targets = df.emotion.values

X_original,y_original  = data, targets
used_inds = [yi in [3,5,6] for yi in y_original]  # Happy, sad and neutral
y_original = y_original[used_inds]
y_original = np.where(y_original == 3, 0, y_original)
y_original = np.where(y_original == 5, 1, y_original)
y_original = np.where(y_original == 6, 2, y_original)
X_original = X_original[used_inds]
n,p = X_original.shape
print(n,p,dim)

n_classes = len(np.unique(y_original))
multiclass = n_classes > 1

BATCH_SIZE = int(n*0.8/10)
TEST_BATCH_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_BATCH_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

TRAIN_SIZE = int(n*0.80/10)
TEST_SIZE = int(n*0.10) # Would normally call this the "validation" part (will be used during training)
VAL_SIZE = int(n*0.10) # and this the "test" part (will be used after training)

NUM_BATCHES = TRAIN_SIZE/BATCH_SIZE

assert (TRAIN_SIZE % BATCH_SIZE) == 0
assert (TEST_SIZE % TEST_BATCH_SIZE) == 0
# Out:
# 19189 2304 100

# %% [markdown]
# # Sigmoid based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 237612
# 0
# loss 3384704.75
# nll 1.928880214691162
# density 0.9833475100244173
#
# val_loss: 3385371.5000, val_nll: 2551.8101, val_ensemble: 0.4617, used_weights_median: 237612
#
# 1
# loss 3366144.75
# nll 2.022289276123047
# density 0.9824611758693325
#
# val_loss: 3366731.0000, val_nll: 2079.9968, val_ensemble: 0.4648, used_weights_median: 237612
#
# 2
# loss 3348608.25
# nll 1.4640742540359497
# density 0.9815183746570502
#
# val_loss: 3348875.5000, val_nll: 1866.3872, val_ensemble: 0.5409, used_weights_median: 237612
#
# 3
# loss 3331012.5
# nll 1.266119122505188
# density 0.9805117215892674
#
# val_loss: 3331287.0000, val_nll: 1762.6981, val_ensemble: 0.5800, used_weights_median: 237612
#
# 4
# loss 3313367.0
# nll 1.0944538116455078
# density 0.9794345179946247
#
# val_loss: 3313431.0000, val_nll: 1715.1664, val_ensemble: 0.6186, used_weights_median: 237612
#
# 5
# loss 3295512.0
# nll 1.0327516794204712
# density 0.9782803655107192
#
# val_loss: 3295544.2500, val_nll: 1740.9482, val_ensemble: 0.5915, used_weights_median: 237612
#
# 6
# loss 3277429.25
# nll 1.129338264465332
# density 0.9770428220537369
#
# val_loss: 3277484.0000, val_nll: 1716.9333, val_ensemble: 0.6055, used_weights_median: 237612
#
# 7
# loss 3258877.0
# nll 0.973720908164978
# density 0.9757151690249033
#
# val_loss: 3259037.0000, val_nll: 1779.2883, val_ensemble: 0.5560, used_weights_median: 237612
#
# 8
# loss 3240197.75
# nll 1.608569860458374
# density 0.9742903012325853
#
# val_loss: 3240175.2500, val_nll: 1663.8657, val_ensemble: 0.6285, used_weights_median: 237612
#
# 9
# loss 3221199.0
# nll 1.0437514781951904
# density 0.9727606559452753
#
# val_loss: 3221386.0000, val_nll: 1836.4766, val_ensemble: 0.5868, used_weights_median: 237612
#
# 10
# loss 3201908.0
# nll 1.1775381565093994
# density 0.9711181765541598
#
# val_loss: 3201797.2500, val_nll: 1705.7593, val_ensemble: 0.6081, used_weights_median: 237612
#
# 11
# loss 3182049.5
# nll 0.9210492372512817
# density 0.9693543068781033
#
# val_loss: 3182099.5000, val_nll: 1735.6390, val_ensemble: 0.5987, used_weights_median: 237612
#
# 12
# loss 3162041.75
# nll 1.090066909790039
# density 0.9674599773536785
#
# val_loss: 3161854.2500, val_nll: 1704.5044, val_ensemble: 0.5993, used_weights_median: 237612
#
# 13
# loss 3141324.75
# nll 1.6391897201538086
# density 0.9654256066007129
#
# val_loss: 3141092.5000, val_nll: 1644.6681, val_ensemble: 0.6295, used_weights_median: 237612
#
# 14
# loss 3120343.75
# nll 1.1126577854156494
# density 0.9632411052775804
#
# val_loss: 3120037.7500, val_nll: 1623.2488, val_ensemble: 0.6357, used_weights_median: 237612
#
# 15
# loss 3098787.0
# nll 0.9726272821426392
# density 0.9608958701007208
#
# val_loss: 3098531.2500, val_nll: 1651.5431, val_ensemble: 0.6243, used_weights_median: 237612
#
# 16
# loss 3076602.25
# nll 1.0319640636444092
# density 0.9583788116098186
#
# val_loss: 3076321.0000, val_nll: 1665.6641, val_ensemble: 0.6248, used_weights_median: 237612
#
# 17
# loss 3054045.25
# nll 1.139601469039917
# density 0.955678398399191
#
# val_loss: 3053638.2500, val_nll: 1681.4591, val_ensemble: 0.6311, used_weights_median: 237612
#
# 18
# loss 3030872.75
# nll 1.0622785091400146
# density 0.9527826887926943
#
# val_loss: 3030299.0000, val_nll: 1626.7616, val_ensemble: 0.6436, used_weights_median: 237612
#
# 19
# loss 3007043.25
# nll 0.7867947816848755
# density 0.9496793324917998
#
# val_loss: 3006633.5000, val_nll: 1846.6879, val_ensemble: 0.5404, used_weights_median: 237612
#
# 20
# loss 2982631.75
# nll 1.3396848440170288
# density 0.9463556450232029
#
# val_loss: 2982015.7500, val_nll: 1795.2417, val_ensemble: 0.5795, used_weights_median: 237612
#
# 21
# loss 2957231.5
# nll 1.092026710510254
# density 0.9427986988064083
#
# val_loss: 2956702.0000, val_nll: 1704.8671, val_ensemble: 0.6285, used_weights_median: 237612
#
# 22
# loss 2931399.25
# nll 1.1099867820739746
# density 0.9389953084379455
#
# val_loss: 2930594.5000, val_nll: 1616.7845, val_ensemble: 0.6451, used_weights_median: 237612
#
# 23
# loss 2904774.75
# nll 1.30879545211792
# density 0.93493209413751
#
# val_loss: 2903903.5000, val_nll: 1619.2196, val_ensemble: 0.6503, used_weights_median: 237612
#
# 24
# loss 2877266.25
# nll 0.8874806761741638
# density 0.9305955681587942
#
# val_loss: 2876453.7500, val_nll: 1657.3193, val_ensemble: 0.6232, used_weights_median: 237612
#
# 25
# loss 2849084.75
# nll 1.2644966840744019
# density 0.9259722310391034
#
# val_loss: 2848044.0000, val_nll: 1606.4944, val_ensemble: 0.6446, used_weights_median: 237612
#
# 26
# loss 2819800.25
# nll 0.9264854788780212
# density 0.9210485879020085
#
# val_loss: 2818995.7500, val_nll: 1618.6705, val_ensemble: 0.6483, used_weights_median: 237612
#
# 27
# loss 2790010.75
# nll 1.0112640857696533
# density 0.915811222230423
#
# val_loss: 2788845.0000, val_nll: 1607.5498, val_ensemble: 0.6425, used_weights_median: 237612
#
# 28
# loss 2759212.5
# nll 1.5117732286453247
# density 0.9102469168077516
#
# val_loss: 2757875.7500, val_nll: 1605.7118, val_ensemble: 0.6420, used_weights_median: 237612
#
# 29
# loss 2727179.75
# nll 1.1368701457977295
# density 0.9043426508085476
#
# val_loss: 2726095.7500, val_nll: 1671.6622, val_ensemble: 0.6191, used_weights_median: 237612
#
# 30
# loss 2694541.75
# nll 1.3106305599212646
# density 0.8980857053538608
#
# val_loss: 2693177.7500, val_nll: 1624.0416, val_ensemble: 0.6493, used_weights_median: 237612
#
# 31
# loss 2660794.0
# nll 0.9695791602134705
# density 0.8914637601931912
#
# val_loss: 2659344.2500, val_nll: 1606.0642, val_ensemble: 0.6404, used_weights_median: 236196
#
# 32
# loss 2626105.25
# nll 1.433512806892395
# density 0.8844648644915354
#
# val_loss: 2624556.5000, val_nll: 1613.0992, val_ensemble: 0.6483, used_weights_median: 233511
#
# 33
# loss 2590457.75
# nll 0.9545480608940125
# density 0.8770775654403575
#
# val_loss: 2588759.2500, val_nll: 1624.1844, val_ensemble: 0.6472, used_weights_median: 230665
#
# 34
# loss 2553679.5
# nll 1.261152982711792
# density 0.8692910051466183
#
# val_loss: 2551837.7500, val_nll: 1620.6986, val_ensemble: 0.6430, used_weights_median: 227763
#
# 35
# loss 2515881.5
# nll 1.6296443939208984
# density 0.8610949580496077
#
# val_loss: 2514171.7500, val_nll: 1643.7030, val_ensemble: 0.6311, used_weights_median: 224757
#
# 36
# loss 2477193.25
# nll 1.091393232345581
# density 0.8524798993740245
#
# val_loss: 2475265.7500, val_nll: 1760.3610, val_ensemble: 0.6118, used_weights_median: 221503
#
# 37
# loss 2437193.0
# nll 1.1022440195083618
# density 0.8434370879383699
#
# val_loss: 2435172.7500, val_nll: 1702.5911, val_ensemble: 0.6311, used_weights_median: 218259
#
# 38
# loss 2396323.5
# nll 0.9598608613014221
# density 0.8339586413683977
#
# val_loss: 2394289.2500, val_nll: 1705.8759, val_ensemble: 0.6123, used_weights_median: 214918
#
# 39
# loss 2354440.0
# nll 1.3983246088027954
# density 0.8240376485801485
#
# val_loss: 2352058.0000, val_nll: 1612.3751, val_ensemble: 0.6420, used_weights_median: 211386
#
# 40
# loss 2311408.0
# nll 1.003432273864746
# density 0.8136682005679821
#
# val_loss: 2309020.5000, val_nll: 1625.0306, val_ensemble: 0.6394, used_weights_median: 207719
#
# 41
# loss 2267210.75
# nll 0.9631500244140625
# density 0.8028455108201975
#
# val_loss: 2264926.0000, val_nll: 1722.4305, val_ensemble: 0.6279, used_weights_median: 204111
#
# 42
# loss 2222153.75
# nll 0.927687406539917
# density 0.7915659590695435
#
# val_loss: 2219722.0000, val_nll: 1701.8118, val_ensemble: 0.6180, used_weights_median: 200251
#
# 43
# loss 2176050.0
# nll 0.8974968194961548
# density 0.7798272092779897
#
# val_loss: 2173505.7500, val_nll: 1655.8856, val_ensemble: 0.6238, used_weights_median: 196173
#
# 44
# loss 2128918.0
# nll 1.4342360496520996
# density 0.7676283363408718
#
# val_loss: 2126792.7500, val_nll: 2091.6240, val_ensemble: 0.5367, used_weights_median: 189953
#
# 45
# loss 2080893.0
# nll 0.8116822838783264
# density 0.7549698766029144
#
# val_loss: 2078227.6250, val_nll: 1803.3500, val_ensemble: 0.5545, used_weights_median: 185625
#
# 46
# loss 2031872.625
# nll 0.6237756609916687
# density 0.7418538722230688
#
# val_loss: 2029191.0000, val_nll: 1806.2219, val_ensemble: 0.6107, used_weights_median: 181191
#
# 47
# loss 1981935.125
# nll 1.004887580871582
# density 0.7282836479453201
#
# val_loss: 1979254.1250, val_nll: 1974.1024, val_ensemble: 0.5274, used_weights_median: 174850
#
# 48
# loss 1931136.625
# nll 1.3955986499786377
# density 0.7142642823035409
#
# val_loss: 1928447.1250, val_nll: 2021.2634, val_ensemble: 0.5565, used_weights_median: 170071
#
# 49
# loss 1879555.75
# nll 1.3784067630767822
# density 0.699802648391042
#
# val_loss: 1876614.1250, val_nll: 1812.5000, val_ensemble: 0.6092, used_weights_median: 163603
#
# 50
# loss 1827129.0
# nll 1.340083122253418
# density 0.6849074028057978
#
# val_loss: 1823896.2500, val_nll: 1667.5286, val_ensemble: 0.6243, used_weights_median: 155555
#
# 51
# loss 1774009.0
# nll 0.7512003183364868
# density 0.6695888794539925
#
# val_loss: 1770813.1250, val_nll: 1689.9949, val_ensemble: 0.6040, used_weights_median: 149141
#
# 52
# loss 1720169.125
# nll 1.188520073890686
# density 0.6538594519639555
#
# val_loss: 1716812.7500, val_nll: 1594.4772, val_ensemble: 0.6483, used_weights_median: 142772
#
# 53
# loss 1665709.25
# nll 1.7014366388320923
# density 0.6377339615509562
#
# val_loss: 1662320.7500, val_nll: 1635.3013, val_ensemble: 0.6274, used_weights_median: 137742
#
# 54
# loss 1610838.125
# nll 1.6863291263580322
# density 0.6212299578875153
#
# val_loss: 1607492.0000, val_nll: 1862.3453, val_ensemble: 0.5670, used_weights_median: 132822
#
# 55
# loss 1555372.625
# nll 1.6277190446853638
# density 0.6043681708255713
#
# val_loss: 1552246.8750, val_nll: 1841.2192, val_ensemble: 0.5623, used_weights_median: 127658
#
# 56
# loss 1499732.375
# nll 1.4672026634216309
# density 0.587172469078324
#
# val_loss: 1496344.2500, val_nll: 1818.0040, val_ensemble: 0.5409, used_weights_median: 122533
#
# 57
# loss 1443704.375
# nll 1.6314160823822021
# density 0.5696698421678512
#
# val_loss: 1440156.5000, val_nll: 1700.7643, val_ensemble: 0.5878, used_weights_median: 113671
#
# 58
# loss 1387534.5
# nll 0.8952333331108093
# density 0.5518949791655352
#
# val_loss: 1384113.8750, val_nll: 1764.1423, val_ensemble: 0.6034, used_weights_median: 105084
#
# 59
# loss 1331398.625
# nll 1.2933579683303833
# density 0.5338894657230265
#
# val_loss: 1328660.3750, val_nll: 1677.4406, val_ensemble: 0.6128, used_weights_median: 96810
#
# 60
# loss 1275365.625
# nll 0.8875117897987366
# density 0.5156868519304281
#
# val_loss: 1272027.8750, val_nll: 1691.0952, val_ensemble: 0.6186, used_weights_median: 88791
#
# 61
# loss 1219608.5
# nll 1.6864067316055298
# density 0.4973328982901939
#
# val_loss: 1216336.6250, val_nll: 1754.3674, val_ensemble: 0.5878, used_weights_median: 79982
#
# 62
# loss 1164144.75
# nll 1.2988200187683105
# density 0.4788778309124733
#
# val_loss: 1160859.6250, val_nll: 1692.6212, val_ensemble: 0.6087, used_weights_median: 72612
#
# 63
# loss 1109418.375
# nll 3.364611864089966
# density 0.46038098373297276
#
# val_loss: 1106190.7500, val_nll: 1763.7827, val_ensemble: 0.5810, used_weights_median: 67269
#
# 64
# loss 1055373.25
# nll 1.1769883632659912
# density 0.4419078537559181
#
# val_loss: 1052137.7500, val_nll: 1639.1812, val_ensemble: 0.6326, used_weights_median: 61215
#
# 65
# loss 1002370.0625
# nll 0.9518975019454956
# density 0.4235301485616503
#
# val_loss: 999361.1250, val_nll: 1907.3254, val_ensemble: 0.5857, used_weights_median: 55185
#
# 66
# loss 950337.0625
# nll 1.9642739295959473
# density 0.4053252564769406
#
# val_loss: 947693.2500, val_nll: 2036.2073, val_ensemble: 0.5508, used_weights_median: 49646
#
# 67
# loss 899701.1875
# nll 1.095281720161438
# density 0.38737417615035385
#
# val_loss: 897088.2500, val_nll: 1928.7185, val_ensemble: 0.5664, used_weights_median: 43426
#
# 68
# loss 850777.1875
# nll 0.5742062926292419
# density 0.3697618179633706
#
# val_loss: 848220.3750, val_nll: 1780.5031, val_ensemble: 0.5935, used_weights_median: 35409
#
# 69
# loss 803575.5625
# nll 1.0888727903366089
# density 0.35257309137823656
#
# val_loss: 801123.8125, val_nll: 1771.8750, val_ensemble: 0.5935, used_weights_median: 31138
#
# 70
# loss 758250.9375
# nll 0.793060302734375
# density 0.3358901878241134
#
# val_loss: 755902.6250, val_nll: 1671.0093, val_ensemble: 0.6217, used_weights_median: 26653
#
# 71
# loss 715117.3125
# nll 1.7994264364242554
# density 0.3197889802877574
#
# val_loss: 713123.4375, val_nll: 1782.2509, val_ensemble: 0.5513, used_weights_median: 20421
#
# 72
# loss 674249.0625
# nll 2.1325767040252686
# density 0.304336091453488
#
# val_loss: 672371.9375, val_nll: 1731.1096, val_ensemble: 0.5826, used_weights_median: 16294
#
# 73
# loss 635682.75
# nll 0.6891269683837891
# density 0.2895856342794965
#
# val_loss: 634228.7500, val_nll: 1953.8334, val_ensemble: 0.4763, used_weights_median: 13354
#
# 74
# loss 599478.125
# nll 1.690278172492981
# density 0.2755771879903016
#
# val_loss: 598064.2500, val_nll: 1864.6274, val_ensemble: 0.5055, used_weights_median: 9532
#
# 75
# loss 565576.9375
# nll 0.3281525671482086
# density 0.2623345381322468
#
# val_loss: 564672.3125, val_nll: 2126.9050, val_ensemble: 0.4101, used_weights_median: 5686
#
# 76
# loss 534151.5625
# nll 1.752501130104065
# density 0.2498659145478892
#
# val_loss: 533302.5625, val_nll: 1955.2491, val_ensemble: 0.4643, used_weights_median: 2547
#
# 77
# loss 504802.84375
# nll 0.857274055480957
# density 0.23816519538614933
#
# val_loss: 504750.6562, val_nll: 2516.9182, val_ensemble: 0.3663, used_weights_median: 873
#
# 78
# loss 477642.9375
# nll 1.627837896347046
# density 0.22721450396584883
#
# val_loss: 477796.0625, val_nll: 2549.7192, val_ensemble: 0.3538, used_weights_median: 168
#
# 79
# loss 452525.5625
# nll 1.028233528137207
# density 0.21698557070805422
#
# val_loss: 453383.1875, val_nll: 2976.0691, val_ensemble: 0.3252, used_weights_median: 133
#
# 80
# loss 429275.90625
# nll 1.3896509408950806
# density 0.20744247253428394
#
# val_loss: 429907.8125, val_nll: 2581.8047, val_ensemble: 0.3377, used_weights_median: 113
#
# 81
# loss 407924.71875
# nll 1.627997636795044
# density 0.19854534867300386
#
# val_loss: 409110.2812, val_nll: 3077.5281, val_ensemble: 0.3200, used_weights_median: 94
#
# 82
# loss 388023.5
# nll 1.3283246755599976
# density 0.19025215096463174
#
# val_loss: 389294.0625, val_nll: 2901.9194, val_ensemble: 0.3283, used_weights_median: 80
#
# 83
# loss 369790.1875
# nll 0.7894275188446045
# density 0.18251967516243622
#
# val_loss: 370716.2188, val_nll: 2570.8965, val_ensemble: 0.3528, used_weights_median: 68
#
# 84
# loss 352779.59375
# nll 0.6727506518363953
# density 0.17530524499324682
#
# val_loss: 354050.5000, val_nll: 2909.8049, val_ensemble: 0.3491, used_weights_median: 57
#
# 85
# loss 336961.75
# nll 1.4257550239562988
# density 0.16856824629847983
#
# val_loss: 338269.0625, val_nll: 2790.7944, val_ensemble: 0.3278, used_weights_median: 51
#
# 86
# loss 322253.9375
# nll 1.3615672588348389
# density 0.16226984253968307
#
# val_loss: 323989.1562, val_nll: 2962.1667, val_ensemble: 0.3246, used_weights_median: 45
#
# 87
# loss 308670.4375
# nll 1.7258347272872925
# density 0.15637431514707933
#
# val_loss: 310138.8125, val_nll: 2531.2427, val_ensemble: 0.3325, used_weights_median: 39
#
# 88
# loss 295917.3125
# nll 0.5940710306167603
# density 0.15084880071492604
#
# val_loss: 297463.7812, val_nll: 2643.5334, val_ensemble: 0.3319, used_weights_median: 35
#
# 89
# loss 284071.1875
# nll 1.4936268329620361
# density 0.14566261185051524
#
# val_loss: 285592.2500, val_nll: 2457.1721, val_ensemble: 0.3356, used_weights_median: 32
#
# 90
# loss 272999.3125
# nll 1.1266567707061768
# density 0.14078814225130273
#
# val_loss: 274542.9062, val_nll: 2632.2847, val_ensemble: 0.3241, used_weights_median: 29
#
# 91
# loss 262511.84375
# nll 0.9458298087120056
# density 0.13619949946583007
#
# val_loss: 264238.9375, val_nll: 2614.0325, val_ensemble: 0.3215, used_weights_median: 27
#
# 92
# loss 252780.625
# nll 1.8614866733551025
# density 0.13187412637080553
#
# val_loss: 254598.7344, val_nll: 2740.6472, val_ensemble: 0.3194, used_weights_median: 25
#
# 93
# loss 243612.765625
# nll 1.3777110576629639
# density 0.12779066909715464
#
# val_loss: 245572.6562, val_nll: 2770.0498, val_ensemble: 0.3210, used_weights_median: 24
#
# 94
# loss 234897.0625
# nll 2.2749974727630615
# density 0.12393064064847947
#
# val_loss: 237041.2344, val_nll: 2877.3123, val_ensemble: 0.3184, used_weights_median: 22
#
# 95
# loss 226737.15625
# nll 1.215888500213623
# density 0.1202765146124808
#
# val_loss: 229134.7656, val_nll: 3014.6606, val_ensemble: 0.3184, used_weights_median: 21
#
# 96
# loss 219012.1875
# nll 0.5588704347610474
# density 0.11681308342203815
#
# val_loss: 221586.9219, val_nll: 3230.3855, val_ensemble: 0.3184, used_weights_median: 19
#
# 97
# loss 211747.265625
# nll 0.938500702381134
# density 0.11352592920299856
#
# val_loss: 214364.5781, val_nll: 3244.1807, val_ensemble: 0.3184, used_weights_median: 18
#
# 98
# loss 204898.484375
# nll 0.7997946739196777
# density 0.11040250491455932
#
# val_loss: 207162.6406, val_nll: 2966.3730, val_ensemble: 0.3184, used_weights_median: 17
#
# 99
# loss 198237.1875
# nll 1.3552900552749634
# density 0.10743123375129206
#
# val_loss: 200633.9375, val_nll: 2913.4321, val_ensemble: 0.3189, used_weights_median: 17
#
# 100
# loss 192106.5
# nll 1.4596190452575684
# density 0.10460114661469523
#
# val_loss: 194471.2188, val_nll: 3002.7747, val_ensemble: 0.3184, used_weights_median: 17
#
# 101
# loss 186083.9375
# nll 0.5947729349136353
# density 0.10190291640527478
#
# val_loss: 188639.7656, val_nll: 3085.1816, val_ensemble: 0.3184, used_weights_median: 17
#
# 102
# loss 180453.6875
# nll 0.9656582474708557
# density 0.09932762408342496
#
# val_loss: 182800.0000, val_nll: 2931.7471, val_ensemble: 0.3184, used_weights_median: 15
#
# 103
# loss 175075.3125
# nll 1.0357685089111328
# density 0.09686707281892683
#
# val_loss: 177488.2500, val_nll: 2924.9487, val_ensemble: 0.3184, used_weights_median: 14
#
# 104
# loss 169873.609375
# nll 2.1276917457580566
# density 0.09451404420397656
#
# val_loss: 172384.3906, val_nll: 2926.4976, val_ensemble: 0.3184, used_weights_median: 14
#
# 105
# loss 164913.640625
# nll 1.2752279043197632
# density 0.0922614694506275
#
# val_loss: 167463.3438, val_nll: 2911.9526, val_ensemble: 0.3184, used_weights_median: 14
#
# 106
# loss 160203.0625
# nll 1.3302104473114014
# density 0.09010332059608403
#
# val_loss: 162870.3750, val_nll: 2978.1455, val_ensemble: 0.3184, used_weights_median: 14
#
# 107
# loss 155758.3125
# nll 1.3171346187591553
# density 0.08803387315036675
#
# val_loss: 158180.0000, val_nll: 2841.4683, val_ensemble: 0.3184, used_weights_median: 14
#
# 108
# loss 151436.71875
# nll 0.3766714334487915
# density 0.08604730758372316
#
# val_loss: 154189.0312, val_nll: 3138.5378, val_ensemble: 0.3184, used_weights_median: 14
#
# 109
# loss 147246.296875
# nll 1.2118337154388428
# density 0.08413949241732858
#
# val_loss: 149816.1094, val_nll: 2959.2288, val_ensemble: 0.3184, used_weights_median: 14
#
# 110
# loss 143279.6875
# nll 2.0098345279693604
# density 0.08230544480957203
#
# val_loss: 145978.0781, val_nll: 3056.2642, val_ensemble: 0.3184, used_weights_median: 14
#
# 111
# loss 139410.25
# nll 1.3929450511932373
# density 0.08054130743641735
#
# val_loss: 142374.4219, val_nll: 3276.3306, val_ensemble: 0.3184, used_weights_median: 14
#
# 112
# loss 135786.625
# nll 0.829556405544281
# density 0.0788433352212219
#
# val_loss: 138542.2656, val_nll: 3009.7041, val_ensemble: 0.3184, used_weights_median: 13
#
# 113
# loss 132190.9375
# nll 0.565355658531189
# density 0.0772074488332989
#
# val_loss: 134950.2969, val_nll: 3032.3296, val_ensemble: 0.3184, used_weights_median: 13
#
# 114
# loss 128886.6640625
# nll 1.1309959888458252
# density 0.07563057188738587
#
# val_loss: 131679.3906, val_nll: 3125.5496, val_ensemble: 0.3184, used_weights_median: 13
#
# 115
# loss 125495.0859375
# nll 0.6684030294418335
# density 0.07410978469933051
#
# val_loss: 128250.7578, val_nll: 2909.8489, val_ensemble: 0.3184, used_weights_median: 13
#
# 116
# loss 122424.84375
# nll 0.640647292137146
# density 0.07264168196283677
#
# val_loss: 124931.5312, val_nll: 2857.6055, val_ensemble: 0.3184, used_weights_median: 13
#
# 117
# loss 119294.4296875
# nll 1.3826777935028076
# density 0.07122421663543226
#
# val_loss: 121772.3828, val_nll: 2728.9573, val_ensemble: 0.3205, used_weights_median: 12
#
# 118
# loss 116315.828125
# nll 1.3988118171691895
# density 0.06985462535106038
#
# val_loss: 118808.1641, val_nll: 2747.0225, val_ensemble: 0.3189, used_weights_median: 12
#
# 119
# loss 113485.59375
# nll 1.0819631814956665
# density 0.06853052901918316
#
# val_loss: 115516.6641, val_nll: 2429.8926, val_ensemble: 0.3278, used_weights_median: 12
#
# 120
# loss 110638.7265625
# nll 1.0609380006790161
# density 0.06724950132645924
#
# val_loss: 113160.3906, val_nll: 2748.9766, val_ensemble: 0.3200, used_weights_median: 12
#
# 121
# loss 108033.7265625
# nll 0.5916997790336609
# density 0.06600970317515116
#
# val_loss: 110322.0547, val_nll: 2673.4470, val_ensemble: 0.3231, used_weights_median: 12
#
# 122
# loss 105649.765625
# nll 0.9989309906959534
# density 0.06480892299486989
#
# val_loss: 107835.6172, val_nll: 2706.4775, val_ensemble: 0.3205, used_weights_median: 12
#
# 123
# loss 102866.3046875
# nll 1.7742576599121094
# density 0.06364574723169636
#
# val_loss: 105536.5859, val_nll: 2801.9587, val_ensemble: 0.3200, used_weights_median: 12
#
# 124
# loss 100328.828125
# nll 1.798052191734314
# density 0.06251829421251524
#
# val_loss: 102961.1016, val_nll: 2794.1543, val_ensemble: 0.3194, used_weights_median: 11
#
# 125
# loss 98006.1875
# nll 1.2044947147369385
# density 0.06142496032040151
#
# val_loss: 100947.8750, val_nll: 3043.5847, val_ensemble: 0.3200, used_weights_median: 11
#
# 126
# loss 95719.34375
# nll 0.8325076699256897
# density 0.060364410361703744
#
# val_loss: 98407.6562, val_nll: 2857.1545, val_ensemble: 0.3220, used_weights_median: 10
#
# 127
# loss 93618.9140625
# nll 1.4483591318130493
# density 0.05933519777881892
#
# val_loss: 96104.5469, val_nll: 2866.5264, val_ensemble: 0.3220, used_weights_median: 10
#
# 128
# loss 91546.21875
# nll 0.9049553275108337
# density 0.05833593247943386
#
# val_loss: 94160.9609, val_nll: 2889.8215, val_ensemble: 0.3194, used_weights_median: 10
#
# 129
# loss 89243.53125
# nll 0.9344251751899719
# density 0.05736486102564847
#
# val_loss: 91914.7031, val_nll: 2839.1831, val_ensemble: 0.3220, used_weights_median: 10
#
# 130
# loss 87274.6953125
# nll 0.9690510034561157
# density 0.05642285723717489
#
# val_loss: 90020.5859, val_nll: 3007.9084, val_ensemble: 0.3200, used_weights_median: 10
#
# 131
# loss 85179.734375
# nll 1.8313837051391602
# density 0.05550883338745852
#
# val_loss: 87985.0469, val_nll: 2938.6509, val_ensemble: 0.3210, used_weights_median: 10
#
# 132
# loss 83430.578125
# nll 1.509930968284607
# density 0.05461791049609849
#
# val_loss: 86036.4375, val_nll: 2910.1228, val_ensemble: 0.3210, used_weights_median: 10
#
# 133
# loss 81361.984375
# nll 1.5699281692504883
# density 0.05375079639730292
#
# val_loss: 83888.7188, val_nll: 2745.1785, val_ensemble: 0.3231, used_weights_median: 10
#
# 134
# loss 79473.78125
# nll 0.5180966258049011
# density 0.052906609914063436
#
# val_loss: 82492.4609, val_nll: 3153.4192, val_ensemble: 0.3200, used_weights_median: 10
#
# 135
# loss 77675.7578125
# nll 0.8164252042770386
# density 0.052084865341158325
#
# val_loss: 80703.7344, val_nll: 3109.6689, val_ensemble: 0.3194, used_weights_median: 10
#
# 136
# loss 75861.796875
# nll 1.3358862400054932
# density 0.05128477348923004
#
# val_loss: 78516.0234, val_nll: 2800.8452, val_ensemble: 0.3231, used_weights_median: 10
#
# 137
# loss 74173.046875
# nll 0.8301562666893005
# density 0.050505108753605206
#
# val_loss: 77063.4609, val_nll: 2887.8706, val_ensemble: 0.3231, used_weights_median: 10
#
# 138
# loss 72517.703125
# nll 1.368514060974121
# density 0.04974553935296441
#
# val_loss: 75262.2891, val_nll: 2918.9604, val_ensemble: 0.3231, used_weights_median: 10
#
# 139
# loss 70850.484375
# nll 1.2902092933654785
# density 0.049005041532139436
#
# val_loss: 73989.3359, val_nll: 3047.6323, val_ensemble: 0.3205, used_weights_median: 10
#
# 140
# loss 69328.328125
# nll 1.4351580142974854
# density 0.048283366911540206
#
# val_loss: 71894.0703, val_nll: 2736.4475, val_ensemble: 0.3236, used_weights_median: 10
#
# 141
# loss 67831.1640625
# nll 1.3035743236541748
# density 0.04757918887117657
#
# val_loss: 70250.8125, val_nll: 2785.4419, val_ensemble: 0.3241, used_weights_median: 10
#
# 142
# loss 66264.6953125
# nll 1.0134907960891724
# density 0.0468920915875832
#
# val_loss: 69226.5859, val_nll: 3086.8042, val_ensemble: 0.3220, used_weights_median: 10
#
# 143
# loss 64686.95703125
# nll 0.8867805004119873
# density 0.046221689548573384
#
# val_loss: 67736.1406, val_nll: 3101.7070, val_ensemble: 0.3200, used_weights_median: 10
#
# 144
# loss 63315.328125
# nll 1.000241994857788
# density 0.045567342055984665
#
# val_loss: 65981.4922, val_nll: 2884.3191, val_ensemble: 0.3215, used_weights_median: 10
#
# 145
# loss 61766.58984375
# nll 0.3416224718093872
# density 0.04492834383733785
#
# val_loss: 64659.9883, val_nll: 2970.9822, val_ensemble: 0.3220, used_weights_median: 10
#
# 146
# loss 60420.75390625
# nll 1.0794968605041504
# density 0.04430409376700211
#
# val_loss: 63421.3555, val_nll: 3202.7175, val_ensemble: 0.3200, used_weights_median: 10
#
# 147
# loss 59362.76953125
# nll 0.6564378142356873
# density 0.04369430317365705
#
# val_loss: 61960.7578, val_nll: 2953.0518, val_ensemble: 0.3205, used_weights_median: 10
#
# 148
# loss 57751.08203125
# nll 1.8729265928268433
# density 0.04310063199593807
#
# val_loss: 60481.0273, val_nll: 2868.2185, val_ensemble: 0.3220, used_weights_median: 10
#
# 149
# loss 56396.8828125
# nll 1.0080053806304932
# density 0.04251939730559349
#
# val_loss: 59278.7344, val_nll: 2910.3965, val_ensemble: 0.3210, used_weights_median: 10
#
# 150
# loss 55245.078125
# nll 0.7325047254562378
# density 0.04194999262734756
#
# val_loss: 58424.2500, val_nll: 3015.9985, val_ensemble: 0.3220, used_weights_median: 10
#
# 151
# loss 53894.0546875
# nll 0.33529433608055115
# density 0.041393322273617264
#
# val_loss: 57008.3477, val_nll: 3192.5408, val_ensemble: 0.3210, used_weights_median: 10
#
# 152
# loss 52707.765625
# nll 0.9784868359565735
# density 0.04084912662553963
#
# val_loss: 55344.2891, val_nll: 2911.6074, val_ensemble: 0.3210, used_weights_median: 10
#
# 153
# loss 51813.7109375
# nll 1.1113255023956299
# density 0.04031645653932833
#
# val_loss: 54566.9570, val_nll: 3098.6804, val_ensemble: 0.3220, used_weights_median: 10
#
# 154
# loss 50455.01171875
# nll 1.3756532669067383
# density 0.03979504171312003
#
# val_loss: 53081.9297, val_nll: 2829.1104, val_ensemble: 0.3200, used_weights_median: 10
#
# 155
# loss 49061.8984375
# nll 1.7961145639419556
# density 0.039284810844288996
#
# val_loss: 51798.3281, val_nll: 2616.4927, val_ensemble: 0.3335, used_weights_median: 10
#
# 156
# loss 47937.7734375
# nll 1.2108843326568604
# density 0.0387875393531652
#
# val_loss: 50782.0039, val_nll: 2913.3157, val_ensemble: 0.3220, used_weights_median: 10
#
# 157
# loss 46906.38671875
# nll 0.6179004907608032
# density 0.03830011731655734
#
# val_loss: 49945.3086, val_nll: 3097.7617, val_ensemble: 0.3236, used_weights_median: 10
#
# 158
# loss 45703.46875
# nll 0.8723447918891907
# density 0.03782173363448339
#
# val_loss: 49191.9922, val_nll: 3286.7412, val_ensemble: 0.3226, used_weights_median: 10
#
# 159
# loss 44771.18359375
# nll 0.7292470335960388
# density 0.03735265627350001
#
# val_loss: 47719.5352, val_nll: 2986.8337, val_ensemble: 0.3231, used_weights_median: 10
#
# 160
# loss 43495.05859375
# nll 0.9634729623794556
# density 0.03689292957624502
#
# val_loss: 46332.9531, val_nll: 2847.8940, val_ensemble: 0.3210, used_weights_median: 10
#
# 161
# loss 42597.72265625
# nll 0.5652415752410889
# density 0.03644260631802492
#
# val_loss: 45250.1445, val_nll: 2805.9712, val_ensemble: 0.3241, used_weights_median: 10
#
# 162
# loss 41832.56640625
# nll 0.9519578218460083
# density 0.0360011728017329
#
# val_loss: 44815.4180, val_nll: 2752.5007, val_ensemble: 0.3205, used_weights_median: 10
#
# 163
# loss 40481.29296875
# nll 0.8253868222236633
# density 0.03556849655381526
#
# val_loss: 43426.3086, val_nll: 3006.6580, val_ensemble: 0.3210, used_weights_median: 10
#
# 164
# loss 39638.9140625
# nll 0.696792483329773
# density 0.03514406425103942
#
# val_loss: 43077.0664, val_nll: 3388.0649, val_ensemble: 0.3236, used_weights_median: 10
#
# 165
# loss 38513.01171875
# nll 1.0697245597839355
# density 0.03472812640256705
#
# val_loss: 41560.8750, val_nll: 2876.3618, val_ensemble: 0.3236, used_weights_median: 10
#
# 166
# loss 37598.33203125
# nll 1.5401617288589478
# density 0.03431998202361974
#
# val_loss: 40222.9492, val_nll: 2774.8867, val_ensemble: 0.3283, used_weights_median: 9
#
# 167
# loss 36617.78515625
# nll 1.626582145690918
# density 0.03391977670205486
#
# val_loss: 41499.1484, val_nll: 2681.9536, val_ensemble: 0.3273, used_weights_median: 9
#
# 168
# loss 35783.4375
# nll 0.8209843039512634
# density 0.033526940177378256
#
# val_loss: 38447.6328, val_nll: 2872.2112, val_ensemble: 0.3226, used_weights_median: 9
#
# 169
# loss 35069.1171875
# nll 0.9289814829826355
# density 0.033141472287188965
#
# val_loss: 37513.1914, val_nll: 2791.2854, val_ensemble: 0.3246, used_weights_median: 9
#
# 170
# loss 33869.8984375
# nll 0.9078226089477539
# density 0.0327661144122368
#
# val_loss: 36441.7734, val_nll: 2522.9446, val_ensemble: 0.3382, used_weights_median: 9
#
# 171
# loss 32977.2109375
# nll 1.6669965982437134
# density 0.032396539918330636
#
# val_loss: 35610.7656, val_nll: 2711.7595, val_ensemble: 0.3304, used_weights_median: 10
#
# 172
# loss 32168.6484375
# nll 1.207810401916504
# density 0.03203255424198921
#
# val_loss: 34886.4648, val_nll: 2885.5374, val_ensemble: 0.3205, used_weights_median: 10
#
# 173
# loss 31798.93359375
# nll 2.1829419136047363
# density 0.03167473870898468
#
# val_loss: 34422.5625, val_nll: 2796.3762, val_ensemble: 0.3220, used_weights_median: 9
#
# 174
# loss 31911.03125
# nll 3.053731918334961
# density 0.031327586421637084
#
# val_loss: 33552.7305, val_nll: 2914.1780, val_ensemble: 0.3220, used_weights_median: 10
#
# 175
# loss 29911.037109375
# nll 1.732788324356079
# density 0.03098385797502263
#
# val_loss: 33539.8203, val_nll: 2932.9370, val_ensemble: 0.3252, used_weights_median: 10
#
# 176
# loss 29019.5
# nll 0.11629822850227356
# density 0.030645032318294935
#
# val_loss: 31671.8652, val_nll: 3056.7356, val_ensemble: 0.3220, used_weights_median: 10
#
# 177
# loss 28245.765625
# nll 1.263178825378418
# density 0.030312057186372504
#
# val_loss: 30867.8301, val_nll: 2640.1707, val_ensemble: 0.3372, used_weights_median: 10
#
# 178
# loss 27351.513671875
# nll 0.5752044320106506
# density 0.02998557036765991
#
# val_loss: 30185.9980, val_nll: 2884.0559, val_ensemble: 0.3278, used_weights_median: 10
#
# 179
# loss 26566.173828125
# nll 1.2285876274108887
# density 0.029664122682433392
#
# val_loss: 29221.2520, val_nll: 2775.9441, val_ensemble: 0.3288, used_weights_median: 10
#
# 180
# loss 25953.91015625
# nll 1.4927220344543457
# density 0.02935279294747601
#
# val_loss: 28593.8301, val_nll: 2855.2048, val_ensemble: 0.3273, used_weights_median: 10
#
# 181
# loss 25150.2265625
# nll 0.7622036337852478
# density 0.029043946523717157
#
# val_loss: 27910.6523, val_nll: 3035.4221, val_ensemble: 0.3231, used_weights_median: 10
#
# 182
# loss 24313.1796875
# nll 2.1637845039367676
# density 0.028738951769976026
#
# val_loss: 27043.1895, val_nll: 2677.1277, val_ensemble: 0.3309, used_weights_median: 10
#
# 183
# loss 23994.265625
# nll 0.5163275599479675
# density 0.028438492249797474
#
# val_loss: 26518.7656, val_nll: 2912.7971, val_ensemble: 0.3220, used_weights_median: 10
#
# 184
# loss 22750.4765625
# nll 2.0344021320343018
# density 0.028143680635981744
#
# val_loss: 25213.4160, val_nll: 2600.7751, val_ensemble: 0.3382, used_weights_median: 10
#
# 185
# loss 22035.087890625
# nll 1.3406245708465576
# density 0.027853659684933408
#
# val_loss: 24956.3164, val_nll: 2829.5078, val_ensemble: 0.3262, used_weights_median: 10
#
# 186
# loss 21237.787109375
# nll 0.6694311499595642
# density 0.027568313531394655
#
# val_loss: 23958.0664, val_nll: 2576.0967, val_ensemble: 0.3304, used_weights_median: 10
#
# 187
# loss 20588.17578125
# nll 1.9342390298843384
# density 0.027287161977925255
#
# val_loss: 23568.2441, val_nll: 2812.5950, val_ensemble: 0.3236, used_weights_median: 10
#
# 188
# loss 20791.919921875
# nll 0.6491937041282654
# density 0.027010681481483115
#
# val_loss: 23147.0371, val_nll: 2416.5046, val_ensemble: 0.3512, used_weights_median: 10
#
# 189
# loss 20401.59375
# nll 0.4345492422580719
# density 0.026738982867792745
#
# val_loss: 23118.1660, val_nll: 2768.4412, val_ensemble: 0.3288, used_weights_median: 10
#
# 190
# loss 19415.248046875
# nll 1.2425519227981567
# density 0.026471955627896584
#
# val_loss: 21469.1797, val_nll: 2590.3396, val_ensemble: 0.3351, used_weights_median: 10
#
# 191
# loss 17848.291015625
# nll 0.6388712525367737
# density 0.026209095874899578
#
# val_loss: 21195.8867, val_nll: 2466.8159, val_ensemble: 0.3377, used_weights_median: 10
#
# 192
# loss 17884.970703125
# nll 1.1336103677749634
# density 0.02595019902590879
#
# val_loss: 20443.5039, val_nll: 2753.8042, val_ensemble: 0.3241, used_weights_median: 10
#
# 193
# loss 16697.373046875
# nll 0.256379097700119
# density 0.025696064953924937
#
# val_loss: 19282.6035, val_nll: 2614.9819, val_ensemble: 0.3257, used_weights_median: 10
#
# 194
# loss 16667.453125
# nll 1.0241953134536743
# density 0.025444989473538158
#
# val_loss: 18705.6250, val_nll: 2601.3367, val_ensemble: 0.3351, used_weights_median: 10
#
# 195
# loss 15733.857421875
# nll 2.0570573806762695
# density 0.025198163160605518
#
# val_loss: 18252.5879, val_nll: 2718.0635, val_ensemble: 0.3345, used_weights_median: 10
#
# 196
# loss 14927.9775390625
# nll 1.098652720451355
# density 0.024955159969901407
#
# val_loss: 17376.5684, val_nll: 2411.2336, val_ensemble: 0.3392, used_weights_median: 10
#
# 197
# loss 16430.197265625
# nll 1.5054638385772705
# density 0.02471608471898856
#
# val_loss: 17150.8281, val_nll: 2522.5388, val_ensemble: 0.3356, used_weights_median: 10
#
# 198
# loss 15613.77734375
# nll 0.6579662561416626
# density 0.024482212494235676
#
# val_loss: 16727.8145, val_nll: 2669.2258, val_ensemble: 0.3293, used_weights_median: 10
#
# 199
# loss 13443.357421875
# nll 1.1755647659301758
# density 0.024252229525875402
#
# val_loss: 17978.6758, val_nll: 3564.6655, val_ensemble: 0.3200, used_weights_median: 10
#
# 200
# loss 13109.7666015625
# nll 2.16241455078125
# density 0.0240244266323457
#
# val_loss: 16016.3730, val_nll: 3219.5193, val_ensemble: 0.3189, used_weights_median: 10
#
# 201
# loss 11968.271484375
# nll 0.9339142441749573
# density 0.023799269671787353
#
# val_loss: 15546.2295, val_nll: 3346.0850, val_ensemble: 0.3189, used_weights_median: 10
#
# 202
# loss 11294.19140625
# nll 1.1697490215301514
# density 0.023577224835264286
#
# val_loss: 15017.4619, val_nll: 3106.9502, val_ensemble: 0.3215, used_weights_median: 10
#
# 203
# loss 10823.5458984375
# nll 1.420668125152588
# density 0.02335869709324447
#
# val_loss: 14691.7012, val_nll: 2942.6960, val_ensemble: 0.3215, used_weights_median: 10
#
# 204
# loss 10392.6279296875
# nll 0.34112441539764404
# density 0.023143758579454346
#
# val_loss: 13861.6348, val_nll: 3414.0720, val_ensemble: 0.3194, used_weights_median: 10
#
# 205
# loss 9624.76953125
# nll 0.3686845302581787
# density 0.022931765047885216
#
# val_loss: 12852.4492, val_nll: 3015.0513, val_ensemble: 0.3215, used_weights_median: 10
#
# 206
# loss 9157.6572265625
# nll 1.4348223209381104
# density 0.022722389395552465
#
# val_loss: 11903.1670, val_nll: 3051.7781, val_ensemble: 0.3205, used_weights_median: 10
#
# 207
# loss 8829.646484375
# nll 1.0651986598968506
# density 0.022516287601156922
#
# val_loss: 11960.5869, val_nll: 2989.2375, val_ensemble: 0.3236, used_weights_median: 10
#
# 208
# loss 8777.2060546875
# nll 0.9417905211448669
# density 0.022313013056234902
#
# val_loss: 12542.3711, val_nll: 3414.0173, val_ensemble: 0.3189, used_weights_median: 10
#
# 209
# loss 7296.9658203125
# nll 0.8359165787696838
# density 0.02211186236589353
#
# val_loss: 10210.8770, val_nll: 2649.4385, val_ensemble: 0.3392, used_weights_median: 10
#
# 210
# loss 7018.59521484375
# nll 1.4801311492919922
# density 0.021914051706872065
#
# val_loss: 10167.4150, val_nll: 3336.4861, val_ensemble: 0.3226, used_weights_median: 10
#
# 211
# loss 6409.02587890625
# nll 2.2788867950439453
# density 0.021718498595038726
#
# val_loss: 9409.0742, val_nll: 2743.9124, val_ensemble: 0.3273, used_weights_median: 10
#
# 212
# loss 6169.33544921875
# nll 1.79429292678833
# density 0.021526251802578056
#
# val_loss: 9417.7646, val_nll: 2911.7283, val_ensemble: 0.3226, used_weights_median: 10
#
# 213
# loss 5814.93017578125
# nll 1.2932310104370117
# density 0.02133889780150697
#
# val_loss: 8926.8047, val_nll: 2854.0569, val_ensemble: 0.3262, used_weights_median: 10
#
# 214
# loss 5823.666015625
# nll 1.3888614177703857
# density 0.021152521688747285
#
# val_loss: 8379.8594, val_nll: 2957.8635, val_ensemble: 0.3257, used_weights_median: 10
#
# 215
# loss 5114.76708984375
# nll 0.38422176241874695
# density 0.02096858433945603
#
# val_loss: 7400.3521, val_nll: 2484.6519, val_ensemble: 0.3460, used_weights_median: 10
#
# 216
# loss 4389.60498046875
# nll 1.263149380683899
# density 0.02078690136722982
#
# val_loss: 6896.1982, val_nll: 2529.5264, val_ensemble: 0.3418, used_weights_median: 10
#
# 217
# loss 4711.2548828125
# nll 1.7196186780929565
# density 0.020607629714393304
#
# val_loss: 7015.0371, val_nll: 2632.3499, val_ensemble: 0.3345, used_weights_median: 10
#
# 218
# loss 3194.87548828125
# nll 1.3715300559997559
# density 0.020430267179264296
#
# val_loss: 6022.8115, val_nll: 2760.8916, val_ensemble: 0.3236, used_weights_median: 10
#
# 219
# loss 2539.19482421875
# nll 2.05610728263855
# density 0.0202554348325658
#
# val_loss: 5897.8779, val_nll: 2754.0833, val_ensemble: 0.3283, used_weights_median: 10
#
# 220
# loss 2703.546630859375
# nll 1.2067251205444336
# density 0.02008350241389482
#
# val_loss: 4706.8833, val_nll: 2033.6185, val_ensemble: 0.4424, used_weights_median: 10
#
# 221
# loss 2418.182373046875
# nll 0.7342026829719543
# density 0.019914690948405808
#
# val_loss: 6653.0732, val_nll: 2267.8899, val_ensemble: 0.3663, used_weights_median: 10
#
# 222
# loss 3051.855224609375
# nll 1.282017469406128
# density 0.019747847601731188
#
# val_loss: 3613.6519, val_nll: 2366.3726, val_ensemble: 0.3538, used_weights_median: 10
#
# 223
# loss 1391.80810546875
# nll 1.7045577764511108
# density 0.019582390314397922
#
# val_loss: 3095.5071, val_nll: 2665.7161, val_ensemble: 0.3372, used_weights_median: 10
#
# 224
# loss 315.12213134765625
# nll 2.034231662750244
# density 0.019422948657526282
#
# val_loss: 11838.3125, val_nll: 2586.0579, val_ensemble: 0.3403, used_weights_median: 10
#
# 225
# loss 285.7530822753906
# nll 0.5665554404258728
# density 0.01926437963350783
#
# val_loss: 2895.7134, val_nll: 2873.6743, val_ensemble: 0.3236, used_weights_median: 10
#
# 226
# loss 1734.60888671875
# nll 2.932074546813965
# density 0.01910669035553959
#
# val_loss: 3148.9097, val_nll: 2713.5483, val_ensemble: 0.3335, used_weights_median: 10
#
# 227
# loss 1655.0543212890625
# nll 1.8297343254089355
# density 0.01895136239550344
#
# val_loss: 1553.1306, val_nll: 2839.2976, val_ensemble: 0.3267, used_weights_median: 10
#
# 228
# loss 1285.2711181640625
# nll 0.45863789319992065
# density 0.01879818825801665
#
# val_loss: 3333.3557, val_nll: 2289.8362, val_ensemble: 0.3783, used_weights_median: 10
#
# 229
# loss -137.57371520996094
# nll 1.1528525352478027
# density 0.018645620912137492
#
# val_loss: 1492.1692, val_nll: 2502.9045, val_ensemble: 0.3471, used_weights_median: 10
#
# 230
# loss -1538.7957763671875
# nll 3.101724863052368
# density 0.01849588917142526
#
# val_loss: 1593.0723, val_nll: 2219.1680, val_ensemble: 0.3960, used_weights_median: 10
#
# 231
# loss -1516.4423828125
# nll 0.4072791039943695
# density 0.01834634283515031
#
# val_loss: 1734.6946, val_nll: 2945.2268, val_ensemble: 0.3273, used_weights_median: 10
#
# 232
# loss -2771.70751953125
# nll 2.8824045658111572
# density 0.018199015568000115
#
# val_loss: 1422.5042, val_nll: 2471.7942, val_ensemble: 0.3471, used_weights_median: 10
#
# 233
# loss -2424.39892578125
# nll 2.5111544132232666
# density 0.018050714662623753
#
# val_loss: 19.0139, val_nll: 2843.5002, val_ensemble: 0.3299, used_weights_median: 10
#
# 234
# loss -3692.1630859375
# nll 2.06632661819458
# density 0.017906850802878658
#
# val_loss: 719.4976, val_nll: 3254.6851, val_ensemble: 0.3189, used_weights_median: 10
#
# 235
# loss -1091.9332275390625
# nll 0.06966997683048248
# density 0.017769029534978446
#
# val_loss: -751.3403, val_nll: 3065.8960, val_ensemble: 0.3257, used_weights_median: 10
#
# 236
# loss -1747.1568603515625
# nll 2.8382229804992676
# density 0.017634619905181764
#
# val_loss: 1658.4854, val_nll: 3457.1299, val_ensemble: 0.3194, used_weights_median: 10
#
# 237
# loss -1972.4156494140625
# nll 0.15367387235164642
# density 0.01749910461829581
#
# val_loss: 1000.2615, val_nll: 3138.3220, val_ensemble: 0.3304, used_weights_median: 10
#
# 238
# loss -4775.4501953125
# nll 0.5779141783714294
# density 0.017361699231630567
#
# val_loss: -1004.1187, val_nll: 3373.9048, val_ensemble: 0.3215, used_weights_median: 10
#
# 239
# loss -4027.62158203125
# nll 0.2875511050224304
# density 0.01722741236921136
#
# val_loss: -155.0603, val_nll: 3303.9397, val_ensemble: 0.3226, used_weights_median: 10
#
# 240
# loss -4779.263671875
# nll 0.39565372467041016
# density 0.017094989577835548
#
# val_loss: -620.0071, val_nll: 3448.9685, val_ensemble: 0.3194, used_weights_median: 10
#
# 241
# loss 7170.27587890625
# nll 0.025731787085533142
# density 0.016959682396490254
#
# val_loss: -2330.2566, val_nll: 2853.3586, val_ensemble: 0.3309, used_weights_median: 10
#
# 242
# loss 9649.3544921875
# nll 0.9225960373878479
# density 0.016822533516879363
#
# val_loss: -1445.4121, val_nll: 3314.1133, val_ensemble: 0.3226, used_weights_median: 10
#
# 243
# loss -2006.0654296875
# nll 0.23336921632289886
# density 0.016686993498399708
#
# val_loss: 1216.2742, val_nll: 2704.0984, val_ensemble: 0.3377, used_weights_median: 10
#
# 244
# loss -1604.607177734375
# nll 0.2893177270889282
# density 0.01654918326035689
#
# val_loss: 197.7070, val_nll: 3261.1553, val_ensemble: 0.3262, used_weights_median: 10
#
# 245
# loss -6073.28515625
# nll 0.6472508907318115
# density 0.016419903664530916
#
# val_loss: -2909.7959, val_nll: 2639.0801, val_ensemble: 0.3356, used_weights_median: 10
#
# 246
# loss -5001.904296875
# nll 0.09390243142843246
# density 0.01630261056275046
#
# val_loss: -1610.9563, val_nll: 2692.9187, val_ensemble: 0.3345, used_weights_median: 10
#
# 247
# loss -5462.3857421875
# nll 0.11139200627803802
# density 0.016188991070622286
#
# val_loss: -2344.8350, val_nll: 2791.4160, val_ensemble: 0.3304, used_weights_median: 10
#
# 248
# loss -6209.00146484375
# nll 0.5950871109962463
# density 0.016076750489092403
#
# val_loss: -3923.3167, val_nll: 2821.5164, val_ensemble: 0.3288, used_weights_median: 10
#
# 249
# loss -5469.84423828125
# nll 0.8161371350288391
# density 0.01596870361523003
#
# val_loss: -4375.4844, val_nll: 2360.2595, val_ensemble: 0.3731, used_weights_median: 10
#
# 250
# loss -6946.19091796875
# nll 1.2972681522369385
# density 0.01586134736429859
#
# val_loss: -3993.2632, val_nll: 3095.0659, val_ensemble: 0.3241, used_weights_median: 10
#
# 251
# loss -6048.9833984375
# nll 0.47477394342422485
# density 0.015753643772828268
#
# val_loss: -3619.8989, val_nll: 2898.8335, val_ensemble: 0.3299, used_weights_median: 10
#
# 252
# loss -7021.72021484375
# nll 0.25940796732902527
# density 0.015646874910339375
#
# val_loss: -4447.5615, val_nll: 2281.6631, val_ensemble: 0.3835, used_weights_median: 10
#
# 253
# loss -6708.19873046875
# nll 2.200911283493042
# density 0.015540804051673124
#
# val_loss: -5118.5122, val_nll: 2189.9692, val_ensemble: 0.4007, used_weights_median: 10
#
# 254
# loss -8647.970703125
# nll 0.6931705474853516
# density 0.01543899457497066
#
# val_loss: -6252.1504, val_nll: 2354.3542, val_ensemble: 0.3710, used_weights_median: 10
#
# 255
# loss -5762.44287109375
# nll 0.8746620416641235
# density 0.015338090572788489
#
# val_loss: -5254.6660, val_nll: 2208.7285, val_ensemble: 0.4065, used_weights_median: 10
#
# 256
# loss -9721.734375
# nll 1.454681396484375
# density 0.015238026633300763
#
# val_loss: -6955.9224, val_nll: 2957.8120, val_ensemble: 0.3267, used_weights_median: 10
#
# 257
# loss -8257.173828125
# nll 0.8552238345146179
# density 0.015138864008439938
#
# val_loss: -7146.3296, val_nll: 2215.8560, val_ensemble: 0.3986, used_weights_median: 10
#
# 258
# loss -9944.818359375
# nll 0.816832959651947
# density 0.015039781477759516
#
# val_loss: -7390.4702, val_nll: 2213.2095, val_ensemble: 0.3929, used_weights_median: 10
#
# 259
# loss -9409.9130859375
# nll 0.4680061638355255
# density 0.014938578819858243
#
# val_loss: -8475.7324, val_nll: 2120.3074, val_ensemble: 0.4106, used_weights_median: 10
#
# 260
# loss -10640.6943359375
# nll 0.6129373908042908
# density 0.014835284880572678
#
# val_loss: -8640.2305, val_nll: 2308.1389, val_ensemble: 0.3731, used_weights_median: 10
#
# 261
# loss -11322.1083984375
# nll 0.4516017735004425
# density 0.014736237443451034
#
# val_loss: -8511.4766, val_nll: 2364.5542, val_ensemble: 0.3648, used_weights_median: 10
#
# 262
# loss -11391.0634765625
# nll 1.1005700826644897
# density 0.014641746532276475
#
# val_loss: -8187.8154, val_nll: 2185.5789, val_ensemble: 0.3981, used_weights_median: 10
#
# 263
# loss -10964.8037109375
# nll 1.9506170749664307
# density 0.014548587881756678
#
# val_loss: -7620.2891, val_nll: 2341.1250, val_ensemble: 0.3669, used_weights_median: 10
#
# 264
# loss -9841.1533203125
# nll 0.5345373749732971
# density 0.014455370218226439
#
# val_loss: -9531.0254, val_nll: 2084.1809, val_ensemble: 0.4174, used_weights_median: 10
#
# 265
# loss -10735.984375
# nll 0.32230737805366516
# density 0.014359273284147473
#
# val_loss: -9725.6992, val_nll: 2218.4956, val_ensemble: 0.3867, used_weights_median: 10
#
# 266
# loss -7645.25244140625
# nll 1.9585018157958984
# density 0.014264016363361451
#
# val_loss: -6722.5107, val_nll: 2179.3992, val_ensemble: 0.4023, used_weights_median: 10
#
# 267
# loss -1788.1541748046875
# nll 5.424886703491211
# density 0.014157354118717116
#
# val_loss: -8043.2109, val_nll: 2222.6250, val_ensemble: 0.3783, used_weights_median: 10
#
# 268
# loss -10958.4599609375
# nll 0.2355048507452011
# density 0.014060725786099853
#
# val_loss: -9446.4219, val_nll: 2122.6494, val_ensemble: 0.4049, used_weights_median: 10
#
# 269
# loss -8958.822265625
# nll 0.9579697251319885
# density 0.013975240010841078
#
# val_loss: -9465.7402, val_nll: 2132.8647, val_ensemble: 0.4091, used_weights_median: 10
#
# 270
# loss -11460.615234375
# nll 2.7650465965270996
# density 0.013889282241284242
#
# val_loss: -7450.1504, val_nll: 2189.1614, val_ensemble: 0.4096, used_weights_median: 10
#
# 271
# loss -12176.0263671875
# nll 3.6444332599639893
# density 0.013804804571794135
#
# val_loss: -9915.5537, val_nll: 2206.9724, val_ensemble: 0.3986, used_weights_median: 10
#
# 272
# loss -12895.0712890625
# nll 1.596971035003662
# density 0.013721188998911131
#
# val_loss: -11003.1406, val_nll: 2318.6641, val_ensemble: 0.3814, used_weights_median: 10
#
# 273
# loss -11031.7548828125
# nll 1.535776138305664
# density 0.013640061008939745
#
# val_loss: -11167.7773, val_nll: 2286.0342, val_ensemble: 0.3913, used_weights_median: 10
#
# 274
# loss -12506.53125
# nll 0.31032171845436096
# density 0.013562455710574788
#
# val_loss: -9867.4531, val_nll: 2596.0601, val_ensemble: 0.3497, used_weights_median: 10
#
# 275
# loss -12468.0419921875
# nll 2.7952771186828613
# density 0.013483016433054369
#
# val_loss: -11592.1484, val_nll: 2355.5867, val_ensemble: 0.3814, used_weights_median: 10
#
# 276
# loss -13029.1318359375
# nll 2.114521026611328
# density 0.013400490362620593
#
# val_loss: -6989.4072, val_nll: 2502.4668, val_ensemble: 0.3465, used_weights_median: 10
#
# 277
# loss -13248.9609375
# nll 4.120640277862549
# density 0.013315911816760336
#
# val_loss: -10835.7119, val_nll: 2495.1072, val_ensemble: 0.3559, used_weights_median: 10
#
# 278
# loss -13650.359375
# nll 1.1352474689483643
# density 0.013229498707206555
#
# val_loss: -8628.0488, val_nll: 2843.1536, val_ensemble: 0.3267, used_weights_median: 10
#
# 279
# loss -13277.0537109375
# nll 1.7678710222244263
# density 0.013145795565694698
#
# val_loss: -10617.1152, val_nll: 2472.1650, val_ensemble: 0.3538, used_weights_median: 10
#
# 280
# loss -14584.8173828125
# nll 0.5373873710632324
# density 0.013064669497645167
#
# val_loss: -11715.5000, val_nll: 2237.4993, val_ensemble: 0.3940, used_weights_median: 10
#
# 281
# loss -14474.1669921875
# nll 0.9631423354148865
# density 0.012985189812470998
#
# val_loss: -10910.4268, val_nll: 3335.6970, val_ensemble: 0.3220, used_weights_median: 10
#
# 282
# loss -15142.669921875
# nll 1.1734371185302734
# density 0.012909242856550452
#
# val_loss: -13304.4268, val_nll: 2198.5488, val_ensemble: 0.3997, used_weights_median: 10
#
# 283
# loss -15725.4970703125
# nll 3.116701602935791
# density 0.012835687471759316
#
# val_loss: -9543.4531, val_nll: 2589.8206, val_ensemble: 0.3382, used_weights_median: 10
#
# 284
# loss -16168.30078125
# nll 4.219191551208496
# density 0.012763670793227667
#
# val_loss: -12219.8604, val_nll: 2280.2830, val_ensemble: 0.3851, used_weights_median: 10
#
# 285
# loss -13600.576171875
# nll 0.7817456722259521
# density 0.012691629999380567
#
# val_loss: -13399.6445, val_nll: 2599.4556, val_ensemble: 0.3319, used_weights_median: 10
#
# 286
# loss -16953.5234375
# nll 0.011242847889661789
# density 0.012619090014728593
#
# val_loss: -11360.9082, val_nll: 3301.0415, val_ensemble: 0.3236, used_weights_median: 10
#
# 287
# loss -16866.642578125
# nll 0.3412066400051117
# density 0.012543569862721416
#
# val_loss: -13478.0967, val_nll: 3181.3582, val_ensemble: 0.3257, used_weights_median: 10
#
# 288
# loss -15849.580078125
# nll 0.6793673038482666
# density 0.01246858903148343
#
# val_loss: -13408.7344, val_nll: 2609.0352, val_ensemble: 0.3330, used_weights_median: 10
#
# 289
# loss -14688.44140625
# nll 0.19589608907699585
# density 0.012394243663620285
#
# val_loss: -4064.5229, val_nll: 2211.5181, val_ensemble: 0.3981, used_weights_median: 10
#
# 290
# loss -14632.3623046875
# nll 0.303774893283844
# density 0.012321549187844366
#
# ...
#
# 1106
# loss -47215.23828125
# nll 1.1240036487579346
# density 0.004693672297928949
#
# val_loss: -43957.8594, val_nll: 1804.8240, val_ensemble: 0.5503, used_weights_median: 10
#
# 1107
# loss -47507.640625
# nll 1.031620740890503
# density 0.004693672297928949
#
# val_loss: -45827.4531, val_nll: 1812.1176, val_ensemble: 0.5472, used_weights_median: 10
#
# 1108
# loss -45796.29296875
# nll 1.1378923654556274
# density 0.004693672297928949
#
# val_loss: -43652.9570, val_nll: 1808.2568, val_ensemble: 0.5487, used_weights_median: 10
#
# 1109
# loss -47332.9296875
# nll 1.3593302965164185
# density 0.004693672297928949
#
# val_loss: -45008.6211, val_nll: 1831.9553, val_ensemble: 0.5456, used_weights_median: 10
#
# 1110
# loss -47649.5703125
# nll 1.038166880607605
# density 0.004693672297928949
#
# val_loss: -45238.7109, val_nll: 1834.8773, val_ensemble: 0.5451, used_weights_median: 10
#
# 1111
# loss -46684.546875
# nll 1.0076667070388794
# density 0.004693672297928949
#
# val_loss: -44522.4023, val_nll: 1812.2650, val_ensemble: 0.5576, used_weights_median: 10
#
# 1112
# loss -47867.69921875
# nll 1.119362711906433
# density 0.004693672297928949
#
# val_loss: -44366.8047, val_nll: 1813.6345, val_ensemble: 0.5477, used_weights_median: 10
#
# 1113
# loss -45962.98046875
# nll 1.2183597087860107
# density 0.004693672297928949
#
# val_loss: -44039.5977, val_nll: 1828.6437, val_ensemble: 0.5482, used_weights_median: 10
#
# 1114
# loss -47760.484375
# nll 1.2496898174285889
# density 0.004693672297928949
#
# val_loss: -45809.7812, val_nll: 1814.6156, val_ensemble: 0.5565, used_weights_median: 10
#
# 1115
# loss -47096.04296875
# nll 1.3359565734863281
# density 0.004693672297928949
#
# val_loss: -42993.3086, val_nll: 1816.7701, val_ensemble: 0.5524, used_weights_median: 10
#
# 1116
# loss -43661.859375
# nll 1.290245771408081
# density 0.004693672297928949
#
# val_loss: -42736.9102, val_nll: 1826.4120, val_ensemble: 0.5414, used_weights_median: 10
#
# 1117
# loss -47999.99609375
# nll 1.1624033451080322
# density 0.004693672297928949
#
# val_loss: -43592.5547, val_nll: 1816.2102, val_ensemble: 0.5472, used_weights_median: 10
#
# 1118
# loss -47924.23828125
# nll 1.223587989807129
# density 0.004693672297928949
#
# val_loss: -44771.6289, val_nll: 1815.4686, val_ensemble: 0.5446, used_weights_median: 10
#
# 1119
# loss -47845.81640625
# nll 1.1448352336883545
# density 0.004693672297928949
#
# val_loss: -46019.8359, val_nll: 1813.7428, val_ensemble: 0.5425, used_weights_median: 10
#
# 1120
# loss -48102.23046875
# nll 1.0689105987548828
# density 0.004693672297928949
#
# val_loss: -46315.6992, val_nll: 1820.0664, val_ensemble: 0.5482, used_weights_median: 10
#
# 1121
# loss -47584.11328125
# nll 1.318995714187622
# density 0.004693672297928949
#
# val_loss: -46001.8047, val_nll: 1822.6250, val_ensemble: 0.5378, used_weights_median: 10
#
# 1122
# loss -48181.546875
# nll 1.107822060585022
# density 0.004693672297928949
#
# val_loss: -46001.1055, val_nll: 1815.0657, val_ensemble: 0.5545, used_weights_median: 10
#
# 1123
# loss -47966.65625
# nll 1.0108654499053955
# density 0.004693672297928949
#
# val_loss: -45869.8320, val_nll: 1811.2518, val_ensemble: 0.5435, used_weights_median: 10
#
# 1124
# loss -48137.57421875
# nll 1.015878438949585
# density 0.004693672297928949
#
# val_loss: -46449.1914, val_nll: 1819.9017, val_ensemble: 0.5451, used_weights_median: 10
#
# 1125
# loss -47715.12890625
# nll 1.3695683479309082
# density 0.004693672297928949
#
# val_loss: -46050.6953, val_nll: 1824.2512, val_ensemble: 0.5482, used_weights_median: 10
#
# 1126
# loss -48325.62109375
# nll 1.4542195796966553
# density 0.004693672297928949
#
# val_loss: -46261.2461, val_nll: 1811.0200, val_ensemble: 0.5539, used_weights_median: 10
#
# 1127
# loss -48389.50390625
# nll 0.8830273151397705
# density 0.004693672297928949
#
# val_loss: -46662.3516, val_nll: 1808.8339, val_ensemble: 0.5503, used_weights_median: 10
#
# 1128
# loss -47856.06640625
# nll 1.3482052087783813
# density 0.004693672297928949
#
# val_loss: -45654.4023, val_nll: 1811.3885, val_ensemble: 0.5456, used_weights_median: 10
#
# 1129
# loss -43374.234375
# nll 1.0196962356567383
# density 0.004693672297928949
#
# val_loss: -44300.5898, val_nll: 1849.9563, val_ensemble: 0.5461, used_weights_median: 10
#
# 1130
# loss -44719.25
# nll 1.097257137298584
# density 0.004693672297928949
#
# val_loss: -44525.8320, val_nll: 1862.3051, val_ensemble: 0.5430, used_weights_median: 10
#
# 1131
# loss -47247.12109375
# nll 1.337857723236084
# density 0.004693672297928949
#
# val_loss: -46594.5039, val_nll: 1811.2081, val_ensemble: 0.5399, used_weights_median: 10
#
# 1132
# loss -46543.20703125
# nll 1.0191848278045654
# density 0.004693672297928949
#
# val_loss: -46284.0742, val_nll: 1807.0593, val_ensemble: 0.5508, used_weights_median: 10
#
# 1133
# loss -46383.71484375
# nll 1.191741943359375
# density 0.004693672297928949
#
# val_loss: -43468.5430, val_nll: 1809.3942, val_ensemble: 0.5451, used_weights_median: 10
#
# 1134
# loss -48161.44140625
# nll 1.4485690593719482
# density 0.004693672297928949
#
# val_loss: -45889.9961, val_nll: 1820.3943, val_ensemble: 0.5451, used_weights_median: 10
#
# 1135
# loss -46698.0625
# nll 1.2291591167449951
# density 0.004693672297928949
#
# val_loss: -45374.9844, val_nll: 1805.2324, val_ensemble: 0.5529, used_weights_median: 10
#
# 1136
# loss -48740.77734375
# nll 1.069763422012329
# density 0.004693672297928949
#
# val_loss: -46717.9609, val_nll: 1802.3193, val_ensemble: 0.5534, used_weights_median: 10
#
# 1137
# loss -42381.0703125
# nll 1.321556806564331
# density 0.004693672297928949
#
# val_loss: -41214.1914, val_nll: 1805.4966, val_ensemble: 0.5482, used_weights_median: 10
#
# 1138
# loss -48808.69921875
# nll 1.135673999786377
# density 0.004693672297928949
#
# val_loss: -46655.1523, val_nll: 1809.9569, val_ensemble: 0.5419, used_weights_median: 10
#
# 1139
# loss -48726.96484375
# nll 1.3514823913574219
# density 0.004693672297928949
#
# val_loss: -46989.5977, val_nll: 1824.2177, val_ensemble: 0.5550, used_weights_median: 10
#
# 1140
# loss -47236.67578125
# nll 1.2463264465332031
# density 0.004693672297928949
#
# val_loss: -46621.2578, val_nll: 1845.1881, val_ensemble: 0.5284, used_weights_median: 10
#
# 1141
# loss -47462.8046875
# nll 1.2790244817733765
# density 0.004693672297928949
#
# val_loss: -46496.8398, val_nll: 1840.0367, val_ensemble: 0.5399, used_weights_median: 10
#
# 1142
# loss -46129.7734375
# nll 1.2802772521972656
# density 0.004693672297928949
#
# val_loss: -45497.2070, val_nll: 1827.6826, val_ensemble: 0.5482, used_weights_median: 10
#
# 1143
# loss -47046.13671875
# nll 1.4773099422454834
# density 0.004693672297928949
#
# val_loss: -47125.3633, val_nll: 1858.5785, val_ensemble: 0.5326, used_weights_median: 10
#
# 1144
# loss -45013.79296875
# nll 1.3252040147781372
# density 0.004693672297928949
#
# val_loss: -41017.0664, val_nll: 1805.4999, val_ensemble: 0.5539, used_weights_median: 10
#
# 1145
# loss -49043.13671875
# nll 1.2228975296020508
# density 0.004693672297928949
#
# val_loss: -43581.2109, val_nll: 1814.5859, val_ensemble: 0.5399, used_weights_median: 10
#
# 1146
# loss -46759.2265625
# nll 1.3975298404693604
# density 0.004693672297928949
#
# val_loss: -43585.5078, val_nll: 1826.0698, val_ensemble: 0.5388, used_weights_median: 10
#
# 1147
# loss -48753.13671875
# nll 0.9896236658096313
# density 0.004693672297928949
#
# val_loss: -46565.6328, val_nll: 1818.8665, val_ensemble: 0.5362, used_weights_median: 10
#
# 1148
# loss -46955.64453125
# nll 1.1069931983947754
# density 0.004693672297928949
#
# val_loss: -47063.9922, val_nll: 1815.7559, val_ensemble: 0.5461, used_weights_median: 10
#
# 1149
# loss -48987.12109375
# nll 0.9514178037643433
# density 0.004693672297928949
#
# val_loss: -47243.0469, val_nll: 1834.3282, val_ensemble: 0.5446, used_weights_median: 10
#
# 1150
# loss -48980.765625
# nll 1.2339296340942383
# density 0.004693672297928949
#
# val_loss: -45961.1875, val_nll: 1807.2800, val_ensemble: 0.5576, used_weights_median: 10
#
# 1151
# loss -49081.87890625
# nll 1.0000042915344238
# density 0.004693672297928949
#
# val_loss: -46304.5000, val_nll: 1807.2181, val_ensemble: 0.5451, used_weights_median: 10
#
# 1152
# loss -49297.80859375
# nll 1.14725923538208
# density 0.004693672297928949
#
# val_loss: -47222.7031, val_nll: 1813.2858, val_ensemble: 0.5513, used_weights_median: 10
#
# 1153
# loss -48966.65625
# nll 1.3075952529907227
# density 0.004693672297928949
#
# val_loss: -46771.0820, val_nll: 1853.7902, val_ensemble: 0.5310, used_weights_median: 10
#
# 1154
# loss -48821.03515625
# nll 1.2133171558380127
# density 0.004693672297928949
#
# val_loss: -47448.2148, val_nll: 1852.4014, val_ensemble: 0.5357, used_weights_median: 10
#
# 1155
# loss -49357.1328125
# nll 1.2134554386138916
# density 0.004693672297928949
#
# val_loss: -47548.3320, val_nll: 1818.8468, val_ensemble: 0.5477, used_weights_median: 10
#
# 1156
# loss -49437.296875
# nll 1.0471572875976562
# density 0.004693672297928949
#
# val_loss: -47484.0273, val_nll: 1806.4315, val_ensemble: 0.5576, used_weights_median: 10
#
# 1157
# loss -49312.03515625
# nll 1.081791639328003
# density 0.004693672297928949
#
# val_loss: -47593.1445, val_nll: 1826.1653, val_ensemble: 0.5508, used_weights_median: 10
#
# 1158
# loss -49580.671875
# nll 1.3528566360473633
# density 0.004693672297928949
#
# val_loss: -47670.2266, val_nll: 1802.5575, val_ensemble: 0.5529, used_weights_median: 10
#
# 1159
# loss -49452.4140625
# nll 1.2496368885040283
# density 0.004693672297928949
#
# val_loss: -47107.6172, val_nll: 1804.9352, val_ensemble: 0.5524, used_weights_median: 10
#
# 1160
# loss -49555.8359375
# nll 0.9990251064300537
# density 0.004693672297928949
#
# val_loss: -47837.7070, val_nll: 1808.6149, val_ensemble: 0.5446, used_weights_median: 10
#
# 1161
# loss -49177.60546875
# nll 0.8959982395172119
# density 0.004693672297928949
#
# val_loss: -47037.7695, val_nll: 1832.0573, val_ensemble: 0.5435, used_weights_median: 10
#
# 1162
# loss -49212.6015625
# nll 1.1678359508514404
# density 0.004693672297928949
#
# val_loss: -45676.9453, val_nll: 1809.1738, val_ensemble: 0.5477, used_weights_median: 10
#
# 1163
# loss -48409.25
# nll 1.202022910118103
# density 0.004693672297928949
#
# val_loss: -46646.9219, val_nll: 1850.3807, val_ensemble: 0.5399, used_weights_median: 10
#
# 1164
# loss -49257.12890625
# nll 1.0031832456588745
# density 0.004693672297928949
#
# val_loss: -47033.7383, val_nll: 1856.8368, val_ensemble: 0.5268, used_weights_median: 10
#
# 1165
# loss -48773.58203125
# nll 0.9370330572128296
# density 0.004693672297928949
#
# val_loss: -45427.3086, val_nll: 1830.7449, val_ensemble: 0.5289, used_weights_median: 10
#
# 1166
# loss -48582.33984375
# nll 0.9643117189407349
# density 0.004693672297928949
#
# val_loss: -48136.7500, val_nll: 1841.4600, val_ensemble: 0.5331, used_weights_median: 10
#
# 1167
# loss -49212.13671875
# nll 1.0804044008255005
# density 0.004693672297928949
#
# val_loss: -46140.6016, val_nll: 1807.5648, val_ensemble: 0.5513, used_weights_median: 10
#
# 1168
# loss -50036.94921875
# nll 0.8587798476219177
# density 0.004693672297928949
#
# val_loss: -47770.9453, val_nll: 1818.9749, val_ensemble: 0.5534, used_weights_median: 10
#
# 1169
# loss -48968.24609375
# nll 0.7893348336219788
# density 0.004693672297928949
#
# val_loss: -46638.3477, val_nll: 1845.1244, val_ensemble: 0.5440, used_weights_median: 10
#
# 1170
# loss -49628.98828125
# nll 1.2895116806030273
# density 0.004693672297928949
#
# val_loss: -48082.9844, val_nll: 1830.9623, val_ensemble: 0.5362, used_weights_median: 10
#
# 1171
# loss -49990.05078125
# nll 1.1413558721542358
# density 0.004693672297928949
#
# val_loss: -48223.9102, val_nll: 1815.2454, val_ensemble: 0.5430, used_weights_median: 10
#
# 1172
# loss -49805.578125
# nll 1.1630480289459229
# density 0.004693672297928949
#
# val_loss: -48328.3633, val_nll: 1837.8871, val_ensemble: 0.5472, used_weights_median: 10
#
# 1173
# loss -46768.65625
# nll 1.250108242034912
# density 0.004693672297928949
#
# val_loss: -46715.5625, val_nll: 1802.7667, val_ensemble: 0.5498, used_weights_median: 10
#
# 1174
# loss -50223.765625
# nll 1.2797508239746094
# density 0.004693672297928949
#
# val_loss: -47200.3203, val_nll: 1808.5162, val_ensemble: 0.5524, used_weights_median: 10
#
# 1175
# loss -49481.8046875
# nll 1.2046575546264648
# density 0.004693672297928949
#
# val_loss: -47574.4258, val_nll: 1809.1610, val_ensemble: 0.5456, used_weights_median: 10
#
# 1176
# loss -48619.60546875
# nll 0.971617579460144
# density 0.004693672297928949
#
# val_loss: -46649.2656, val_nll: 1840.0188, val_ensemble: 0.5388, used_weights_median: 10
#
# 1177
# loss -50377.15234375
# nll 1.3520545959472656
# density 0.004693672297928949
#
# val_loss: -48482.9414, val_nll: 1803.9813, val_ensemble: 0.5529, used_weights_median: 10
#
# 1178
# loss -50075.8359375
# nll 1.0061701536178589
# density 0.004693672297928949
#
# val_loss: -48661.2422, val_nll: 1815.1899, val_ensemble: 0.5508, used_weights_median: 10
#
# 1179
# loss -50018.1484375
# nll 1.2484861612319946
# density 0.004693672297928949
#
# val_loss: -48666.4336, val_nll: 1811.4744, val_ensemble: 0.5508, used_weights_median: 10
#
# 1180
# loss -50229.22265625
# nll 1.1187803745269775
# density 0.004693672297928949
#
# val_loss: -48615.8672, val_nll: 1834.0505, val_ensemble: 0.5357, used_weights_median: 10
#
# 1181
# loss -50145.16015625
# nll 1.379087209701538
# density 0.004693672297928949
#
# val_loss: -48625.0156, val_nll: 1815.1705, val_ensemble: 0.5456, used_weights_median: 10
#
# 1182
# loss -50428.57421875
# nll 0.912426233291626
# density 0.004693672297928949
#
# val_loss: -48608.5156, val_nll: 1809.3282, val_ensemble: 0.5446, used_weights_median: 10
#
# 1183
# loss -50682.0
# nll 1.3757133483886719
# density 0.004693672297928949
#
# val_loss: -48057.0117, val_nll: 1805.5824, val_ensemble: 0.5498, used_weights_median: 10
#
# 1184
# loss -48066.35546875
# nll 1.2946606874465942
# density 0.004693672297928949
#
# val_loss: -45052.8867, val_nll: 1826.2618, val_ensemble: 0.5388, used_weights_median: 10
#
# 1185
# loss -49177.54296875
# nll 1.2547802925109863
# density 0.004693672297928949
#
# val_loss: -47755.5820, val_nll: 1806.9272, val_ensemble: 0.5399, used_weights_median: 10
#
# 1186
# loss -50772.25
# nll 0.8199052214622498
# density 0.004693672297928949
#
# val_loss: -48477.1836, val_nll: 1888.8152, val_ensemble: 0.5128, used_weights_median: 10
#
# 1187
# loss -50782.12890625
# nll 1.1937196254730225
# density 0.004693672297928949
#
# val_loss: -48906.0156, val_nll: 1838.2369, val_ensemble: 0.5393, used_weights_median: 10
#
# 1188
# loss -50789.30859375
# nll 1.245836615562439
# density 0.004693672297928949
#
# val_loss: -49088.5469, val_nll: 1856.3835, val_ensemble: 0.5373, used_weights_median: 10
#
# 1189
# loss -49176.12890625
# nll 1.2922594547271729
# density 0.004693672297928949
#
# val_loss: -47237.4531, val_nll: 1823.2220, val_ensemble: 0.5331, used_weights_median: 10
#
# 1190
# loss -51058.48046875
# nll 1.3178331851959229
# density 0.004693672297928949
#
# val_loss: -49216.2148, val_nll: 1804.2629, val_ensemble: 0.5430, used_weights_median: 10
#
# 1191
# loss -50932.6328125
# nll 1.2677347660064697
# density 0.004693672297928949
#
# val_loss: -47867.9141, val_nll: 1808.7633, val_ensemble: 0.5456, used_weights_median: 10
#
# 1192
# loss -49513.44140625
# nll 1.0643110275268555
# density 0.004693672297928949
#
# val_loss: -48102.8906, val_nll: 1817.4224, val_ensemble: 0.5373, used_weights_median: 10
#
# 1193
# loss -50157.60546875
# nll 1.129194736480713
# density 0.004693672297928949
#
# val_loss: -48698.3555, val_nll: 1856.8638, val_ensemble: 0.5320, used_weights_median: 10
#
# 1194
# loss -49575.9296875
# nll 1.0118520259857178
# density 0.004693672297928949
#
# val_loss: -48226.6641, val_nll: 1820.5061, val_ensemble: 0.5466, used_weights_median: 10
#
# 1195
# loss -51221.03125
# nll 1.5764938592910767
# density 0.004693672297928949
#
# val_loss: -48608.3164, val_nll: 1864.3087, val_ensemble: 0.5362, used_weights_median: 10
#
# 1196
# loss -50341.94140625
# nll 1.0199949741363525
# density 0.004693672297928949
#
# val_loss: -49241.3008, val_nll: 1878.2405, val_ensemble: 0.5201, used_weights_median: 10
#
# 1197
# loss -51298.6171875
# nll 0.9687320590019226
# density 0.004693672297928949
#
# val_loss: -49528.8867, val_nll: 1821.3380, val_ensemble: 0.5482, used_weights_median: 10
#
# 1198
# loss -48596.7265625
# nll 1.0807336568832397
# density 0.004693672297928949
#
# val_loss: -48396.7461, val_nll: 1808.1033, val_ensemble: 0.5633, used_weights_median: 10
#
# 1199
# loss -45158.5703125
# nll 1.2782965898513794
# density 0.004693672297928949
#
# val_loss: -41984.4766, val_nll: 1866.2590, val_ensemble: 0.5310, used_weights_median: 10
#
# 4.2085416e-05 density median
# 10.0 used weights median
# 0.3404377279833247 ensemble full
# 0.5452840020844191 ensemble median
# [0.3404377279833247, 4.2085416e-05]

# %% [markdown]
# ## Weights used each class
#
# Classes:
# * 0 = Happy
# * 1 = Surprised
# * 2 = Neutral

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")

# %% [markdown]
# # ReLU based network
#
# ## Seperate a test set for later

# %%
# Split keep some of the data for validation after training
X, X_test, y, y_test = train_test_split(
    copy.deepcopy(X_original), copy.deepcopy(y_original), test_size=0.10, random_state=42, stratify=y_original)

test_dat = torch.tensor(np.column_stack((X_test,y_test)),dtype = torch.float32)

# %% [markdown]
# ## Train, validate, and test network

# %%
# select the device and initiate model

# DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "mps")
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
LOADER_KWARGS = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {}

all_nets = {}
metrics_several_runs = []
metrics_median_several_runs = []
for ni in range(n_nets):
    post_train = False
    print('network', ni)
    # Initate network
    torch.manual_seed(ni+42)
    #---------------------------
    # DIFFERENCE IS IN act_func=F.relu part
    net = BayesianNetwork(dim, p, HIDDEN_LAYERS, classification=class_problem, num_transforms=num_transforms, act_func=F.relu, a_prior=a_prior, n_classes=n_classes).to(DEVICE)
    #---------------------------
    alphas = pip_func.get_alphas_numpy(net)
    nr_weights = np.sum([np.prod(a.shape) for a in alphas])
    print(nr_weights)

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    all_nll = []
    all_loss = []

    # Split into training and test set
    X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=1/9, random_state=ni)#, stratify=y)
            
    train_dat = torch.tensor(np.column_stack((X_train,y_train)),dtype = torch.float32)
    val_dat = torch.tensor(np.column_stack((X_val,y_val)),dtype = torch.float32)
    
    # Train network
    counter = 0
    highest_acc = 0
    best_model = copy.deepcopy(net)
    for epoch in range(epochs + post_train_epochs):
        if verbose:
            print(epoch)
        nll, loss = pip_func.train(net, train_dat, optimizer, BATCH_SIZE, NUM_BATCHES, p, DEVICE, nr_weights, post_train=post_train, multiclass=multiclass)
        nll_val, loss_val, ensemble_val = pip_func.val(net, val_dat, DEVICE, verbose=verbose, reg=(not class_problem), post_train=post_train, multiclass=multiclass)
        if ensemble_val >= highest_acc:
            counter = 0
            highest_acc = ensemble_val
            best_model = copy.deepcopy(net)
        else:
            counter += 1
        
        all_nll.append(nll)
        all_loss.append(loss)

        if epoch == epochs-1:
            post_train = True   # Post-train --> use median model 
            for name, param in net.named_parameters():
                for i in range(HIDDEN_LAYERS+1):
                    #if f"linears{i}.lambdal" in name:
                    if f"linears.{i}.lambdal" in name:
                        param.requires_grad_(False)

        if counter >= patience:
            break
        
    all_nets[ni] = net 
    # Results
    metrics, metrics_median = pip_func.test_ensemble(all_nets[ni],test_dat,DEVICE,SAMPLES=10, reg=(not class_problem), multiclass=multiclass) # Test same data 10 times to get average 
    metrics_several_runs.append(metrics)
    metrics_median_several_runs.append(metrics_median)

if verbose:
    print(metrics)
m = np.array(metrics_several_runs)
m_median = np.array(metrics_median_several_runs)
# Out:
# network 0
# 237612
# 0
# loss 3384595.0
# nll 1.2513524293899536
# density 0.9833475105261146
#
# val_loss: 3384950.7500, val_nll: 2237.6169, val_ensemble: 0.3580, used_weights_median: 237612
#
# 1
# loss 3366043.25
# nll 0.9384532570838928
# density 0.9824611791559512
#
# val_loss: 3366716.5000, val_nll: 2164.5901, val_ensemble: 0.4117, used_weights_median: 237612
#
# 2
# loss 3348527.25
# nll 0.8060848116874695
# density 0.9815183717677757
#
# val_loss: 3349274.0000, val_nll: 2344.5098, val_ensemble: 0.3413, used_weights_median: 237612
#
# 3
# loss 3330950.75
# nll 1.6624782085418701
# density 0.9805117049878541
#
# val_loss: 3331691.5000, val_nll: 2227.8389, val_ensemble: 0.4810, used_weights_median: 237612
#
# 4
# loss 3313317.25
# nll 1.8636609315872192
# density 0.9794344999034215
#
# val_loss: 3313521.2500, val_nll: 1854.4235, val_ensemble: 0.5399, used_weights_median: 237612
#
# 5
# loss 3295469.5
# nll 1.051542043685913
# density 0.9782803685600352
#
# val_loss: 3295522.0000, val_nll: 1760.8043, val_ensemble: 0.5972, used_weights_median: 237612
#
# 6
# loss 3277392.75
# nll 1.1027631759643555
# density 0.9770428634593136
#
# val_loss: 3277462.5000, val_nll: 1731.1744, val_ensemble: 0.6019, used_weights_median: 237612
#
# 7
# loss 3258845.25
# nll 0.9977928996086121
# density 0.9757152549016778
#
# val_loss: 3258976.2500, val_nll: 1750.1360, val_ensemble: 0.5998, used_weights_median: 237612
#
# 8
# loss 3240169.5
# nll 1.3347148895263672
# density 0.9742904258933174
#
# val_loss: 3240225.2500, val_nll: 1742.3530, val_ensemble: 0.6029, used_weights_median: 237612
#
# 9
# loss 3221174.75
# nll 1.0236213207244873
# density 0.9727608090138621
#
# val_loss: 3221291.5000, val_nll: 1766.6294, val_ensemble: 0.5951, used_weights_median: 237612
#
# 10
# loss 3201886.0
# nll 1.1310999393463135
# density 0.9711183482756
#
# val_loss: 3201816.7500, val_nll: 1746.6030, val_ensemble: 0.6123, used_weights_median: 237612
#
# 11
# loss 3182030.75
# nll 0.8435056209564209
# density 0.969354488680899
#
# val_loss: 3182111.7500, val_nll: 1765.9240, val_ensemble: 0.6008, used_weights_median: 237612
#
# 12
# loss 3162025.75
# nll 1.0595952272415161
# density 0.9674601578686175
#
# val_loss: 3161923.2500, val_nll: 1788.9349, val_ensemble: 0.5941, used_weights_median: 237612
#
# 13
# loss 3141311.5
# nll 1.1894969940185547
# density 0.965425772180626
#
# val_loss: 3141179.5000, val_nll: 1744.7754, val_ensemble: 0.6139, used_weights_median: 237612
#
# 14
# loss 3120333.0
# nll 0.8928602337837219
# density 0.9632412422956177
#
# val_loss: 3120154.5000, val_nll: 1750.9133, val_ensemble: 0.6060, used_weights_median: 237612
#
# 15
# loss 3098778.0
# nll 0.7720018029212952
# density 0.9608959690805734
#
# val_loss: 3098710.0000, val_nll: 1838.8036, val_ensemble: 0.5352, used_weights_median: 237612
#
# 16
# loss 3076595.75
# nll 1.1591778993606567
# density 0.9583788711888769
#
# val_loss: 3076379.2500, val_nll: 1730.1588, val_ensemble: 0.6170, used_weights_median: 237612
#
# 17
# loss 3054040.0
# nll 1.0625132322311401
# density 0.9556784381376277
#
# val_loss: 3053688.0000, val_nll: 1735.9935, val_ensemble: 0.6128, used_weights_median: 237612
#
# 18
# loss 3030869.5
# nll 0.8270777463912964
# density 0.9527827073517302
#
# val_loss: 3030386.5000, val_nll: 1716.8712, val_ensemble: 0.6180, used_weights_median: 237612
#
# 19
# loss 3007042.5
# nll 0.8487904667854309
# density 0.9496793249083948
#
# val_loss: 3006573.7500, val_nll: 1788.1581, val_ensemble: 0.5795, used_weights_median: 237612
#
# 20
# loss 2982632.25
# nll 1.1002717018127441
# density 0.9463556091485877
#
# val_loss: 2981910.2500, val_nll: 1689.6505, val_ensemble: 0.6253, used_weights_median: 237612
#
# 21
# loss 2957234.0
# nll 0.9614640474319458
# density 0.9427986032759752
#
# val_loss: 2956686.0000, val_nll: 1686.9904, val_ensemble: 0.6238, used_weights_median: 237612
#
# 22
# loss 2931402.75
# nll 1.0132436752319336
# density 0.9389951096429143
#
# val_loss: 2930642.5000, val_nll: 1661.4597, val_ensemble: 0.6316, used_weights_median: 237612
#
# 23
# loss 2904779.5
# nll 1.1632908582687378
# density 0.9349317555794051
#
# val_loss: 2903964.2500, val_nll: 1676.1179, val_ensemble: 0.6222, used_weights_median: 237612
#
# 24
# loss 2877271.5
# nll 0.9563649296760559
# density 0.930595064198377
#
# val_loss: 2876468.5000, val_nll: 1668.9452, val_ensemble: 0.6295, used_weights_median: 237612
#
# 25
# loss 2849090.75
# nll 1.282804012298584
# density 0.9259715350174357
#
# val_loss: 2848121.2500, val_nll: 1680.2072, val_ensemble: 0.6196, used_weights_median: 237612
#
# 26
# loss 2819806.0
# nll 0.8518673181533813
# density 0.9210476639161292
#
# val_loss: 2819032.7500, val_nll: 1648.8398, val_ensemble: 0.6316, used_weights_median: 237612
#
# 27
# loss 2790016.25
# nll 0.8117610216140747
# density 0.9158100471375392
#
# val_loss: 2788904.2500, val_nll: 1659.3738, val_ensemble: 0.6326, used_weights_median: 237612
#
# 28
# loss 2759218.75
# nll 1.377436637878418
# density 0.9102454564375136
#
# val_loss: 2757928.0000, val_nll: 1652.3110, val_ensemble: 0.6326, used_weights_median: 237612
#
# 29
# loss 2727186.5
# nll 1.103096842765808
# density 0.9043408834713287
#
# val_loss: 2726087.0000, val_nll: 1656.7512, val_ensemble: 0.6305, used_weights_median: 237612
#
# 30
# loss 2694543.75
# nll 1.156097412109375
# density 0.8980835989726432
#
# val_loss: 2693224.0000, val_nll: 1662.7854, val_ensemble: 0.6326, used_weights_median: 237612
#
# 31
# loss 2660797.25
# nll 0.7274332642555237
# density 0.8914612557323802
#
# val_loss: 2659388.0000, val_nll: 1639.9353, val_ensemble: 0.6321, used_weights_median: 236196
#
# 32
# loss 2626112.5
# nll 1.3528587818145752
# density 0.8844619249786768
#
# val_loss: 2624608.5000, val_nll: 1656.6554, val_ensemble: 0.6305, used_weights_median: 233511
#
# 33
# loss 2590464.75
# nll 0.9400364756584167
# density 0.8770741735569874
#
# val_loss: 2588800.5000, val_nll: 1658.5288, val_ensemble: 0.6300, used_weights_median: 230663
#
# 34
# loss 2553684.75
# nll 1.2514979839324951
# density 0.869287135521028
#
# val_loss: 2551874.2500, val_nll: 1650.2697, val_ensemble: 0.6326, used_weights_median: 227763
#
# 35
# loss 2515887.75
# nll 1.2697231769561768
# density 0.8610905632075653
#
# val_loss: 2514194.5000, val_nll: 1660.6416, val_ensemble: 0.6311, used_weights_median: 224756
#
# 36
# loss 2477199.5
# nll 1.1635327339172363
# density 0.8524749373605948
#
# val_loss: 2475196.7500, val_nll: 1688.8391, val_ensemble: 0.6149, used_weights_median: 221504
#
# 37
# loss 2437197.75
# nll 1.0733866691589355
# density 0.8434315016740758
#
# val_loss: 2435132.2500, val_nll: 1662.0226, val_ensemble: 0.6258, used_weights_median: 218258
#
# 38
# loss 2396327.25
# nll 0.993602991104126
# density 0.8339523837912768
#
# val_loss: 2394307.7500, val_nll: 1720.0448, val_ensemble: 0.6191, used_weights_median: 214918
#
# 39
# loss 2354441.75
# nll 1.0174763202667236
# density 0.8240306598022226
#
# val_loss: 2352221.5000, val_nll: 1773.3359, val_ensemble: 0.5763, used_weights_median: 211388
#
# 40
# loss 2311410.5
# nll 1.0081939697265625
# density 0.8136604794437508
#
# val_loss: 2309145.7500, val_nll: 1747.5948, val_ensemble: 0.6102, used_weights_median: 207718
#
# 41
# loss 2267211.0
# nll 0.7236175537109375
# density 0.8028370877140096
#
# val_loss: 2265059.2500, val_nll: 1854.4651, val_ensemble: 0.5920, used_weights_median: 204107
#
# 42
# loss 2222153.25
# nll 0.8905209898948669
# density 0.7915568747774135
#
# val_loss: 2219918.0000, val_nll: 1895.6903, val_ensemble: 0.5800, used_weights_median: 200248
#
# 43
# loss 2176048.5
# nll 0.5544887781143188
# density 0.7798175505244348
#
# val_loss: 2174136.7500, val_nll: 2287.3635, val_ensemble: 0.4351, used_weights_median: 196171
#
# 44
# loss 2128916.75
# nll 0.8098651170730591
# density 0.7676182346985073
#
# val_loss: 2127177.0000, val_nll: 2474.3518, val_ensemble: 0.5201, used_weights_median: 189952
#
# 45
# loss 2080897.25
# nll 1.6116889715194702
# density 0.7549601659506593
#
# val_loss: 2078261.8750, val_nll: 1834.1316, val_ensemble: 0.5847, used_weights_median: 185622
#
# 46
# loss 2031881.875
# nll 1.2591062784194946
# density 0.7418451829561992
#
# val_loss: 2029203.3750, val_nll: 1810.2451, val_ensemble: 0.5821, used_weights_median: 181184
#
# 47
# loss 1981950.125
# nll 1.7854244709014893
# density 0.7282764089788718
#
# val_loss: 1979097.3750, val_nll: 1802.1615, val_ensemble: 0.5852, used_weights_median: 174852
#
# 48
# loss 1931158.125
# nll 2.2417171001434326
# density 0.7142587632730764
#
# val_loss: 1928296.8750, val_nll: 1849.0109, val_ensemble: 0.5753, used_weights_median: 170066
#
# 49
# loss 1879584.625
# nll 1.5685839653015137
# density 0.6997988892192462
#
# val_loss: 1876654.0000, val_nll: 1823.1633, val_ensemble: 0.5753, used_weights_median: 163599
#
# 50
# loss 1827162.875
# nll 1.2322666645050049
# density 0.6849053885360719
#
# val_loss: 1823953.2500, val_nll: 1688.8169, val_ensemble: 0.6128, used_weights_median: 155551
#
# 51
# loss 1774050.75
# nll 0.466337651014328
# density 0.66958871636463
#
# val_loss: 1770928.7500, val_nll: 1761.9260, val_ensemble: 0.5763, used_weights_median: 149140
#
# 52
# loss 1720215.0
# nll 1.1687877178192139
# density 0.6538613453294077
#
# val_loss: 1716977.1250, val_nll: 1706.6208, val_ensemble: 0.5920, used_weights_median: 142774
#
# 53
# loss 1665768.875
# nll 1.4655814170837402
# density 0.6377379461316941
#
# val_loss: 1662362.8750, val_nll: 1618.9736, val_ensemble: 0.6451, used_weights_median: 137738
#
# 54
# loss 1610902.0
# nll 1.1083426475524902
# density 0.6212358570590114
#
# val_loss: 1607321.7500, val_nll: 1627.8605, val_ensemble: 0.6384, used_weights_median: 131404
#
# 55
# loss 1555440.75
# nll 1.1356053352355957
# density 0.6043753453949116
#
# val_loss: 1552100.2500, val_nll: 1626.0526, val_ensemble: 0.6483, used_weights_median: 124913
#
# 56
# loss 1499801.375
# nll 1.685112476348877
# density 0.5871799377030273
#
# val_loss: 1496329.0000, val_nll: 1730.1931, val_ensemble: 0.5982, used_weights_median: 118646
#
# 57
# loss 1443771.375
# nll 1.5286051034927368
# density 0.569676686124717
#
# val_loss: 1440204.1250, val_nll: 1678.6826, val_ensemble: 0.6316, used_weights_median: 111162
#
# 58
# loss 1387600.75
# nll 0.7674062848091125
# density 0.5519006460814895
#
# val_loss: 1384100.0000, val_nll: 1685.3318, val_ensemble: 0.6139, used_weights_median: 102692
#
# 59
# loss 1331438.125
# nll 1.3199379444122314
# density 0.5338855137640869
#
# val_loss: 1328078.7500, val_nll: 1779.7572, val_ensemble: 0.5868, used_weights_median: 93378
#
# 60
# loss 1275372.625
# nll 0.8837124705314636
# density 0.5156698981166576
#
# val_loss: 1271979.3750, val_nll: 1639.6707, val_ensemble: 0.6389, used_weights_median: 85549
#
# 61
# loss 1219569.5
# nll 1.315955638885498
# density 0.4973007794940877
#
# val_loss: 1216201.5000, val_nll: 1660.6577, val_ensemble: 0.6238, used_weights_median: 77925
#
# 62
# loss 1164059.375
# nll 1.0942704677581787
# density 0.47883070562496216
#
# val_loss: 1160778.3750, val_nll: 1704.7743, val_ensemble: 0.6087, used_weights_median: 69764
#
# 63
# loss 1109312.625
# nll 2.1349000930786133
# density 0.4603261446494595
#
# val_loss: 1106126.5000, val_nll: 1807.9169, val_ensemble: 0.5690, used_weights_median: 62835
#
# 64
# loss 1055248.75
# nll 1.1141737699508667
# density 0.4418459351213901
#
# val_loss: 1052172.7500, val_nll: 1798.8186, val_ensemble: 0.5675, used_weights_median: 57876
#
# 65
# loss 1002229.6875
# nll 1.1388299465179443
# density 0.4234601234863504
#
# val_loss: 999275.5625, val_nll: 1855.8936, val_ensemble: 0.5706, used_weights_median: 52116
#
# 66
# loss 950186.25
# nll 1.485656499862671
# density 0.40525063778532494
#
# val_loss: 947359.6250, val_nll: 1853.3953, val_ensemble: 0.5748, used_weights_median: 47519
#
# 67
# loss 899552.0
# nll 0.9605089426040649
# density 0.38729883247690966
#
# val_loss: 896844.9375, val_nll: 1834.3854, val_ensemble: 0.5748, used_weights_median: 42094
#
# 68
# loss 850628.6875
# nll 0.5709096789360046
# density 0.3696854346803879
#
# val_loss: 848040.1875, val_nll: 1748.1508, val_ensemble: 0.5982, used_weights_median: 33581
#
# 69
# loss 803428.8125
# nll 1.0584487915039062
# density 0.3524959133985146
#
# val_loss: 800976.3125, val_nll: 1770.3593, val_ensemble: 0.5633, used_weights_median: 27924
#
# 70
# loss 758107.0
# nll 0.7134575843811035
# density 0.3358125669092375
#
# val_loss: 755853.7500, val_nll: 1768.5123, val_ensemble: 0.5654, used_weights_median: 23808
#
# 71
# loss 714976.875
# nll 1.7999680042266846
# density 0.31971127625105217
#
# val_loss: 713050.9375, val_nll: 1855.6680, val_ensemble: 0.5659, used_weights_median: 18768
#
# 72
# loss 674112.1875
# nll 2.089268922805786
# density 0.30425851814648386
#
# val_loss: 672343.0000, val_nll: 1838.9023, val_ensemble: 0.5612, used_weights_median: 14225
#
# 73
# loss 635548.125
# nll 0.6916953325271606
# density 0.28950837265291907
#
# val_loss: 633999.6875, val_nll: 1857.2574, val_ensemble: 0.5711, used_weights_median: 11114
#
# 74
# loss 599350.6875
# nll 1.533592939376831
# density 0.27550044155940073
#
# val_loss: 597883.0000, val_nll: 1811.0699, val_ensemble: 0.5842, used_weights_median: 7762
#
# 75
# loss 565454.375
# nll 0.30630260705947876
# density 0.26225850764296604
#
# val_loss: 564277.7500, val_nll: 1854.5906, val_ensemble: 0.5175, used_weights_median: 4117
#
# 76
# loss 534033.4375
# nll 1.6250383853912354
# density 0.24979129200524536
#
# val_loss: 533062.8125, val_nll: 1830.7992, val_ensemble: 0.5503, used_weights_median: 1545
#
# 77
# loss 504693.15625
# nll 0.8686399459838867
# density 0.2380921324145623
#
# val_loss: 504157.5000, val_nll: 2037.0394, val_ensemble: 0.4278, used_weights_median: 516
#
# 78
# loss 477537.90625
# nll 1.621003270149231
# density 0.2271430152726052
#
# val_loss: 477493.4688, val_nll: 2350.8840, val_ensemble: 0.3491, used_weights_median: 145
#
# 79
# loss 452431.25
# nll 1.0188755989074707
# density 0.2169155388171344
#
# val_loss: 452884.7188, val_nll: 2572.2100, val_ensemble: 0.3288, used_weights_median: 122
#
# 80
# loss 429186.0
# nll 1.2343426942825317
# density 0.20737412182489628
#
# val_loss: 429780.7812, val_nll: 2543.4893, val_ensemble: 0.3299, used_weights_median: 105
#
# 81
# loss 407842.78125
# nll 1.534503698348999
# density 0.19847881386591382
#
# val_loss: 408611.3438, val_nll: 2659.9705, val_ensemble: 0.3236, used_weights_median: 89
#
# 82
# loss 387940.15625
# nll 1.409456491470337
# density 0.19018726110254686
#
# val_loss: 389009.0000, val_nll: 2700.8562, val_ensemble: 0.3220, used_weights_median: 77
#
# 83
# loss 369715.46875
# nll 0.7077131867408752
# density 0.18245613685778395
#
# val_loss: 370644.1562, val_nll: 2571.4121, val_ensemble: 0.3241, used_weights_median: 71
#
# 84
# loss 352713.09375
# nll 0.732787549495697
# density 0.17524326517190897
#
# val_loss: 353520.6875, val_nll: 2444.9355, val_ensemble: 0.3241, used_weights_median: 57
#
# 85
# loss 336901.40625
# nll 1.4176557064056396
# density 0.16850775142559146
#
# val_loss: 337829.5000, val_nll: 2410.4480, val_ensemble: 0.3241, used_weights_median: 52
#
# 86
# loss 322199.90625
# nll 1.3170809745788574
# density 0.16221099003803016
#
# val_loss: 323569.5938, val_nll: 2595.4683, val_ensemble: 0.3210, used_weights_median: 47
#
# 87
# loss 308599.0
# nll 1.7377299070358276
# density 0.15631719010219697
#
# val_loss: 309877.1562, val_nll: 2386.4409, val_ensemble: 0.3252, used_weights_median: 44
#
# 88
# loss 295874.4375
# nll 0.6440138220787048
# density 0.15079300902925474
#
# val_loss: 297526.5625, val_nll: 2748.9324, val_ensemble: 0.3179, used_weights_median: 34
#
# 89
# loss 284030.53125
# nll 1.474165439605713
# density 0.1456081736628102
#
# val_loss: 285689.3750, val_nll: 2591.9529, val_ensemble: 0.3184, used_weights_median: 33
#
# 90
# loss 272965.65625
# nll 1.15338134765625
# density 0.1407346535330012
#
# val_loss: 274450.1250, val_nll: 2573.0251, val_ensemble: 0.3179, used_weights_median: 30
#
# 91
# loss 262481.15625
# nll 0.9422101974487305
# density 0.1361470375804997
#
# val_loss: 264375.0312, val_nll: 2781.0151, val_ensemble: 0.3179, used_weights_median: 28
#
# 92
# loss 252751.015625
# nll 1.8009660243988037
# density 0.131822706178437
#
# val_loss: 254521.5156, val_nll: 2695.4810, val_ensemble: 0.3184, used_weights_median: 23
#
# 93
# loss 243590.296875
# nll 1.3640486001968384
# density 0.1277403857117723
#
# val_loss: 245521.8750, val_nll: 2740.4971, val_ensemble: 0.3184, used_weights_median: 22
#
# 94
# loss 234877.515625
# nll 2.2376368045806885
# density 0.12388151840566149
#
# val_loss: 236938.0625, val_nll: 2793.5115, val_ensemble: 0.3179, used_weights_median: 22
#
# 95
# loss 226727.0625
# nll 1.2583056688308716
# density 0.12022868663047752
#
# val_loss: 228865.3906, val_nll: 2766.8643, val_ensemble: 0.3184, used_weights_median: 20
#
# 96
# loss 219005.59375
# nll 0.551393449306488
# density 0.11676630140469801
#
# val_loss: 221274.3438, val_nll: 2929.7144, val_ensemble: 0.3184, used_weights_median: 19
#
# 97
# loss 211746.921875
# nll 1.0447224378585815
# density 0.11348021678860329
#
# val_loss: 213864.9688, val_nll: 2752.9036, val_ensemble: 0.3184, used_weights_median: 18
#
# 98
# loss 204896.15625
# nll 0.8483266234397888
# density 0.11035815007492222
#
# val_loss: 206958.7656, val_nll: 2767.0059, val_ensemble: 0.3184, used_weights_median: 16
#
# 99
# loss 198239.953125
# nll 1.360373854637146
# density 0.10738790996640857
#
# val_loss: 200406.6562, val_nll: 2740.2041, val_ensemble: 0.3184, used_weights_median: 16
#
# 100
# loss 192112.796875
# nll 1.5510516166687012
# density 0.10455904012697424
#
# val_loss: 194196.1094, val_nll: 2720.1289, val_ensemble: 0.3184, used_weights_median: 16
#
# 101
# loss 186094.703125
# nll 0.6619107723236084
# density 0.10186164938409471
#
# val_loss: 188416.8906, val_nll: 2850.7542, val_ensemble: 0.3184, used_weights_median: 16
#
# 102
# loss 180467.390625
# nll 0.9582810401916504
# density 0.09928720324005279
#
# val_loss: 182714.0938, val_nll: 2836.5247, val_ensemble: 0.3184, used_weights_median: 16
#
# 103
# loss 175092.125
# nll 0.9747342467308044
# density 0.09682752176702972
#
# val_loss: 177373.5156, val_nll: 2792.7883, val_ensemble: 0.3184, used_weights_median: 16
#
# 104
# loss 169894.0
# nll 2.0620880126953125
# density 0.09447523368771461
#
# val_loss: 172314.6719, val_nll: 2835.7349, val_ensemble: 0.3189, used_weights_median: 16
#
# 105
# loss 164935.0625
# nll 1.3465356826782227
# density 0.09222346860247224
#
# val_loss: 167322.4844, val_nll: 2756.3445, val_ensemble: 0.3184, used_weights_median: 15
#
# 106
# loss 160203.453125
# nll 1.4213324785232544
# density 0.09006594563316601
#
# val_loss: 162880.2500, val_nll: 2960.0425, val_ensemble: 0.3184, used_weights_median: 14
#
# 107
# loss 155791.21875
# nll 1.4336410760879517
# density 0.08799724903108125
#
# val_loss: 158181.9062, val_nll: 2814.1421, val_ensemble: 0.3184, used_weights_median: 14
#
# 108
# loss 151468.53125
# nll 0.46273374557495117
# density 0.08601165454467018
#
# val_loss: 154085.4375, val_nll: 3007.4609, val_ensemble: 0.3184, used_weights_median: 14
#
# 109
# loss 147282.109375
# nll 1.262723445892334
# density 0.08410467657388389
#
# val_loss: 149730.4375, val_nll: 2837.0842, val_ensemble: 0.3184, used_weights_median: 14
#
# 110
# loss 143313.640625
# nll 2.2485945224761963
# density 0.08227162969105523
#
# val_loss: 145967.9375, val_nll: 3008.3416, val_ensemble: 0.3184, used_weights_median: 14
#
# 111
# loss 139450.734375
# nll 1.4117395877838135
# density 0.08050837943621172
#
# val_loss: 142231.0781, val_nll: 3090.2505, val_ensemble: 0.3184, used_weights_median: 14
#
# 112
# loss 135811.296875
# nll 0.8864920735359192
# density 0.07881107754640877
#
# val_loss: 138627.3750, val_nll: 3050.4436, val_ensemble: 0.3184, used_weights_median: 14
#
# 113
# loss 132239.78125
# nll 0.6142060160636902
# density 0.07717582385774387
#
# val_loss: 134900.2500, val_nll: 2939.8083, val_ensemble: 0.3184, used_weights_median: 14
#
# 114
# loss 128940.8359375
# nll 1.1816507577896118
# density 0.07559952347641759
#
# val_loss: 131666.0938, val_nll: 3064.2666, val_ensemble: 0.3184, used_weights_median: 14
#
# 115
# loss 125521.265625
# nll 0.7056788802146912
# density 0.07407956343743581
#
# val_loss: 128249.9141, val_nll: 2860.8369, val_ensemble: 0.3189, used_weights_median: 13
#
# 116
# loss 122484.671875
# nll 0.7287124395370483
# density 0.07261215131183618
#
# val_loss: 125292.3047, val_nll: 3156.6946, val_ensemble: 0.3184, used_weights_median: 13
#
# 117
# loss 119306.1875
# nll 1.3916369676589966
# density 0.07119517647703678
#
# val_loss: 122112.7734, val_nll: 3011.6897, val_ensemble: 0.3189, used_weights_median: 13
#
# 118
# loss 116377.75
# nll 1.6996639966964722
# density 0.06982594856553159
#
# val_loss: 119110.6562, val_nll: 2991.5486, val_ensemble: 0.3189, used_weights_median: 13
#
# 119
# loss 113548.9609375
# nll 1.1399145126342773
# density 0.0685022266223819
#
# val_loss: 115917.2109, val_nll: 2767.4377, val_ensemble: 0.3210, used_weights_median: 12
#
# 120
# loss 110699.8515625
# nll 0.9788004159927368
# density 0.06722161602073981
#
# val_loss: 113427.2188, val_nll: 3029.6892, val_ensemble: 0.3189, used_weights_median: 12
#
# 121
# loss 107931.484375
# nll 0.6158231496810913
# density 0.06598226518822821
#
# val_loss: 110517.6719, val_nll: 2914.6384, val_ensemble: 0.3231, used_weights_median: 12
#
# 122
# loss 105578.859375
# nll 1.0267059803009033
# density 0.06478208159185356
#
# val_loss: 107960.8125, val_nll: 2909.5149, val_ensemble: 0.3226, used_weights_median: 12
#
# 123
# loss 102813.046875
# nll 1.9488778114318848
# density 0.06361950900283482
#
# val_loss: 105688.9297, val_nll: 3012.0925, val_ensemble: 0.3210, used_weights_median: 12
#
# 124
# loss 100238.4765625
# nll 2.0233206748962402
# density 0.06249269645086296
#
# val_loss: 103023.0078, val_nll: 2945.8464, val_ensemble: 0.3205, used_weights_median: 12
#
# 125
# loss 97918.7578125
# nll 0.9765809774398804
# density 0.061400000211499564
#
# val_loss: 101064.9375, val_nll: 3261.0432, val_ensemble: 0.3189, used_weights_median: 12
#
# 126
# loss 95626.53125
# nll 0.8056535124778748
# density 0.06033994968939913
#
# val_loss: 98420.8281, val_nll: 2961.5962, val_ensemble: 0.3246, used_weights_median: 12
#
# 127
# loss 93526.8203125
# nll 1.4431114196777344
# density 0.05931120543389925
#
# val_loss: 96100.2891, val_nll: 2961.3286, val_ensemble: 0.3246, used_weights_median: 12
#
# 128
# loss 91514.78125
# nll 1.019758939743042
# density 0.05831236392325446
#
# val_loss: 94205.0469, val_nll: 3035.5295, val_ensemble: 0.3226, used_weights_median: 12
#
# 129
# loss 89173.40625
# nll 1.039520025253296
# density 0.05734187361590013
#
# val_loss: 92037.8984, val_nll: 2999.9438, val_ensemble: 0.3231, used_weights_median: 12
#
# 130
# loss 87204.5703125
# nll 1.0490683317184448
# density 0.05639881657183227
#
# val_loss: 90048.3047, val_nll: 3099.9287, val_ensemble: 0.3215, used_weights_median: 12
#
# 131
# loss 85101.0078125
# nll 1.8739967346191406
# density 0.05548232481167496
#
# val_loss: 87787.4688, val_nll: 2833.5518, val_ensemble: 0.3252, used_weights_median: 12
#
# 132
# loss 83309.78125
# nll 1.6358325481414795
# density 0.05459092917333772
#
# val_loss: 86132.2422, val_nll: 3096.7231, val_ensemble: 0.3200, used_weights_median: 12
#
# 133
# loss 81285.1015625
# nll 1.4654479026794434
# density 0.05372385031275437
#
# val_loss: 83840.2656, val_nll: 2780.6123, val_ensemble: 0.3252, used_weights_median: 12
#
# 134
# loss 79380.1328125
# nll 0.6659883260726929
# density 0.0528798183922659
#
# val_loss: 82302.2969, val_nll: 3065.0435, val_ensemble: 0.3241, used_weights_median: 12
#
# 135
# loss 77578.3984375
# nll 0.8673719763755798
# density 0.05205818884719181
#
# val_loss: 80722.7188, val_nll: 3232.0430, val_ensemble: 0.3220, used_weights_median: 12
#
# 136
# loss 75747.6484375
# nll 1.336316704750061
# density 0.05126022964194757
#
# val_loss: 78465.5391, val_nll: 2835.3342, val_ensemble: 0.3262, used_weights_median: 12
#
# 137
# loss 74084.9609375
# nll 0.88260418176651
# density 0.05048254674476992
#
# val_loss: 77041.4844, val_nll: 2943.5298, val_ensemble: 0.3246, used_weights_median: 12
#
# 138
# loss 72444.1640625
# nll 1.3725807666778564
# density 0.04972365478015529
#
# val_loss: 75404.2891, val_nll: 3155.7141, val_ensemble: 0.3236, used_weights_median: 12
#
# 139
# loss 70772.7109375
# nll 1.35205078125
# density 0.048983485692556665
#
# val_loss: 73943.4688, val_nll: 3057.6194, val_ensemble: 0.3226, used_weights_median: 12
#
# 140
# loss 69243.3359375
# nll 1.5569034814834595
# density 0.048261920357628135
#
# val_loss: 71998.9609, val_nll: 2938.3105, val_ensemble: 0.3246, used_weights_median: 12
#
# 141
# loss 67761.1015625
# nll 1.2679517269134521
# density 0.04755787311764213
#
# val_loss: 70094.8438, val_nll: 2722.5056, val_ensemble: 0.3377, used_weights_median: 12
#
# 142
# loss 66179.4453125
# nll 1.184866189956665
# density 0.04687077705392566
#
# val_loss: 69190.6016, val_nll: 3145.6448, val_ensemble: 0.3246, used_weights_median: 12
#
# 143
# loss 64624.109375
# nll 0.9724112153053284
# density 0.04620042152160913
#
# val_loss: 67764.0312, val_nll: 3231.4399, val_ensemble: 0.3205, used_weights_median: 11
#
# 144
# loss 63225.76953125
# nll 0.9645309448242188
# density 0.04554621276888262
#
# val_loss: 65686.0547, val_nll: 2764.8103, val_ensemble: 0.3293, used_weights_median: 11
#
# 145
# loss 61664.27734375
# nll 0.4191673696041107
# density 0.044907265322092674
#
# val_loss: 64597.5156, val_nll: 3006.4238, val_ensemble: 0.3246, used_weights_median: 11
#
# 146
# loss 60321.90625
# nll 1.1339209079742432
# density 0.04428314812847141
#
# val_loss: 63061.0391, val_nll: 2939.1050, val_ensemble: 0.3293, used_weights_median: 11
#
# 147
# loss 59280.87109375
# nll 0.768264651298523
# density 0.043673440083390254
#
# val_loss: 61772.2461, val_nll: 2868.6055, val_ensemble: 0.3340, used_weights_median: 10
#
# 148
# loss 57660.578125
# nll 2.0129194259643555
# density 0.043077550807166104
#
# val_loss: 60292.4570, val_nll: 2751.8752, val_ensemble: 0.3366, used_weights_median: 10
#
# 149
# loss 56292.13671875
# nll 1.089200735092163
# density 0.04249539491553448
#
# val_loss: 59202.6328, val_nll: 2951.3574, val_ensemble: 0.3293, used_weights_median: 10
#
# 150
# loss 55121.01953125
# nll 0.8712931275367737
# density 0.04192604412495194
#
# val_loss: 58373.7578, val_nll: 3066.0029, val_ensemble: 0.3236, used_weights_median: 10
#
# 151
# loss 53787.65625
# nll 0.3822106420993805
# density 0.04136946178574374
#
# val_loss: 56842.0078, val_nll: 3130.3958, val_ensemble: 0.3246, used_weights_median: 10
#
# 152
# loss 52616.3203125
# nll 1.1145330667495728
# density 0.04082516023815403
#
# val_loss: 55180.6680, val_nll: 2869.6931, val_ensemble: 0.3361, used_weights_median: 10
#
# 153
# loss 51692.3046875
# nll 1.217292308807373
# density 0.04029241749987679
#
# val_loss: 54564.1836, val_nll: 3173.3757, val_ensemble: 0.3252, used_weights_median: 10
#
# 154
# loss 50363.63671875
# nll 1.4960581064224243
# density 0.03977111859265495
#
# val_loss: 52905.3398, val_nll: 2773.3940, val_ensemble: 0.3361, used_weights_median: 10
#
# 155
# loss 48940.59765625
# nll 1.9162805080413818
# density 0.03926091412672405
#
# val_loss: 51868.2305, val_nll: 2782.5671, val_ensemble: 0.3372, used_weights_median: 10
#
# 156
# loss 47813.1015625
# nll 1.481423258781433
# density 0.038763726443390815
#
# val_loss: 50604.6250, val_nll: 2856.6230, val_ensemble: 0.3299, used_weights_median: 10
#
# 157
# loss 46784.57421875
# nll 0.6161644458770752
# density 0.03827638865498532
#
# val_loss: 49682.4766, val_nll: 2959.9453, val_ensemble: 0.3372, used_weights_median: 10
#
# 158
# loss 45577.68359375
# nll 0.9811446070671082
# density 0.037798049075408666
#
# val_loss: 49138.2305, val_nll: 3362.4131, val_ensemble: 0.3252, used_weights_median: 10
#
# 159
# loss 44635.3671875
# nll 0.8442465662956238
# density 0.03732899656800589
#
# val_loss: 47451.9180, val_nll: 2836.8567, val_ensemble: 0.3372, used_weights_median: 9
#
# 160
# loss 43368.9609375
# nll 1.1155076026916504
# density 0.03686926578447375
#
# val_loss: 46230.0391, val_nll: 2868.6096, val_ensemble: 0.3366, used_weights_median: 9
#
# 161
# loss 42480.10546875
# nll 0.6853333115577698
# density 0.036418865318510046
#
# val_loss: 45139.0703, val_nll: 2833.9746, val_ensemble: 0.3304, used_weights_median: 9
#
# 162
# loss 41629.8515625
# nll 1.1781749725341797
# density 0.03597968235711816
#
# val_loss: 44472.5703, val_nll: 2495.2488, val_ensemble: 0.3559, used_weights_median: 9
#
# 163
# loss 40391.1640625
# nll 0.845227837562561
# density 0.03554855084029538
#
# val_loss: 42989.7188, val_nll: 2727.7832, val_ensemble: 0.3398, used_weights_median: 9
#
# 164
# loss 39503.78125
# nll 0.8530951738357544
# density 0.03512454048689655
#
# val_loss: 42780.2305, val_nll: 3193.3474, val_ensemble: 0.3299, used_weights_median: 9
#
# 165
# loss 38403.328125
# nll 1.1378849744796753
# density 0.03470881985293316
#
# val_loss: 41525.5703, val_nll: 2924.8940, val_ensemble: 0.3351, used_weights_median: 9
#
# 166
# loss 37469.81640625
# nll 1.8073444366455078
# density 0.03430075272891252
#
# val_loss: 40144.4180, val_nll: 2820.2617, val_ensemble: 0.3330, used_weights_median: 9
#
# 167
# loss 36494.16796875
# nll 1.871953010559082
# density 0.033900403098120604
#
# val_loss: 40134.9414, val_nll: 2717.2056, val_ensemble: 0.3366, used_weights_median: 9
#
# 168
# loss 35686.70703125
# nll 0.8789172172546387
# density 0.03350840409930233
#
# val_loss: 38480.6602, val_nll: 3000.5417, val_ensemble: 0.3366, used_weights_median: 9
#
# 169
# loss 34947.12109375
# nll 1.1741679906845093
# density 0.03312364293609882
#
# val_loss: 37575.3867, val_nll: 2951.0042, val_ensemble: 0.3408, used_weights_median: 9
#
# 170
# loss 33829.4296875
# nll 1.0854923725128174
# density 0.032745584232923515
#
# val_loss: 36620.5547, val_nll: 2674.4941, val_ensemble: 0.3528, used_weights_median: 9
#
# 171
# loss 32882.8984375
# nll 1.4155210256576538
# density 0.032376679596138165
#
# val_loss: 35490.7773, val_nll: 2756.9800, val_ensemble: 0.3424, used_weights_median: 9
#
# 172
# loss 32117.947265625
# nll 1.260746717453003
# density 0.03201393905093514
#
# val_loss: 34808.9766, val_nll: 2911.7939, val_ensemble: 0.3398, used_weights_median: 9
#
# 173
# loss 31681.1953125
# nll 2.54289174079895
# density 0.031656750698087696
#
# val_loss: 34150.7578, val_nll: 2840.0652, val_ensemble: 0.3398, used_weights_median: 9
#
# 174
# loss 31830.85546875
# nll 3.4414074420928955
# density 0.03130993270558632
#
# val_loss: 33273.1016, val_nll: 2694.8335, val_ensemble: 0.3471, used_weights_median: 9
#
# 175
# loss 29687.64453125
# nll 1.7976778745651245
# density 0.030966316194458547
#
# val_loss: 33229.7148, val_nll: 2888.0125, val_ensemble: 0.3481, used_weights_median: 9
#
# 176
# loss 28854.94140625
# nll 0.1375817507505417
# density 0.030627776668260356
#
# val_loss: 31595.3750, val_nll: 3078.8555, val_ensemble: 0.3398, used_weights_median: 9
#
# 177
# loss 28003.091796875
# nll 1.630751371383667
# density 0.030294712703688702
#
# val_loss: 30643.9355, val_nll: 2808.2664, val_ensemble: 0.3372, used_weights_median: 9
#
# 178
# loss 27178.20703125
# nll 0.5812530517578125
# density 0.029967432391761573
#
# val_loss: 29977.4922, val_nll: 2827.4814, val_ensemble: 0.3392, used_weights_median: 9
#
# 179
# loss 26397.671875
# nll 1.277373194694519
# density 0.029645536480920793
#
# val_loss: 29139.5312, val_nll: 2822.4561, val_ensemble: 0.3429, used_weights_median: 9
#
# 180
# loss 25952.720703125
# nll 1.7707844972610474
# density 0.029334454283086203
#
# val_loss: 28368.7461, val_nll: 2742.8650, val_ensemble: 0.3403, used_weights_median: 9
#
# 181
# loss 25026.3828125
# nll 0.796241819858551
# density 0.029025243822621106
#
# val_loss: 27627.0840, val_nll: 2935.7793, val_ensemble: 0.3403, used_weights_median: 9
#
# 182
# loss 24199.869140625
# nll 2.386709451675415
# density 0.02872013870047604
#
# val_loss: 26960.4727, val_nll: 2776.4451, val_ensemble: 0.3392, used_weights_median: 9
#
# 183
# loss 23579.806640625
# nll 0.5377599000930786
# density 0.02841972291488607
#
# val_loss: 26546.4102, val_nll: 2981.1047, val_ensemble: 0.3392, used_weights_median: 9
#
# 184
# loss 22614.884765625
# nll 2.089470386505127
# density 0.028124906274306798
#
# val_loss: 25086.6016, val_nll: 2566.7180, val_ensemble: 0.3559, used_weights_median: 9
#
# 185
# loss 21853.740234375
# nll 1.5105969905853271
# density 0.02783459013653683
#
# val_loss: 24712.5020, val_nll: 2730.4773, val_ensemble: 0.3424, used_weights_median: 9
#
# 186
# loss 21120.517578125
# nll 0.820044994354248
# density 0.02754880569217327
#
# val_loss: 24147.4766, val_nll: 2503.5713, val_ensemble: 0.3502, used_weights_median: 9
#
# 187
# loss 20606.40625
# nll 2.222777843475342
# density 0.027267475344759044
#
# val_loss: 23422.9492, val_nll: 2745.8313, val_ensemble: 0.3460, used_weights_median: 9
#
# 188
# loss 20694.923828125
# nll 0.7652201056480408
# density 0.02699073616062757
#
# val_loss: 22698.4141, val_nll: 2475.5420, val_ensemble: 0.3736, used_weights_median: 9
#
# 189
# loss 20219.861328125
# nll 0.526793897151947
# density 0.026718856033134744
#
# val_loss: 22897.6211, val_nll: 2745.7607, val_ensemble: 0.3517, used_weights_median: 9
#
# 190
# loss 19939.8515625
# nll 1.3662257194519043
# density 0.026451474715881447
#
# val_loss: 21204.2676, val_nll: 2581.0437, val_ensemble: 0.3517, used_weights_median: 9
#
# 191
# loss 17774.63671875
# nll 0.7293339967727661
# density 0.0261880807975563
#
# val_loss: 21054.7500, val_nll: 2623.6057, val_ensemble: 0.3418, used_weights_median: 9
#
# 192
# loss 17843.859375
# nll 1.4451593160629272
# density 0.025928655692760764
#
# val_loss: 20197.6523, val_nll: 2692.8154, val_ensemble: 0.3544, used_weights_median: 9
#
# 193
# loss 16567.783203125
# nll 0.2988172173500061
# density 0.0256740511660388
#
# val_loss: 18961.0820, val_nll: 2440.4568, val_ensemble: 0.3575, used_weights_median: 9
#
# 194
# loss 16566.72265625
# nll 1.1992285251617432
# density 0.025423024068222718
#
# val_loss: 18588.5840, val_nll: 2567.0012, val_ensemble: 0.3564, used_weights_median: 9
#
# 195
# loss 15576.83984375
# nll 2.3065309524536133
# density 0.02517597511492521
#
# val_loss: 18193.8770, val_nll: 2705.7788, val_ensemble: 0.3528, used_weights_median: 9
#
# 196
# loss 14709.4697265625
# nll 1.2097575664520264
# density 0.02493263979579773
#
# val_loss: 17347.4297, val_nll: 2467.2598, val_ensemble: 0.3669, used_weights_median: 9
#
# 197
# loss 16286.67578125
# nll 1.8417394161224365
# density 0.024693070332531673
#
# val_loss: 16935.6016, val_nll: 2403.2458, val_ensemble: 0.3778, used_weights_median: 9
#
# 198
# loss 14999.3583984375
# nll 0.7469910383224487
# density 0.024459513896102673
#
# val_loss: 16617.6914, val_nll: 2503.3323, val_ensemble: 0.3611, used_weights_median: 9
#
# 199
# loss 13314.7060546875
# nll 1.2982652187347412
# density 0.02422944221075791
#
# val_loss: 16917.9883, val_nll: 2725.9805, val_ensemble: 0.3533, used_weights_median: 9
#
# 200
# loss 12759.306640625
# nll 2.4573302268981934
# density 0.02400194009660438
#
# val_loss: 15226.7998, val_nll: 2490.5166, val_ensemble: 0.3523, used_weights_median: 9
#
# 201
# loss 11949.6748046875
# nll 1.142006278038025
# density 0.02377641050307862
#
# val_loss: 14538.8789, val_nll: 2442.2642, val_ensemble: 0.3715, used_weights_median: 9
#
# 202
# loss 11264.7587890625
# nll 1.2670834064483643
# density 0.023554460306523032
#
# val_loss: 14420.8584, val_nll: 2556.3098, val_ensemble: 0.3700, used_weights_median: 9
#
# 203
# loss 10763.560546875
# nll 1.4082980155944824
# density 0.023335349644305815
#
# val_loss: 14467.2568, val_nll: 2492.0449, val_ensemble: 0.3575, used_weights_median: 9
#
# 204
# loss 10024.904296875
# nll 0.46580469608306885
# density 0.02311999916335421
#
# val_loss: 13271.9541, val_nll: 2739.6904, val_ensemble: 0.3403, used_weights_median: 9
#
# 205
# loss 9427.947265625
# nll 0.6313693523406982
# density 0.022907414975392403
#
# val_loss: 11900.1191, val_nll: 2380.5669, val_ensemble: 0.3986, used_weights_median: 9
#
# 206
# loss 8986.3291015625
# nll 1.6102485656738281
# density 0.022697785899852132
#
# val_loss: 11155.1260, val_nll: 2442.0339, val_ensemble: 0.3794, used_weights_median: 9
#
# 207
# loss 8585.4033203125
# nll 1.3521127700805664
# density 0.022490708517920996
#
# val_loss: 10970.8906, val_nll: 2346.3374, val_ensemble: 0.3710, used_weights_median: 9
#
# 208
# loss 9376.1103515625
# nll 1.5479307174682617
# density 0.022286374145789867
#
# val_loss: 11268.8604, val_nll: 2503.6018, val_ensemble: 0.3627, used_weights_median: 9
#
# 209
# loss 7124.71875
# nll 1.3846676349639893
# density 0.022085325231134503
#
# val_loss: 9824.1650, val_nll: 2342.9922, val_ensemble: 0.3715, used_weights_median: 9
#
# 210
# loss 6837.5390625
# nll 1.9159648418426514
# density 0.02188756839413247
#
# val_loss: 9300.3906, val_nll: 2602.5269, val_ensemble: 0.3549, used_weights_median: 9
#
# 211
# loss 6107.62060546875
# nll 1.6791114807128906
# density 0.021692275568286193
#
# val_loss: 9030.5645, val_nll: 2286.1421, val_ensemble: 0.3742, used_weights_median: 9
#
# 212
# loss 6493.58349609375
# nll 1.7193622589111328
# density 0.02149983043673529
#
# val_loss: 8349.8428, val_nll: 2371.1023, val_ensemble: 0.3721, used_weights_median: 9
#
# 213
# loss 5952.169921875
# nll 1.8124529123306274
# density 0.021311002877874782
#
# val_loss: 7946.6187, val_nll: 2284.4067, val_ensemble: 0.3773, used_weights_median: 9
#
# 214
# loss 5373.28955078125
# nll 1.0608370304107666
# density 0.021123976638297334
#
# val_loss: 7577.0303, val_nll: 2374.4978, val_ensemble: 0.3689, used_weights_median: 9
#
# 215
# loss 4849.44091796875
# nll 0.7495983242988586
# density 0.020939907324839732
#
# val_loss: 6706.9307, val_nll: 2234.3171, val_ensemble: 0.3747, used_weights_median: 9
#
# 216
# loss 4247.03857421875
# nll 1.3938311338424683
# density 0.02075902060868271
#
# val_loss: 6438.9365, val_nll: 2199.7881, val_ensemble: 0.3877, used_weights_median: 9
#
# 217
# loss 5135.57666015625
# nll 2.1370043754577637
# density 0.02058007685761909
#
# val_loss: 6379.0020, val_nll: 2207.1687, val_ensemble: 0.4268, used_weights_median: 9
#
# 218
# loss 2960.572021484375
# nll 1.3990718126296997
# density 0.020402532948665078
#
# val_loss: 5447.9048, val_nll: 2165.0347, val_ensemble: 0.4007, used_weights_median: 9
#
# 219
# loss 2336.915283203125
# nll 2.1731204986572266
# density 0.020226701770185446
#
# val_loss: 5073.2959, val_nll: 2129.7629, val_ensemble: 0.4310, used_weights_median: 9
#
# 220
# loss 1859.647216796875
# nll 1.6989824771881104
# density 0.020055958109863454
#
# val_loss: 4151.3291, val_nll: 2129.2754, val_ensemble: 0.4096, used_weights_median: 9
#
# 221
# loss 2023.3956298828125
# nll 1.6768310070037842
# density 0.01988903002604721
#
# val_loss: 4680.9248, val_nll: 2131.8245, val_ensemble: 0.4049, used_weights_median: 9
#
# 222
# loss 2254.87646484375
# nll 1.7290432453155518
# density 0.019724553161807636
#
# val_loss: 3116.4395, val_nll: 2100.5576, val_ensemble: 0.4242, used_weights_median: 9
#
# 223
# loss 1624.6258544921875
# nll 2.408127784729004
# density 0.019561977317415356
#
# val_loss: 2603.3599, val_nll: 2388.4771, val_ensemble: 0.3684, used_weights_median: 9
#
# 224
# loss 263.5262145996094
# nll 2.73518705368042
# density 0.019403801498197884
#
# val_loss: 11451.3389, val_nll: 2343.6611, val_ensemble: 0.3710, used_weights_median: 9
#
# 225
# loss 165.37364196777344
# nll 0.6392707824707031
# density 0.019246454760509537
#
# val_loss: 2278.6255, val_nll: 2319.6919, val_ensemble: 0.3747, used_weights_median: 9
#
# 226
# loss 607.3904418945312
# nll 3.8689775466918945
# density 0.019087799110541582
#
# val_loss: 4043.1204, val_nll: 2611.5286, val_ensemble: 0.3486, used_weights_median: 9
#
# 227
# loss 1022.0323486328125
# nll 2.0577666759490967
# density 0.018933231262156056
#
# val_loss: 1442.1819, val_nll: 2394.2141, val_ensemble: 0.3736, used_weights_median: 9
#
# 228
# loss 46.12810134887695
# nll 0.5939230918884277
# density 0.01878105718337457
#
# val_loss: 2266.6316, val_nll: 2236.1003, val_ensemble: 0.3992, used_weights_median: 9
#
# 229
# loss -746.1832885742188
# nll 1.6028311252593994
# density 0.018631056497074836
#
# val_loss: 3017.5938, val_nll: 2281.9346, val_ensemble: 0.3825, used_weights_median: 9
#
# 230
# loss -2068.355224609375
# nll 4.091955184936523
# density 0.018479149815831243
#
# val_loss: 6153.5718, val_nll: 2245.9272, val_ensemble: 0.3986, used_weights_median: 9
#
# 231
# loss 1524.17138671875
# nll 0.4936572015285492
# density 0.018327543659666025
#
# val_loss: 1286.1016, val_nll: 2411.4883, val_ensemble: 0.3658, used_weights_median: 9
#
# 232
# loss 892.241455078125
# nll 3.4406630992889404
# density 0.018180009319911036
#
# val_loss: -459.5854, val_nll: 2302.4009, val_ensemble: 0.3820, used_weights_median: 9
#
# 233
# loss -3229.156494140625
# nll 2.7654459476470947
# density 0.01803445320883264
#
# val_loss: 700.5820, val_nll: 2201.6768, val_ensemble: 0.3950, used_weights_median: 9
#
# 234
# loss -2864.932373046875
# nll 2.2024459838867188
# density 0.01788829510293684
#
# val_loss: 138.7773, val_nll: 2415.3965, val_ensemble: 0.3575, used_weights_median: 9
#
# 235
# loss -1800.8426513671875
# nll 0.10358680039644241
# density 0.017751006840570047
#
# val_loss: -781.2424, val_nll: 2425.0515, val_ensemble: 0.3679, used_weights_median: 9
#
# 236
# loss -2744.2578125
# nll 3.2637362480163574
# density 0.017618194087634795
#
# val_loss: -749.1733, val_nll: 2375.3062, val_ensemble: 0.3622, used_weights_median: 9
#
# 237
# loss -3238.2177734375
# nll 0.26669377088546753
# density 0.01748661749387608
#
# val_loss: -1468.1125, val_nll: 2673.4753, val_ensemble: 0.3465, used_weights_median: 9
#
# 238
# loss -4945.2724609375
# nll 0.7023534178733826
# density 0.017354232543925496
#
# val_loss: -2039.1453, val_nll: 2651.9592, val_ensemble: 0.3439, used_weights_median: 9
#
# 239
# loss -4900.787109375
# nll 0.3699846565723419
# density 0.01722070056184591
#
# val_loss: -1395.8809, val_nll: 2940.1738, val_ensemble: 0.3403, used_weights_median: 9
#
# 240
# loss -4169.66943359375
# nll 0.5620872974395752
# density 0.017087916699143505
#
# val_loss: -1751.8020, val_nll: 2740.2263, val_ensemble: 0.3429, used_weights_median: 9
#
# 241
# loss 1554.0457763671875
# nll 0.030206460505723953
# density 0.016955544964949203
#
# val_loss: -2709.1775, val_nll: 2688.6819, val_ensemble: 0.3471, used_weights_median: 9
#
# 242
# loss -5704.8291015625
# nll 1.2859680652618408
# density 0.01681669739408571
#
# val_loss: -969.1418, val_nll: 2775.9832, val_ensemble: 0.3413, used_weights_median: 9
#
# 243
# loss -5404.416015625
# nll 0.231232151389122
# density 0.016683997182354277
#
# val_loss: -3504.9446, val_nll: 2652.6863, val_ensemble: 0.3507, used_weights_median: 9
#
# 244
# loss -3184.53125
# nll 0.341778427362442
# density 0.01655595184556566
#
# val_loss: -1056.4724, val_nll: 2925.7268, val_ensemble: 0.3403, used_weights_median: 9
#
# 245
# loss -6241.8564453125
# nll 0.8564806580543518
# density 0.016432928637207023
#
# val_loss: -3821.4951, val_nll: 2507.2236, val_ensemble: 0.3622, used_weights_median: 9
#
# 246
# loss -6210.642578125
# nll 0.10053221136331558
# density 0.016313796619217304
#
# val_loss: -2976.1541, val_nll: 2605.2004, val_ensemble: 0.3486, used_weights_median: 9
#
# 247
# loss -6613.2607421875
# nll 0.07339811325073242
# density 0.016200872211441338
#
# val_loss: -4008.5632, val_nll: 2494.1467, val_ensemble: 0.3575, used_weights_median: 9
#
# 248
# loss -7538.3427734375
# nll 1.0477324724197388
# density 0.016091485082507698
#
# val_loss: -5649.9443, val_nll: 2499.5413, val_ensemble: 0.3601, used_weights_median: 9
#
# 249
# loss -6877.166015625
# nll 0.9266247749328613
# density 0.01598113602701186
#
# val_loss: -4977.6309, val_nll: 2483.5398, val_ensemble: 0.3648, used_weights_median: 9
#
# 250
# loss -7492.39599609375
# nll 1.6364057064056396
# density 0.01586904850109132
#
# val_loss: -5357.9150, val_nll: 2466.4695, val_ensemble: 0.3637, used_weights_median: 9
#
# 251
# loss -7629.50732421875
# nll 1.0531114339828491
# density 0.015761211109485685
#
# val_loss: -4628.4370, val_nll: 2375.8521, val_ensemble: 0.3684, used_weights_median: 9
#
# 252
# loss -9074.43359375
# nll 0.37093889713287354
# density 0.015651344782559393
#
# val_loss: -6062.4209, val_nll: 2477.2900, val_ensemble: 0.3700, used_weights_median: 9
#
# 253
# loss -7280.8486328125
# nll 2.0850977897644043
# density 0.015542086175925472
#
# val_loss: -5806.1289, val_nll: 2123.5928, val_ensemble: 0.4148, used_weights_median: 8
#
# 254
# loss -8362.4404296875
# nll 0.8410043716430664
# density 0.015434071107627376
#
# val_loss: -6986.2236, val_nll: 2187.7195, val_ensemble: 0.3955, used_weights_median: 8
#
# 255
# loss -7128.27099609375
# nll 1.2135032415390015
# density 0.015325676348339784
#
# val_loss: -6279.8086, val_nll: 2212.8093, val_ensemble: 0.3950, used_weights_median: 8
#
# 256
# loss -9546.0439453125
# nll 1.7653594017028809
# density 0.015222847079179796
#
# val_loss: -7524.5186, val_nll: 2183.0605, val_ensemble: 0.4002, used_weights_median: 8
#
# 257
# loss -9076.2626953125
# nll 1.1010092496871948
# density 0.01511964247467578
#
# val_loss: -6780.3066, val_nll: 2285.9043, val_ensemble: 0.3851, used_weights_median: 8
#
# 258
# loss -10241.9501953125
# nll 1.196421504020691
# density 0.015021751942038728
#
# val_loss: -7508.0859, val_nll: 2185.2751, val_ensemble: 0.4070, used_weights_median: 8
#
# 259
# loss -8138.9794921875
# nll 0.4296357035636902
# density 0.014920279251779614
#
# val_loss: -8257.9639, val_nll: 2197.4150, val_ensemble: 0.3898, used_weights_median: 8
#
# 260
# loss -10510.8310546875
# nll 0.9467688202857971
# density 0.014816067886670954
#
# val_loss: -5237.7480, val_nll: 2199.3037, val_ensemble: 0.3908, used_weights_median: 8
#
# 261
# loss -8144.107421875
# nll 0.2716163098812103
# density 0.014712073132964543
#
# val_loss: -8343.6426, val_nll: 2186.6345, val_ensemble: 0.3934, used_weights_median: 8
#
# 262
# loss -10994.150390625
# nll 2.1766185760498047
# density 0.014609480010279072
#
# val_loss: -8925.0352, val_nll: 2207.5569, val_ensemble: 0.3924, used_weights_median: 8
#
# 263
# loss -10838.3857421875
# nll 4.0591139793396
# density 0.01451030952237587
#
# val_loss: -9643.3271, val_nll: 2206.9607, val_ensemble: 0.4002, used_weights_median: 8
#
# 264
# loss -11249.029296875
# nll 0.7398535013198853
# density 0.014412093902440526
#
# val_loss: -9249.5752, val_nll: 2223.9250, val_ensemble: 0.3950, used_weights_median: 8
#
# 265
# loss -12659.0791015625
# nll 0.8888334631919861
# density 0.014317616238374405
#
# val_loss: -10183.0732, val_nll: 2187.4285, val_ensemble: 0.3992, used_weights_median: 8
#
# 266
# loss -12346.98828125
# nll 1.4925663471221924
# density 0.014226686596903378
#
# val_loss: -8403.3174, val_nll: 2293.8455, val_ensemble: 0.3804, used_weights_median: 8
#
# 267
# loss -1220.71337890625
# nll 3.0845041275024414
# density 0.014132363214367373
#
# val_loss: -11498.0088, val_nll: 2106.3123, val_ensemble: 0.4143, used_weights_median: 8
#
# 268
# loss -12980.3232421875
# nll 0.5648750066757202
# density 0.014037020244752238
#
# val_loss: -11333.6738, val_nll: 2027.1753, val_ensemble: 0.4289, used_weights_median: 8
#
# 269
# loss -12241.447265625
# nll 1.2203539609909058
# density 0.01394423801782054
#
# val_loss: -9219.4023, val_nll: 2025.2457, val_ensemble: 0.4310, used_weights_median: 8
#
# 270
# loss -12845.4169921875
# nll 1.7702109813690186
# density 0.01385539254289842
#
# val_loss: -8311.1152, val_nll: 2110.3979, val_ensemble: 0.4315, used_weights_median: 8
#
# 271
# loss -13701.0576171875
# nll 2.581191301345825
# density 0.013766812411988917
#
# val_loss: -11784.2871, val_nll: 2145.9077, val_ensemble: 0.4065, used_weights_median: 8
#
# 272
# loss -13968.2529296875
# nll 1.4658582210540771
# density 0.013676437247686758
#
# val_loss: -11614.7842, val_nll: 2160.4043, val_ensemble: 0.4007, used_weights_median: 8
#
# 273
# loss -11022.3173828125
# nll 1.8771030902862549
# density 0.013588320480659541
#
# val_loss: -12778.4727, val_nll: 2214.1333, val_ensemble: 0.3981, used_weights_median: 8
#
# 274
# loss -9619.76171875
# nll 0.4458710551261902
# density 0.01349883287302261
#
# val_loss: -8569.1895, val_nll: 2247.4446, val_ensemble: 0.3861, used_weights_median: 8
#
# 275
# loss -14491.1142578125
# nll 4.4831743240356445
# density 0.013408477044070173
#
# val_loss: -11787.6719, val_nll: 2282.6184, val_ensemble: 0.3913, used_weights_median: 8
#
# 276
# loss -13323.568359375
# nll 2.6262474060058594
# density 0.013321369415974824
#
# val_loss: -11386.7969, val_nll: 2126.5144, val_ensemble: 0.4252, used_weights_median: 8
#
# 277
# loss -14698.349609375
# nll 5.500579357147217
# density 0.013236547948159748
#
# val_loss: -12040.6416, val_nll: 2445.8528, val_ensemble: 0.3710, used_weights_median: 8
#
# 278
# loss -13780.4208984375
# nll 1.710360050201416
# density 0.013151882951928354
#
# val_loss: -10820.5391, val_nll: 2483.1731, val_ensemble: 0.3606, used_weights_median: 8
#
# 279
# loss -12943.8857421875
# nll 2.1548912525177
# density 0.013067052125538804
#
# val_loss: -12331.2236, val_nll: 2451.3049, val_ensemble: 0.3679, used_weights_median: 8
#
# 280
# loss -13689.44140625
# nll 0.6365777850151062
# density 0.012986069183038046
#
# val_loss: -9453.9766, val_nll: 2388.2654, val_ensemble: 0.3726, used_weights_median: 8
#
# 281
# loss -13036.8583984375
# nll 1.2954456806182861
# density 0.012904901152890474
#
# val_loss: -11768.8662, val_nll: 2615.8293, val_ensemble: 0.3570, used_weights_median: 8
#
# 282
# loss -14955.44921875
# nll 1.7918570041656494
# density 0.012822903932868729
#
# val_loss: -14050.5293, val_nll: 2462.8755, val_ensemble: 0.3653, used_weights_median: 8
#
# 283
# loss -16390.638671875
# nll 4.607231616973877
# density 0.012742919042734977
#
# val_loss: -11395.6084, val_nll: 2401.1179, val_ensemble: 0.3752, used_weights_median: 8
#
# 284
# loss -16474.40234375
# nll 5.038851261138916
# density 0.01266653720942216
#
# val_loss: -13434.3066, val_nll: 2421.4487, val_ensemble: 0.3752, used_weights_median: 8
#
# 285
# loss -15250.4140625
# nll 1.2646089792251587
# density 0.012593891806652317
#
# val_loss: -13042.5449, val_nll: 2399.9790, val_ensemble: 0.3658, used_weights_median: 8
#
# 286
# loss -16229.830078125
# nll 0.01525355875492096
# density 0.012519368337360984
#
# val_loss: -14764.2461, val_nll: 2634.8501, val_ensemble: 0.3486, used_weights_median: 8
#
# 287
# loss -15405.7705078125
# nll 0.46756306290626526
# density 0.012441739044268218
#
# val_loss: -15103.0518, val_nll: 2555.1692, val_ensemble: 0.3544, used_weights_median: 8
#
# 288
# loss -15294.240234375
# nll 1.0688986778259277
# density 0.012365577634325952
#
# val_loss: -13659.8164, val_nll: 2309.2783, val_ensemble: 0.3820, used_weights_median: 8
#
# 289
# loss -17892.740234375
# nll 0.29036009311676025
# density 0.012289438187694212
#
# val_loss: -4571.3301, val_nll: 2528.1355, val_ensemble: 0.3705, used_weights_median: 8
#
# 290
# loss -17231.724609375
# nll 1.197609782218933
# density 0.01221712959647218
#
# val_loss: -14037.9756, val_nll: 2301.8767, val_ensemble: 0.3945, used_weights_median: 8
#
# 291
# loss -1725.2845458984375
# nll 1.6934775114059448
# ...
# nll 1.7032625675201416
# density 0.0046197150876796204
#
# val_loss: -45553.4023, val_nll: 1823.5107, val_ensemble: 0.5586, used_weights_median: 12
#
# 1107
# loss -47319.57421875
# nll 1.7128803730010986
# density 0.0046197150876796204
#
# val_loss: -45570.4766, val_nll: 1850.0120, val_ensemble: 0.5409, used_weights_median: 12
#
# 1108
# loss -47487.45703125
# nll 1.5440422296524048
# density 0.0046197150876796204
#
# val_loss: -45531.8711, val_nll: 1824.6163, val_ensemble: 0.5654, used_weights_median: 12
#
# 1109
# loss -47363.140625
# nll 2.2776103019714355
# density 0.0046197150876796204
#
# val_loss: -45620.1719, val_nll: 1840.4537, val_ensemble: 0.5477, used_weights_median: 12
#
# 1110
# loss -47488.9375
# nll 1.7461284399032593
# density 0.0046197150876796204
#
# val_loss: -45595.5195, val_nll: 1876.9597, val_ensemble: 0.5612, used_weights_median: 12
#
# 1111
# loss -47504.2421875
# nll 1.950721025466919
# density 0.0046197150876796204
#
# val_loss: -45702.4766, val_nll: 1821.1659, val_ensemble: 0.5550, used_weights_median: 12
#
# 1112
# loss -47551.40234375
# nll 1.6847800016403198
# density 0.0046197150876796204
#
# val_loss: -45666.0078, val_nll: 1850.6844, val_ensemble: 0.5591, used_weights_median: 12
#
# 1113
# loss -47587.87890625
# nll 1.8419058322906494
# density 0.0046197150876796204
#
# val_loss: -45748.3516, val_nll: 1805.4218, val_ensemble: 0.5591, used_weights_median: 12
#
# 1114
# loss -47592.77734375
# nll 2.0523300170898438
# density 0.0046197150876796204
#
# val_loss: -45681.5195, val_nll: 1823.9752, val_ensemble: 0.5581, used_weights_median: 12
#
# 1115
# loss -47561.921875
# nll 1.9724926948547363
# density 0.0046197150876796204
#
# val_loss: -45675.8516, val_nll: 1834.4398, val_ensemble: 0.5545, used_weights_median: 12
#
# 1116
# loss -47639.1953125
# nll 1.9313801527023315
# density 0.0046197150876796204
#
# val_loss: -45882.1523, val_nll: 1821.7399, val_ensemble: 0.5534, used_weights_median: 12
#
# 1117
# loss -47695.1796875
# nll 1.9828426837921143
# density 0.0046197150876796204
#
# val_loss: -45752.6367, val_nll: 1856.1304, val_ensemble: 0.5664, used_weights_median: 12
#
# 1118
# loss -47552.84375
# nll 2.132205009460449
# density 0.0046197150876796204
#
# val_loss: -45832.1641, val_nll: 1814.8574, val_ensemble: 0.5591, used_weights_median: 12
#
# 1119
# loss -47856.09765625
# nll 2.0099124908447266
# density 0.0046197150876796204
#
# val_loss: -45868.7500, val_nll: 1855.0127, val_ensemble: 0.5633, used_weights_median: 12
#
# 1120
# loss -47853.375
# nll 1.8670756816864014
# density 0.0046197150876796204
#
# val_loss: -46016.2578, val_nll: 1842.4143, val_ensemble: 0.5393, used_weights_median: 12
#
# 1121
# loss -47861.66015625
# nll 2.1834716796875
# density 0.0046197150876796204
#
# val_loss: -45961.0703, val_nll: 1853.8738, val_ensemble: 0.5482, used_weights_median: 12
#
# 1122
# loss -47891.05859375
# nll 1.8096379041671753
# density 0.0046197150876796204
#
# val_loss: -46043.9062, val_nll: 1804.4360, val_ensemble: 0.5607, used_weights_median: 12
#
# 1123
# loss -47918.79296875
# nll 1.5112173557281494
# density 0.0046197150876796204
#
# val_loss: -46011.9492, val_nll: 1831.3330, val_ensemble: 0.5628, used_weights_median: 12
#
# 1124
# loss -47787.1328125
# nll 1.4874000549316406
# density 0.0046197150876796204
#
# val_loss: -46096.6328, val_nll: 1852.9677, val_ensemble: 0.5638, used_weights_median: 12
#
# 1125
# loss -48025.9296875
# nll 2.413821220397949
# density 0.0046197150876796204
#
# val_loss: -46165.3828, val_nll: 1821.2664, val_ensemble: 0.5529, used_weights_median: 12
#
# 1126
# loss -48005.69140625
# nll 2.6139843463897705
# density 0.0046197150876796204
#
# val_loss: -46189.7109, val_nll: 1824.9580, val_ensemble: 0.5461, used_weights_median: 12
#
# 1127
# loss -48090.71484375
# nll 1.3050326108932495
# density 0.0046197150876796204
#
# val_loss: -46236.9805, val_nll: 1829.4403, val_ensemble: 0.5612, used_weights_median: 12
#
# 1128
# loss -48014.31640625
# nll 2.3476905822753906
# density 0.0046197150876796204
#
# val_loss: -46081.0352, val_nll: 1850.8290, val_ensemble: 0.5602, used_weights_median: 12
#
# 1129
# loss -48084.55078125
# nll 1.964369773864746
# density 0.0046197150876796204
#
# val_loss: -46077.5547, val_nll: 1813.8965, val_ensemble: 0.5571, used_weights_median: 12
#
# 1130
# loss -48197.671875
# nll 1.8587069511413574
# density 0.0046197150876796204
#
# val_loss: -46316.8359, val_nll: 1837.9082, val_ensemble: 0.5529, used_weights_median: 12
#
# 1131
# loss -48294.015625
# nll 1.8426377773284912
# density 0.0046197150876796204
#
# val_loss: -46418.4375, val_nll: 1824.3274, val_ensemble: 0.5545, used_weights_median: 12
#
# 1132
# loss -48141.9375
# nll 1.6796939373016357
# density 0.0046197150876796204
#
# val_loss: -46440.7266, val_nll: 1821.3285, val_ensemble: 0.5565, used_weights_median: 12
#
# 1133
# loss -48315.7890625
# nll 1.5872502326965332
# density 0.0046197150876796204
#
# val_loss: -46385.6758, val_nll: 1829.2377, val_ensemble: 0.5602, used_weights_median: 12
#
# 1134
# loss -48374.33203125
# nll 2.1543407440185547
# density 0.0046197150876796204
#
# val_loss: -46407.3086, val_nll: 1842.9540, val_ensemble: 0.5430, used_weights_median: 12
#
# 1135
# loss -48462.89453125
# nll 2.371568441390991
# density 0.0046197150876796204
#
# val_loss: -46407.3477, val_nll: 1799.0729, val_ensemble: 0.5644, used_weights_median: 12
#
# 1136
# loss -48329.5625
# nll 1.836579442024231
# density 0.0046197150876796204
#
# val_loss: -46475.8867, val_nll: 1833.9821, val_ensemble: 0.5482, used_weights_median: 12
#
# 1137
# loss -48327.44140625
# nll 2.060554027557373
# density 0.0046197150876796204
#
# val_loss: -46622.5078, val_nll: 1817.3331, val_ensemble: 0.5623, used_weights_median: 12
#
# 1138
# loss -48370.51953125
# nll 1.7030324935913086
# density 0.0046197150876796204
#
# val_loss: -46598.6016, val_nll: 1848.3794, val_ensemble: 0.5477, used_weights_median: 12
#
# 1139
# loss -48415.0390625
# nll 1.6955804824829102
# density 0.0046197150876796204
#
# val_loss: -46665.2969, val_nll: 1820.9885, val_ensemble: 0.5586, used_weights_median: 12
#
# 1140
# loss -48456.93359375
# nll 1.9686110019683838
# density 0.0046197150876796204
#
# val_loss: -46762.9297, val_nll: 1823.4075, val_ensemble: 0.5565, used_weights_median: 12
#
# 1141
# loss -48544.0546875
# nll 1.8089377880096436
# density 0.0046197150876796204
#
# val_loss: -46854.2773, val_nll: 1805.4650, val_ensemble: 0.5565, used_weights_median: 12
#
# 1142
# loss -48632.828125
# nll 2.2671279907226562
# density 0.0046197150876796204
#
# val_loss: -46744.9297, val_nll: 1905.1182, val_ensemble: 0.5545, used_weights_median: 12
#
# 1143
# loss -48774.26171875
# nll 2.0381155014038086
# density 0.0046197150876796204
#
# val_loss: -46824.7891, val_nll: 1838.8333, val_ensemble: 0.5456, used_weights_median: 12
#
# 1144
# loss -48671.5
# nll 1.8136732578277588
# density 0.0046197150876796204
#
# val_loss: -46955.1680, val_nll: 1817.7462, val_ensemble: 0.5586, used_weights_median: 12
#
# 1145
# loss -48700.65234375
# nll 1.9963352680206299
# density 0.0046197150876796204
#
# val_loss: -46936.0938, val_nll: 1820.4161, val_ensemble: 0.5597, used_weights_median: 12
#
# 1146
# loss -48757.64453125
# nll 2.208494186401367
# density 0.0046197150876796204
#
# val_loss: -46960.9219, val_nll: 1815.0636, val_ensemble: 0.5618, used_weights_median: 12
#
# 1147
# loss -48804.0546875
# nll 1.4448792934417725
# density 0.0046197150876796204
#
# val_loss: -46857.8789, val_nll: 1869.7405, val_ensemble: 0.5560, used_weights_median: 12
#
# 1148
# loss -48906.6171875
# nll 1.6439595222473145
# density 0.0046197150876796204
#
# val_loss: -47082.6680, val_nll: 1791.6228, val_ensemble: 0.5602, used_weights_median: 12
#
# 1149
# loss -48834.75390625
# nll 1.3858582973480225
# density 0.0046197150876796204
#
# val_loss: -47044.1953, val_nll: 1820.4932, val_ensemble: 0.5545, used_weights_median: 12
#
# 1150
# loss -48974.421875
# nll 1.7378625869750977
# density 0.0046197150876796204
#
# val_loss: -47097.4727, val_nll: 1798.5071, val_ensemble: 0.5597, used_weights_median: 12
#
# 1151
# loss -48855.9453125
# nll 1.5484423637390137
# density 0.0046197150876796204
#
# val_loss: -47070.9844, val_nll: 1809.3029, val_ensemble: 0.5576, used_weights_median: 12
#
# 1152
# loss -49051.27734375
# nll 1.4945688247680664
# density 0.0046197150876796204
#
# val_loss: -47264.0742, val_nll: 1791.7693, val_ensemble: 0.5685, used_weights_median: 12
#
# 1153
# loss -49057.9140625
# nll 2.072071075439453
# density 0.0046197150876796204
#
# val_loss: -47279.5469, val_nll: 1818.7362, val_ensemble: 0.5534, used_weights_median: 12
#
# 1154
# loss -48977.86328125
# nll 1.8660492897033691
# density 0.0046197150876796204
#
# val_loss: -47283.3438, val_nll: 1800.9789, val_ensemble: 0.5633, used_weights_median: 12
#
# 1155
# loss -49130.296875
# nll 1.9113965034484863
# density 0.0046197150876796204
#
# val_loss: -47332.9688, val_nll: 1831.4720, val_ensemble: 0.5581, used_weights_median: 12
#
# 1156
# loss -49215.421875
# nll 1.5248773097991943
# density 0.0046197150876796204
#
# val_loss: -47363.4180, val_nll: 1811.7544, val_ensemble: 0.5524, used_weights_median: 12
#
# 1157
# loss -49198.6484375
# nll 1.4093996286392212
# density 0.0046197150876796204
#
# val_loss: -47434.1406, val_nll: 1812.6722, val_ensemble: 0.5545, used_weights_median: 12
#
# 1158
# loss -49301.203125
# nll 1.9515107870101929
# density 0.0046197150876796204
#
# val_loss: -47478.7695, val_nll: 1806.8767, val_ensemble: 0.5618, used_weights_median: 12
#
# 1159
# loss -49043.9765625
# nll 1.6738084554672241
# density 0.0046197150876796204
#
# val_loss: -47513.1797, val_nll: 1810.0918, val_ensemble: 0.5597, used_weights_median: 12
#
# 1160
# loss -49192.79296875
# nll 1.1827031373977661
# density 0.0046197150876796204
#
# val_loss: -47511.3086, val_nll: 1797.2533, val_ensemble: 0.5649, used_weights_median: 12
#
# 1161
# loss -49332.1640625
# nll 1.2236098051071167
# density 0.0046197150876796204
#
# val_loss: -47580.2969, val_nll: 1817.6138, val_ensemble: 0.5503, used_weights_median: 12
#
# 1162
# loss -49453.7421875
# nll 1.874619960784912
# density 0.0046197150876796204
#
# val_loss: -47381.8867, val_nll: 1820.8407, val_ensemble: 0.5513, used_weights_median: 12
#
# 1163
# loss -49512.55078125
# nll 1.9290578365325928
# density 0.0046197150876796204
#
# val_loss: -47623.5195, val_nll: 1869.5153, val_ensemble: 0.5378, used_weights_median: 12
#
# 1164
# loss -49474.71484375
# nll 1.4524011611938477
# density 0.0046197150876796204
#
# val_loss: -47666.4297, val_nll: 1858.6094, val_ensemble: 0.5456, used_weights_median: 12
#
# 1165
# loss -49578.23046875
# nll 1.2027466297149658
# density 0.0046197150876796204
#
# val_loss: -47547.0391, val_nll: 1881.4030, val_ensemble: 0.5487, used_weights_median: 12
#
# 1166
# loss -49588.7109375
# nll 1.7017197608947754
# density 0.0046197150876796204
#
# val_loss: -47802.9648, val_nll: 1860.3413, val_ensemble: 0.5644, used_weights_median: 12
#
# 1167
# loss -49632.56640625
# nll 1.5969762802124023
# density 0.0046197150876796204
#
# val_loss: -47785.5742, val_nll: 1812.6448, val_ensemble: 0.5555, used_weights_median: 12
#
# 1168
# loss -49685.0703125
# nll 1.1580911874771118
# density 0.0046197150876796204
#
# val_loss: -47730.0898, val_nll: 1796.7614, val_ensemble: 0.5529, used_weights_median: 12
#
# 1169
# loss -49729.01171875
# nll 0.9681775569915771
# density 0.0046197150876796204
#
# val_loss: -47724.2852, val_nll: 1857.0239, val_ensemble: 0.5425, used_weights_median: 12
#
# 1170
# loss -49682.01953125
# nll 1.9564530849456787
# density 0.0046197150876796204
#
# val_loss: -47735.1719, val_nll: 1813.7051, val_ensemble: 0.5591, used_weights_median: 12
#
# 1171
# loss -49807.36328125
# nll 1.6061134338378906
# density 0.0046197150876796204
#
# val_loss: -47911.4531, val_nll: 1876.2810, val_ensemble: 0.5539, used_weights_median: 12
#
# 1172
# loss -49913.21484375
# nll 1.699627161026001
# density 0.0046197150876796204
#
# val_loss: -48009.5898, val_nll: 1838.0209, val_ensemble: 0.5456, used_weights_median: 12
#
# 1173
# loss -49836.16015625
# nll 1.6456584930419922
# density 0.0046197150876796204
#
# val_loss: -47996.1602, val_nll: 1821.7886, val_ensemble: 0.5565, used_weights_median: 12
#
# 1174
# loss -49883.87109375
# nll 1.9574360847473145
# density 0.0046197150876796204
#
# val_loss: -47938.8984, val_nll: 1809.2357, val_ensemble: 0.5612, used_weights_median: 12
#
# 1175
# loss -49988.671875
# nll 1.7894927263259888
# density 0.0046197150876796204
#
# val_loss: -48143.9844, val_nll: 1802.6213, val_ensemble: 0.5612, used_weights_median: 12
#
# 1176
# loss -50034.109375
# nll 1.2503753900527954
# density 0.0046197150876796204
#
# val_loss: -48161.1797, val_nll: 1832.2822, val_ensemble: 0.5508, used_weights_median: 12
#
# 1177
# loss -50092.80078125
# nll 2.0879061222076416
# density 0.0046197150876796204
#
# val_loss: -48257.2305, val_nll: 1808.0969, val_ensemble: 0.5571, used_weights_median: 12
#
# 1178
# loss -49965.48828125
# nll 1.571858525276184
# density 0.0046197150876796204
#
# val_loss: -48194.0391, val_nll: 1809.5846, val_ensemble: 0.5518, used_weights_median: 12
#
# 1179
# loss -50116.36328125
# nll 1.8366436958312988
# density 0.0046197150876796204
#
# val_loss: -48286.1836, val_nll: 1797.1569, val_ensemble: 0.5628, used_weights_median: 12
#
# 1180
# loss -50281.21875
# nll 1.5327727794647217
# density 0.0046197150876796204
#
# val_loss: -48217.5000, val_nll: 1843.0831, val_ensemble: 0.5425, used_weights_median: 12
#
# 1181
# loss -50142.7109375
# nll 1.9103302955627441
# density 0.0046197150876796204
#
# val_loss: -48416.1094, val_nll: 1833.1871, val_ensemble: 0.5597, used_weights_median: 12
#
# 1182
# loss -50276.859375
# nll 1.3965916633605957
# density 0.0046197150876796204
#
# val_loss: -48477.7852, val_nll: 1811.0072, val_ensemble: 0.5607, used_weights_median: 12
#
# 1183
# loss -50367.72265625
# nll 1.966234564781189
# density 0.0046197150876796204
#
# val_loss: -48483.4219, val_nll: 1830.6146, val_ensemble: 0.5498, used_weights_median: 12
#
# 1184
# loss -50293.4375
# nll 1.786144495010376
# density 0.0046197150876796204
#
# val_loss: -48578.2227, val_nll: 1820.5623, val_ensemble: 0.5633, used_weights_median: 12
#
# 1185
# loss -50525.9609375
# nll 1.9915056228637695
# density 0.0046197150876796204
#
# val_loss: -48529.2656, val_nll: 1805.6512, val_ensemble: 0.5581, used_weights_median: 12
#
# 1186
# loss -50457.83203125
# nll 1.0448329448699951
# density 0.0046197150876796204
#
# val_loss: -48671.6211, val_nll: 1829.7408, val_ensemble: 0.5545, used_weights_median: 12
#
# 1187
# loss -50408.73828125
# nll 1.6146767139434814
# density 0.0046197150876796204
#
# val_loss: -48715.8320, val_nll: 1815.2946, val_ensemble: 0.5607, used_weights_median: 12
#
# 1188
# loss -50535.4375
# nll 1.7508022785186768
# density 0.0046197150876796204
#
# val_loss: -48729.9531, val_nll: 1789.1515, val_ensemble: 0.5597, used_weights_median: 12
#
# 1189
# loss -50641.92578125
# nll 2.046213150024414
# density 0.0046197150876796204
#
# val_loss: -48685.2617, val_nll: 1809.1106, val_ensemble: 0.5602, used_weights_median: 12
#
# 1190
# loss -50671.90625
# nll 2.146749258041382
# density 0.0046197150876796204
#
# val_loss: -48483.4727, val_nll: 1790.4661, val_ensemble: 0.5581, used_weights_median: 12
#
# 1191
# loss -50850.92578125
# nll 2.003167152404785
# density 0.0046197150876796204
#
# val_loss: -48796.1250, val_nll: 1802.6462, val_ensemble: 0.5623, used_weights_median: 12
#
# 1192
# loss -50289.15625
# nll 1.7591688632965088
# density 0.0046197150876796204
#
# val_loss: -48890.0859, val_nll: 1815.0106, val_ensemble: 0.5602, used_weights_median: 12
#
# 1193
# loss -50764.99609375
# nll 1.5031319856643677
# density 0.0046197150876796204
#
# val_loss: -48559.8125, val_nll: 1807.6407, val_ensemble: 0.5539, used_weights_median: 12
#
# 1194
# loss -50824.73828125
# nll 1.2991507053375244
# density 0.0046197150876796204
#
# val_loss: -48961.7656, val_nll: 1791.0947, val_ensemble: 0.5602, used_weights_median: 12
#
# 1195
# loss -50797.84375
# nll 2.1446707248687744
# density 0.0046197150876796204
#
# val_loss: -48892.1875, val_nll: 1846.2915, val_ensemble: 0.5430, used_weights_median: 12
#
# 1196
# loss -50840.65625
# nll 1.3382306098937988
# density 0.0046197150876796204
#
# val_loss: -49200.1680, val_nll: 1848.3171, val_ensemble: 0.5440, used_weights_median: 12
#
# 1197
# loss -50950.7734375
# nll 1.460263967514038
# density 0.0046197150876796204
#
# val_loss: -49177.3008, val_nll: 1792.6334, val_ensemble: 0.5628, used_weights_median: 12
#
# 1198
# loss -51129.65234375
# nll 1.3282101154327393
# density 0.0046197150876796204
#
# val_loss: -49094.1172, val_nll: 1803.3903, val_ensemble: 0.5550, used_weights_median: 12
#
# 1199
# loss -50546.90625
# nll 1.8404481410980225
# density 0.0046197150876796204
#
# val_loss: -49213.3594, val_nll: 1822.7695, val_ensemble: 0.5612, used_weights_median: 12
#
# 5.05025e-05 density median
# 12.0 used weights median
# 0.3327253778009379 ensemble full
# 0.5494007295466388 ensemble median
# [0.3327253778009379, 5.05025e-05]

# %% [markdown]
# ## Weights used each class
#
# Classes:
#
# * 0 = Happy
# * 1 = Surprised
# * 2 = Neutral

# %%
train_data = torch.tensor(copy.deepcopy(X_original),dtype=torch.float32)
train_target = torch.tensor(copy.deepcopy(y_original), dtype=torch.float32)
for c in range(n_classes):
    pf.plot_model_vision_image(net, train_data=train_data, train_target=train_target, c=c, save_path=f"individual_classes/class{c}")
